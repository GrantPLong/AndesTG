# %% [markdown]
# # <center>detritalPy-mix</center>
# ### <center>Glenn R. Sharman and Sam A. Johnstone </center>
# #### <center>Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty</center>

# %% [markdown]
# #### <center>Version 0.1 (Beta)</center>
# ##### <center>Updated Feb 9, 2024</center>
# ##### <center><i>Requires detritalPy v1.4.0 or later</i></center>

# %% [markdown]
# <center>This is a <b>Beta</b> release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.</center>

# %% [markdown]
# <center>If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044) </center>

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).

# %%
dataToLoad = ['/Users/Glong1/Desktop/Andes/AndesTG/Mataquito_Paleo/Spreadsheets/CT-1-11_ZrUPb_datasheets.xlsx',
             '/Users/Glong1/Desktop/Andes/AndesTG/Mataquito_Paleo/Spreadsheets/CT-Ter_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

parent_list = ['CT-3','CT-8.2']
child_list = ['CT-Ter-2', 'CT-Ter-10']

# %%
# Specify file paths to data input file(s)
dataToLoad = ['example-data/Sundell and Saylor (2017) ds05.xlsx']

main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='U_Th_Pb')

# Sediment sources, or parents, must be formatted as a tuple, as shown below
parent_list = [(['Mu_Us'], 'Mu_Us'),
             (['Central_Deserts'], 'Central Deserts'),
             (['Qaidam_Basin'], 'Qaidam Basin'),
             (['NE_Tibet_Yellow_River'],'Yellow River')]

# Child samples, or samples assumed to be mixtures of the parents
child_list = ['Loess']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Specify file paths to data input file(s)
#       2 dataToLoad = ['example-data/Sundell and Saylor (2017) ds05.xlsx']
# ----> 4 main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='U_Th_Pb')
#       6 # Sediment sources, or parents, must be formatted as a tuple, as shown below
#       7 parent_list = [(['Mu_Us'], 'Mu_Us'),
#       8              (['Central_Deserts'], 'Central Deserts'),
#       9              (['Qaidam_Basin'], 'Qaidam Basin'),
#      10              (['NE_Tibet_Yellow_River'],'Yellow River')]
#
# File ~/anaconda3/lib/python3.11/site-packages/detritalpy/detritalFuncs.py:113, in loadDataExcel(dataToPlot, mainSheet, dataSheet, ID_col)
#     111 for i in range(len(dataToPlot)):
#     112     if dataToPlot[i].endswith('.xlsx'):
# --> 113         dfs = pd.read_excel(dataToPlot[i],sheet_name=None, engine='openpyxl')
#     114     if dataToPlot[i].endswith('.xls'):
#     115         dfs = pd.read_excel(dataToPlot[i],sheet_name=None, engine='xlrd')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:572, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     568 self.handles = IOHandles(
#     569     handle=filepath_or_buffer, compression={"method": None}
#     570 )
#     571 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 572     self.handles = get_handle(
#     573         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     574     )
#     576 if isinstance(self.handles.handle, self._workbook_class):
#     577     self.book = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example-data/Sundell and Saylor (2017) ds05.xlsx'

# %%
dataToLoad = ['example-data/Blum et al. (2018) Scientific Reports.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, mainSheet = 'Samples', dataSheet='U_Th_Pb')

# Samples grouped by age
parent_list = [(['M01_GR'],'Modern Ganges River'),
              (['J03'],'Modern Brahmaputra River')]
               
child_list =  [(['U1451A_4H-6H','U1450A_6F-8F','U1452B_8F','U1453A_11F','U1451A_13F_combined','U1453A_26F'],'Mid-Pleistocene'),
              (['U1452B_38F','U1453_32F','U1449A_29,30,31F_combined'],'Early-Pleistocene'),
              (['U1450A_70F','U1450A_78,79,80F','U1450_98F','U1450A_124F'],'Pliocene'),
              (['U1451A_37F','U1451A_41F','U1451A_47,48,49F_pilot','U1451A_60F','U1451A_66F','U1451B_3X','U1451A_80F','U1451A_102F','U1451B_22R'],'Late Miocene'),
              (['U1451B_41R','U1451B_51_54R','U1451B_62R'],'Early- to Mid-Miocene')]

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 10 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-Ter-2
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.21807280489126724
#             Iterations: 15
#             Function evaluations: 92
#             Gradient evaluations: 15
# Starting: CT-Ter-10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.24793250277285755
#             Iterations: 11
#             Function evaluations: 47
#             Gradient evaluations: 11
# Completed mixing children.
# Time elapsed: 0.085 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-Ter-2
# Best-fit vmax : 0.218
# Mixing coefficients
# --- CT-3 : 0.317
# --- CT-8.2 : 0.683
# Sample: CT-Ter-10
# Best-fit vmax : 0.248
# Mixing coefficients
# --- CT-3 : 0.345
# --- CT-8.2 : 0.655

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 10000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-Ter-2 ( 1 of 2 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 7.224 minutes remaining
# 0.1 % completed, 0.006 minutes elapsed, 5.383 minutes remaining
# 0.2 % completed, 0.011 minutes elapsed, 5.3 minutes remaining
# 0.3 % completed, 0.016 minutes elapsed, 5.26 minutes remaining
# 0.4 % completed, 0.022 minutes elapsed, 5.251 minutes remaining
# 0.5 % completed, 0.027 minutes elapsed, 5.221 minutes remaining
# 0.6 % completed, 0.032 minutes elapsed, 5.199 minutes remaining
# 0.7 % completed, 0.037 minutes elapsed, 5.198 minutes remaining
# 0.8 % completed, 0.042 minutes elapsed, 5.182 minutes remaining
# 0.9 % completed, 0.048 minutes elapsed, 5.278 minutes remaining
# 1.0 % completed, 0.054 minutes elapsed, 5.256 minutes remaining
# 1.1 % completed, 0.059 minutes elapsed, 5.239 minutes remaining
# 1.2 % completed, 0.064 minutes elapsed, 5.224 minutes remaining
# 1.3 % completed, 0.069 minutes elapsed, 5.214 minutes remaining
# 1.4 % completed, 0.074 minutes elapsed, 5.201 minutes remaining
# 1.5 % completed, 0.08 minutes elapsed, 5.192 minutes remaining
# 1.6 % completed, 0.085 minutes elapsed, 5.185 minutes remaining
# 1.7 % completed, 0.09 minutes elapsed, 5.184 minutes remaining
# 1.8 % completed, 0.095 minutes elapsed, 5.175 minutes remaining
# 1.9 % completed, 0.101 minutes elapsed, 5.166 minutes remaining
# 2.0 % completed, 0.106 minutes elapsed, 5.152 minutes remaining
# 2.1 % completed, 0.111 minutes elapsed, 5.143 minutes remaining
# 2.2 % completed, 0.116 minutes elapsed, 5.136 minutes remaining
# 2.3 % completed, 0.121 minutes elapsed, 5.129 minutes remaining
# 2.4 % completed, 0.126 minutes elapsed, 5.119 minutes remaining
# 2.5 % completed, 0.132 minutes elapsed, 5.12 minutes remaining
# 2.6 % completed, 0.137 minutes elapsed, 5.11 minutes remaining
# 2.7 % completed, 0.142 minutes elapsed, 5.102 minutes remaining
# 2.8 % completed, 0.147 minutes elapsed, 5.091 minutes remaining
# 2.9 % completed, 0.152 minutes elapsed, 5.084 minutes remaining
# 3.0 % completed, 0.158 minutes elapsed, 5.079 minutes remaining
# 3.1 % completed, 0.163 minutes elapsed, 5.074 minutes remaining
# 3.2 % completed, 0.168 minutes elapsed, 5.066 minutes remaining
# 3.3 % completed, 0.173 minutes elapsed, 5.058 minutes remaining
# 3.4 % completed, 0.178 minutes elapsed, 5.05 minutes remaining
# 3.5 % completed, 0.183 minutes elapsed, 5.041 minutes remaining
# 3.6 % completed, 0.189 minutes elapsed, 5.037 minutes remaining
# 3.7 % completed, 0.194 minutes elapsed, 5.03 minutes remaining
# 3.8 % completed, 0.199 minutes elapsed, 5.025 minutes remaining
# 3.9 % completed, 0.204 minutes elapsed, 5.021 minutes remaining
# 4.0 % completed, 0.209 minutes elapsed, 5.015 minutes remaining
# 4.1 % completed, 0.215 minutes elapsed, 5.007 minutes remaining
# 4.2 % completed, 0.22 minutes elapsed, 5.0 minutes remaining
# 4.3 % completed, 0.225 minutes elapsed, 4.993 minutes remaining
# 4.4 % completed, 0.23 minutes elapsed, 4.988 minutes remaining
# 4.5 % completed, 0.235 minutes elapsed, 4.985 minutes remaining
# 4.6 % completed, 0.241 minutes elapsed, 4.978 minutes remaining
# 4.7 % completed, 0.246 minutes elapsed, 4.974 minutes remaining
# 4.8 % completed, 0.251 minutes elapsed, 4.969 minutes remaining
# 4.9 % completed, 0.256 minutes elapsed, 4.962 minutes remaining
# 5.0 % completed, 0.261 minutes elapsed, 4.955 minutes remaining
# 5.1 % completed, 0.267 minutes elapsed, 4.951 minutes remaining
# 5.2 % completed, 0.272 minutes elapsed, 4.946 minutes remaining
# 5.3 % completed, 0.277 minutes elapsed, 4.941 minutes remaining
# 5.4 % completed, 0.282 minutes elapsed, 4.936 minutes remaining
# 5.5 % completed, 0.288 minutes elapsed, 4.931 minutes remaining
# 5.6 % completed, 0.293 minutes elapsed, 4.924 minutes remaining
# 23.2 % completed, 1.209 minutes elapsed, 4.002 minutes remaining
# 23.3 % completed, 1.215 minutes elapsed, 3.996 minutes remaining
# 23.4 % completed, 1.22 minutes elapsed, 3.991 minutes remaining
# 23.5 % completed, 1.225 minutes elapsed, 3.987 minutes remaining
# 23.6 % completed, 1.231 minutes elapsed, 3.982 minutes remaining
# 23.7 % completed, 1.236 minutes elapsed, 3.976 minutes remaining
# 23.8 % completed, 1.241 minutes elapsed, 3.971 minutes remaining
# 23.9 % completed, 1.246 minutes elapsed, 3.966 minutes remaining
# 24.0 % completed, 1.251 minutes elapsed, 3.961 minutes remaining
# 24.1 % completed, 1.257 minutes elapsed, 3.956 minutes remaining
# 24.2 % completed, 1.262 minutes elapsed, 3.95 minutes remaining
# 24.3 % completed, 1.267 minutes elapsed, 3.945 minutes remaining
# 24.4 % completed, 1.272 minutes elapsed, 3.94 minutes remaining
# 24.5 % completed, 1.277 minutes elapsed, 3.934 minutes remaining
# 24.6 % completed, 1.282 minutes elapsed, 3.929 minutes remaining
# 24.7 % completed, 1.288 minutes elapsed, 3.924 minutes remaining
# 24.8 % completed, 1.293 minutes elapsed, 3.919 minutes remaining
# 24.9 % completed, 1.298 minutes elapsed, 3.913 minutes remaining
# 25.0 % completed, 1.303 minutes elapsed, 3.908 minutes remaining
# 25.1 % completed, 1.308 minutes elapsed, 3.902 minutes remaining
# 25.2 % completed, 1.313 minutes elapsed, 3.897 minutes remaining
# 25.3 % completed, 1.319 minutes elapsed, 3.892 minutes remaining
# 25.4 % completed, 1.324 minutes elapsed, 3.886 minutes remaining
# 25.5 % completed, 1.329 minutes elapsed, 3.881 minutes remaining
# 25.6 % completed, 1.334 minutes elapsed, 3.876 minutes remaining
# 25.7 % completed, 1.339 minutes elapsed, 3.87 minutes remaining
# 25.8 % completed, 1.344 minutes elapsed, 3.865 minutes remaining
# 25.9 % completed, 1.35 minutes elapsed, 3.86 minutes remaining
# 26.0 % completed, 1.355 minutes elapsed, 3.854 minutes remaining
# 26.1 % completed, 1.36 minutes elapsed, 3.849 minutes remaining
# 26.2 % completed, 1.365 minutes elapsed, 3.843 minutes remaining
# 26.3 % completed, 1.37 minutes elapsed, 3.838 minutes remaining
# 26.4 % completed, 1.375 minutes elapsed, 3.833 minutes remaining
# 26.5 % completed, 1.381 minutes elapsed, 3.828 minutes remaining
# 26.6 % completed, 1.386 minutes elapsed, 3.822 minutes remaining
# 26.7 % completed, 1.391 minutes elapsed, 3.817 minutes remaining
# 26.8 % completed, 1.396 minutes elapsed, 3.812 minutes remaining
# 26.9 % completed, 1.401 minutes elapsed, 3.807 minutes remaining
# 27.0 % completed, 1.407 minutes elapsed, 3.801 minutes remaining
# 27.1 % completed, 1.412 minutes elapsed, 3.796 minutes remaining
# 27.2 % completed, 1.417 minutes elapsed, 3.791 minutes remaining
# 27.3 % completed, 1.422 minutes elapsed, 3.785 minutes remaining
# 27.4 % completed, 1.427 minutes elapsed, 3.78 minutes remaining
# 27.5 % completed, 1.432 minutes elapsed, 3.774 minutes remaining
# 27.6 % completed, 1.437 minutes elapsed, 3.769 minutes remaining
# 27.7 % completed, 1.443 minutes elapsed, 3.764 minutes remaining
# 27.8 % completed, 1.448 minutes elapsed, 3.759 minutes remaining
# 27.9 % completed, 1.453 minutes elapsed, 3.753 minutes remaining
# 28.0 % completed, 1.458 minutes elapsed, 3.748 minutes remaining
# 28.1 % completed, 1.463 minutes elapsed, 3.743 minutes remaining
# 28.2 % completed, 1.469 minutes elapsed, 3.738 minutes remaining
# 28.3 % completed, 1.474 minutes elapsed, 3.732 minutes remaining
# 28.4 % completed, 1.479 minutes elapsed, 3.727 minutes remaining
# 28.5 % completed, 1.484 minutes elapsed, 3.721 minutes remaining
# 28.6 % completed, 1.489 minutes elapsed, 3.716 minutes remaining
# 28.7 % completed, 1.494 minutes elapsed, 3.711 minutes remaining
# 28.8 % completed, 1.499 minutes elapsed, 3.705 minutes remaining
# 28.9 % completed, 1.504 minutes elapsed, 3.7 minutes remaining
# 29.0 % completed, 1.51 minutes elapsed, 3.695 minutes remaining
# 29.1 % completed, 1.515 minutes elapsed, 3.689 minutes remaining
# 29.2 % completed, 1.52 minutes elapsed, 3.684 minutes remaining
# 29.3 % completed, 1.526 minutes elapsed, 3.68 minutes remaining
# 29.4 % completed, 1.531 minutes elapsed, 3.675 minutes remaining
# 29.5 % completed, 1.536 minutes elapsed, 3.669 minutes remaining
# 29.6 % completed, 1.541 minutes elapsed, 3.664 minutes remaining
# 29.7 % completed, 1.546 minutes elapsed, 3.658 minutes remaining
# 29.8 % completed, 1.551 minutes elapsed, 3.653 minutes remaining
# 29.9 % completed, 1.556 minutes elapsed, 3.648 minutes remaining
# 30.0 % completed, 1.562 minutes elapsed, 3.643 minutes remaining
# 30.1 % completed, 1.567 minutes elapsed, 3.637 minutes remaining
# 30.2 % completed, 1.572 minutes elapsed, 3.632 minutes remaining
# 30.3 % completed, 1.577 minutes elapsed, 3.627 minutes remaining
# 30.4 % completed, 1.583 minutes elapsed, 3.622 minutes remaining
# 30.5 % completed, 1.588 minutes elapsed, 3.617 minutes remaining
# 30.6 % completed, 1.593 minutes elapsed, 3.612 minutes remaining
# 30.7 % completed, 1.598 minutes elapsed, 3.607 minutes remaining
# 30.8 % completed, 1.604 minutes elapsed, 3.602 minutes remaining
# 30.9 % completed, 1.609 minutes elapsed, 3.597 minutes remaining
# 31.0 % completed, 1.614 minutes elapsed, 3.592 minutes remaining
# 31.1 % completed, 1.62 minutes elapsed, 3.587 minutes remaining
# 31.2 % completed, 1.625 minutes elapsed, 3.582 minutes remaining
# 31.3 % completed, 1.63 minutes elapsed, 3.577 minutes remaining
# 31.4 % completed, 1.636 minutes elapsed, 3.572 minutes remaining
# 31.5 % completed, 1.641 minutes elapsed, 3.567 minutes remaining
# 31.6 % completed, 1.646 minutes elapsed, 3.562 minutes remaining
# 31.7 % completed, 1.651 minutes elapsed, 3.556 minutes remaining
# 31.8 % completed, 1.656 minutes elapsed, 3.551 minutes remaining
# 31.9 % completed, 1.662 minutes elapsed, 3.546 minutes remaining
# 62.8 % completed, 3.3 minutes elapsed, 1.955 minutes remaining
# 62.9 % completed, 3.305 minutes elapsed, 1.949 minutes remaining
# 63.0 % completed, 3.311 minutes elapsed, 1.944 minutes remaining
# 63.1 % completed, 3.316 minutes elapsed, 1.939 minutes remaining
# 63.2 % completed, 3.321 minutes elapsed, 1.934 minutes remaining
# 63.3 % completed, 3.327 minutes elapsed, 1.928 minutes remaining
# 63.4 % completed, 3.332 minutes elapsed, 1.923 minutes remaining
# 63.5 % completed, 3.337 minutes elapsed, 1.918 minutes remaining
# 63.6 % completed, 3.343 minutes elapsed, 1.913 minutes remaining
# 63.7 % completed, 3.348 minutes elapsed, 1.908 minutes remaining
# 63.8 % completed, 3.354 minutes elapsed, 1.903 minutes remaining
# 63.9 % completed, 3.359 minutes elapsed, 1.898 minutes remaining
# 64.0 % completed, 3.365 minutes elapsed, 1.892 minutes remaining
# 64.1 % completed, 3.37 minutes elapsed, 1.887 minutes remaining
# 64.2 % completed, 3.375 minutes elapsed, 1.882 minutes remaining
# 64.3 % completed, 3.381 minutes elapsed, 1.877 minutes remaining
# 64.4 % completed, 3.386 minutes elapsed, 1.872 minutes remaining
# 64.5 % completed, 3.392 minutes elapsed, 1.866 minutes remaining
# 64.6 % completed, 3.397 minutes elapsed, 1.861 minutes remaining
# 64.7 % completed, 3.403 minutes elapsed, 1.856 minutes remaining
# 64.8 % completed, 3.408 minutes elapsed, 1.851 minutes remaining
# 64.9 % completed, 3.413 minutes elapsed, 1.846 minutes remaining
# 65.0 % completed, 3.419 minutes elapsed, 1.841 minutes remaining
# 65.1 % completed, 3.424 minutes elapsed, 1.835 minutes remaining
# 65.2 % completed, 3.43 minutes elapsed, 1.83 minutes remaining
# 65.3 % completed, 3.435 minutes elapsed, 1.825 minutes remaining
# 65.4 % completed, 3.44 minutes elapsed, 1.82 minutes remaining
# 65.5 % completed, 3.446 minutes elapsed, 1.815 minutes remaining
# 65.6 % completed, 3.451 minutes elapsed, 1.809 minutes remaining
# 65.7 % completed, 3.457 minutes elapsed, 1.804 minutes remaining
# 65.8 % completed, 3.462 minutes elapsed, 1.799 minutes remaining
# 65.9 % completed, 3.467 minutes elapsed, 1.794 minutes remaining
# 66.0 % completed, 3.473 minutes elapsed, 1.789 minutes remaining
# 66.1 % completed, 3.478 minutes elapsed, 1.783 minutes remaining
# 66.2 % completed, 3.483 minutes elapsed, 1.778 minutes remaining
# 66.3 % completed, 3.489 minutes elapsed, 1.773 minutes remaining
# 66.4 % completed, 3.494 minutes elapsed, 1.768 minutes remaining
# 66.5 % completed, 3.499 minutes elapsed, 1.763 minutes remaining
# 66.6 % completed, 3.505 minutes elapsed, 1.757 minutes remaining
# 66.7 % completed, 3.51 minutes elapsed, 1.752 minutes remaining
# 66.8 % completed, 3.515 minutes elapsed, 1.747 minutes remaining
# 66.9 % completed, 3.521 minutes elapsed, 1.742 minutes remaining
# 67.0 % completed, 3.527 minutes elapsed, 1.737 minutes remaining
# 67.1 % completed, 3.532 minutes elapsed, 1.731 minutes remaining
# 71.6 % completed, 3.771 minutes elapsed, 1.495 minutes remaining
# 71.7 % completed, 3.776 minutes elapsed, 1.49 minutes remaining
# 71.8 % completed, 3.781 minutes elapsed, 1.485 minutes remaining
# 71.9 % completed, 3.787 minutes elapsed, 1.48 minutes remaining
# 72.0 % completed, 3.792 minutes elapsed, 1.474 minutes remaining
# 72.1 % completed, 3.797 minutes elapsed, 1.469 minutes remaining
# 72.2 % completed, 3.803 minutes elapsed, 1.464 minutes remaining
# 72.3 % completed, 3.808 minutes elapsed, 1.459 minutes remaining
# 72.4 % completed, 3.814 minutes elapsed, 1.454 minutes remaining
# 72.5 % completed, 3.819 minutes elapsed, 1.448 minutes remaining
# 72.6 % completed, 3.824 minutes elapsed, 1.443 minutes remaining
# 72.7 % completed, 3.829 minutes elapsed, 1.438 minutes remaining
# 72.8 % completed, 3.835 minutes elapsed, 1.433 minutes remaining
# 72.9 % completed, 3.84 minutes elapsed, 1.427 minutes remaining
# 73.0 % completed, 3.846 minutes elapsed, 1.422 minutes remaining
# 73.1 % completed, 3.851 minutes elapsed, 1.417 minutes remaining
# 73.2 % completed, 3.856 minutes elapsed, 1.412 minutes remaining
# 73.3 % completed, 3.862 minutes elapsed, 1.406 minutes remaining
# 73.4 % completed, 3.867 minutes elapsed, 1.401 minutes remaining
# 73.5 % completed, 3.872 minutes elapsed, 1.396 minutes remaining
# 73.6 % completed, 3.877 minutes elapsed, 1.391 minutes remaining
# 73.7 % completed, 3.883 minutes elapsed, 1.385 minutes remaining
# 73.8 % completed, 3.888 minutes elapsed, 1.38 minutes remaining
# 73.9 % completed, 3.893 minutes elapsed, 1.375 minutes remaining
# ...
# 75.4 % completed, 3.93 minutes elapsed, 1.282 minutes remaining
# 75.5 % completed, 3.935 minutes elapsed, 1.277 minutes remaining
# 75.6 % completed, 3.941 minutes elapsed, 1.272 minutes remaining
# 75.7 % completed, 3.946 minutes elapsed, 1.266 minutes remaining
# 75.8 % completed, 3.951 minutes elapsed, 1.261 minutes remaining
# 75.9 % completed, 3.956 minutes elapsed, 1.256 minutes remaining
# 76.0 % completed, 3.962 minutes elapsed, 1.251 minutes remaining
# 76.1 % completed, 3.967 minutes elapsed, 1.246 minutes remaining
# 76.2 % completed, 3.972 minutes elapsed, 1.24 minutes remaining
# 76.3 % completed, 3.977 minutes elapsed, 1.235 minutes remaining
# 76.4 % completed, 3.982 minutes elapsed, 1.23 minutes remaining
# 76.5 % completed, 3.987 minutes elapsed, 1.225 minutes remaining
# 76.6 % completed, 3.993 minutes elapsed, 1.22 minutes remaining
# 76.7 % completed, 3.998 minutes elapsed, 1.214 minutes remaining
# 76.8 % completed, 4.003 minutes elapsed, 1.209 minutes remaining
# 76.9 % completed, 4.008 minutes elapsed, 1.204 minutes remaining
# 77.0 % completed, 4.013 minutes elapsed, 1.199 minutes remaining
# 77.1 % completed, 4.018 minutes elapsed, 1.193 minutes remaining
# 77.2 % completed, 4.023 minutes elapsed, 1.188 minutes remaining
# 77.3 % completed, 4.029 minutes elapsed, 1.183 minutes remaining
# 81.8 % completed, 4.264 minutes elapsed, 0.949 minutes remaining
# 81.9 % completed, 4.269 minutes elapsed, 0.943 minutes remaining
# 82.0 % completed, 4.274 minutes elapsed, 0.938 minutes remaining
# 82.1 % completed, 4.28 minutes elapsed, 0.933 minutes remaining
# 82.2 % completed, 4.285 minutes elapsed, 0.928 minutes remaining
# 82.3 % completed, 4.29 minutes elapsed, 0.923 minutes remaining
# 82.4 % completed, 4.296 minutes elapsed, 0.917 minutes remaining
# 82.5 % completed, 4.301 minutes elapsed, 0.912 minutes remaining
# 82.6 % completed, 4.306 minutes elapsed, 0.907 minutes remaining
# 82.7 % completed, 4.311 minutes elapsed, 0.902 minutes remaining
# 82.8 % completed, 4.317 minutes elapsed, 0.897 minutes remaining
# 82.9 % completed, 4.322 minutes elapsed, 0.891 minutes remaining
# 83.0 % completed, 4.327 minutes elapsed, 0.886 minutes remaining
# 83.1 % completed, 4.332 minutes elapsed, 0.881 minutes remaining
# 83.2 % completed, 4.338 minutes elapsed, 0.876 minutes remaining
# 83.3 % completed, 4.343 minutes elapsed, 0.871 minutes remaining
# 83.4 % completed, 4.348 minutes elapsed, 0.865 minutes remaining
# 83.5 % completed, 4.353 minutes elapsed, 0.86 minutes remaining
# 83.6 % completed, 4.358 minutes elapsed, 0.855 minutes remaining
# 83.7 % completed, 4.364 minutes elapsed, 0.85 minutes remaining
# 83.8 % completed, 4.369 minutes elapsed, 0.844 minutes remaining
# 83.9 % completed, 4.374 minutes elapsed, 0.839 minutes remaining
# 84.0 % completed, 4.379 minutes elapsed, 0.834 minutes remaining
# 84.1 % completed, 4.384 minutes elapsed, 0.829 minutes remaining
# 84.2 % completed, 4.389 minutes elapsed, 0.824 minutes remaining
# 84.3 % completed, 4.394 minutes elapsed, 0.818 minutes remaining
# 84.4 % completed, 4.4 minutes elapsed, 0.813 minutes remaining
# 84.5 % completed, 4.405 minutes elapsed, 0.808 minutes remaining
# 84.6 % completed, 4.41 minutes elapsed, 0.803 minutes remaining
# 84.7 % completed, 4.415 minutes elapsed, 0.798 minutes remaining
# 84.8 % completed, 4.421 minutes elapsed, 0.792 minutes remaining
# 84.9 % completed, 4.426 minutes elapsed, 0.787 minutes remaining
# 85.0 % completed, 4.431 minutes elapsed, 0.782 minutes remaining
# 85.1 % completed, 4.436 minutes elapsed, 0.777 minutes remaining
# 85.2 % completed, 4.441 minutes elapsed, 0.771 minutes remaining
# 85.3 % completed, 4.447 minutes elapsed, 0.766 minutes remaining
# 85.4 % completed, 4.452 minutes elapsed, 0.761 minutes remaining
# 85.5 % completed, 4.457 minutes elapsed, 0.756 minutes remaining
# 85.6 % completed, 4.462 minutes elapsed, 0.751 minutes remaining
# 85.7 % completed, 4.467 minutes elapsed, 0.745 minutes remaining
# 85.8 % completed, 4.473 minutes elapsed, 0.74 minutes remaining
# 85.9 % completed, 4.478 minutes elapsed, 0.735 minutes remaining
# 86.0 % completed, 4.483 minutes elapsed, 0.73 minutes remaining
# 86.1 % completed, 4.488 minutes elapsed, 0.724 minutes remaining
# 86.2 % completed, 4.493 minutes elapsed, 0.719 minutes remaining
# 86.3 % completed, 4.498 minutes elapsed, 0.714 minutes remaining
# 86.4 % completed, 4.503 minutes elapsed, 0.709 minutes remaining
# 86.5 % completed, 4.509 minutes elapsed, 0.704 minutes remaining
# 86.6 % completed, 4.514 minutes elapsed, 0.698 minutes remaining
# 86.7 % completed, 4.519 minutes elapsed, 0.693 minutes remaining
# 86.8 % completed, 4.524 minutes elapsed, 0.688 minutes remaining
# 86.9 % completed, 4.529 minutes elapsed, 0.683 minutes remaining
# 87.0 % completed, 4.534 minutes elapsed, 0.677 minutes remaining
# 87.1 % completed, 4.54 minutes elapsed, 0.672 minutes remaining
# 87.2 % completed, 4.545 minutes elapsed, 0.667 minutes remaining
# 87.3 % completed, 4.55 minutes elapsed, 0.662 minutes remaining
# 87.4 % completed, 4.555 minutes elapsed, 0.657 minutes remaining
# 87.5 % completed, 4.56 minutes elapsed, 0.651 minutes remaining
# 87.6 % completed, 4.566 minutes elapsed, 0.646 minutes remaining
# 87.7 % completed, 4.571 minutes elapsed, 0.641 minutes remaining
# 87.8 % completed, 4.576 minutes elapsed, 0.636 minutes remaining
# 87.9 % completed, 4.581 minutes elapsed, 0.631 minutes remaining
# 88.0 % completed, 4.586 minutes elapsed, 0.625 minutes remaining
# 88.1 % completed, 4.591 minutes elapsed, 0.62 minutes remaining
# 88.2 % completed, 4.597 minutes elapsed, 0.615 minutes remaining
# 88.3 % completed, 4.602 minutes elapsed, 0.61 minutes remaining
# 88.4 % completed, 4.607 minutes elapsed, 0.604 minutes remaining
# 88.5 % completed, 4.612 minutes elapsed, 0.599 minutes remaining
# 88.6 % completed, 4.617 minutes elapsed, 0.594 minutes remaining
# 88.7 % completed, 4.623 minutes elapsed, 0.589 minutes remaining
# 88.8 % completed, 4.628 minutes elapsed, 0.584 minutes remaining
# 88.9 % completed, 4.633 minutes elapsed, 0.578 minutes remaining
# 89.0 % completed, 4.638 minutes elapsed, 0.573 minutes remaining
# 89.1 % completed, 4.643 minutes elapsed, 0.568 minutes remaining
# 89.2 % completed, 4.648 minutes elapsed, 0.563 minutes remaining
# 89.3 % completed, 4.654 minutes elapsed, 0.558 minutes remaining
# 89.4 % completed, 4.659 minutes elapsed, 0.552 minutes remaining
# 89.5 % completed, 4.664 minutes elapsed, 0.547 minutes remaining
# 89.6 % completed, 4.669 minutes elapsed, 0.542 minutes remaining
# 89.7 % completed, 4.674 minutes elapsed, 0.537 minutes remaining
# 89.8 % completed, 4.679 minutes elapsed, 0.531 minutes remaining
# 89.9 % completed, 4.684 minutes elapsed, 0.526 minutes remaining
# 90.0 % completed, 4.69 minutes elapsed, 0.521 minutes remaining
# 90.1 % completed, 4.695 minutes elapsed, 0.516 minutes remaining
# 90.2 % completed, 4.7 minutes elapsed, 0.511 minutes remaining
# 90.3 % completed, 4.705 minutes elapsed, 0.505 minutes remaining
# 90.4 % completed, 4.71 minutes elapsed, 0.5 minutes remaining
# 94.9 % completed, 4.944 minutes elapsed, 0.266 minutes remaining
# 95.0 % completed, 4.95 minutes elapsed, 0.26 minutes remaining
# 95.1 % completed, 4.955 minutes elapsed, 0.255 minutes remaining
# 95.2 % completed, 4.96 minutes elapsed, 0.25 minutes remaining
# 95.3 % completed, 4.965 minutes elapsed, 0.245 minutes remaining
# 95.4 % completed, 4.971 minutes elapsed, 0.24 minutes remaining
# 95.5 % completed, 4.976 minutes elapsed, 0.234 minutes remaining
# 95.6 % completed, 4.981 minutes elapsed, 0.229 minutes remaining
# 95.7 % completed, 4.986 minutes elapsed, 0.224 minutes remaining
# 95.8 % completed, 4.991 minutes elapsed, 0.219 minutes remaining
# 95.9 % completed, 4.996 minutes elapsed, 0.214 minutes remaining
# 96.0 % completed, 5.001 minutes elapsed, 0.208 minutes remaining
# 96.1 % completed, 5.006 minutes elapsed, 0.203 minutes remaining
# 96.2 % completed, 5.012 minutes elapsed, 0.198 minutes remaining
# 96.3 % completed, 5.017 minutes elapsed, 0.193 minutes remaining
# 96.4 % completed, 5.022 minutes elapsed, 0.188 minutes remaining
# 96.5 % completed, 5.027 minutes elapsed, 0.182 minutes remaining
# 96.6 % completed, 5.032 minutes elapsed, 0.177 minutes remaining
# 96.7 % completed, 5.038 minutes elapsed, 0.172 minutes remaining
# 96.8 % completed, 5.043 minutes elapsed, 0.167 minutes remaining
# 96.9 % completed, 5.048 minutes elapsed, 0.161 minutes remaining
# 97.0 % completed, 5.053 minutes elapsed, 0.156 minutes remaining
# 97.1 % completed, 5.058 minutes elapsed, 0.151 minutes remaining
# 97.2 % completed, 5.063 minutes elapsed, 0.146 minutes remaining
# 97.3 % completed, 5.068 minutes elapsed, 0.141 minutes remaining
# 97.4 % completed, 5.073 minutes elapsed, 0.135 minutes remaining
# 97.5 % completed, 5.079 minutes elapsed, 0.13 minutes remaining
# 97.6 % completed, 5.084 minutes elapsed, 0.125 minutes remaining
# 97.7 % completed, 5.089 minutes elapsed, 0.12 minutes remaining
# 97.8 % completed, 5.094 minutes elapsed, 0.115 minutes remaining
# 97.9 % completed, 5.099 minutes elapsed, 0.109 minutes remaining
# 98.0 % completed, 5.105 minutes elapsed, 0.104 minutes remaining
# 98.1 % completed, 5.11 minutes elapsed, 0.099 minutes remaining
# 98.2 % completed, 5.115 minutes elapsed, 0.094 minutes remaining
# 98.3 % completed, 5.12 minutes elapsed, 0.089 minutes remaining
# 98.4 % completed, 5.126 minutes elapsed, 0.083 minutes remaining
# 98.5 % completed, 5.131 minutes elapsed, 0.078 minutes remaining
# 98.6 % completed, 5.136 minutes elapsed, 0.073 minutes remaining
# 98.7 % completed, 5.142 minutes elapsed, 0.068 minutes remaining
# 98.8 % completed, 5.147 minutes elapsed, 0.063 minutes remaining
# 98.9 % completed, 5.152 minutes elapsed, 0.057 minutes remaining
# 99.0 % completed, 5.157 minutes elapsed, 0.052 minutes remaining
# 99.1 % completed, 5.162 minutes elapsed, 0.047 minutes remaining
# 99.2 % completed, 5.168 minutes elapsed, 0.042 minutes remaining
# 99.3 % completed, 5.173 minutes elapsed, 0.036 minutes remaining
# 99.4 % completed, 5.178 minutes elapsed, 0.031 minutes remaining
# 99.5 % completed, 5.183 minutes elapsed, 0.026 minutes remaining
# 99.6 % completed, 5.188 minutes elapsed, 0.021 minutes remaining
# 99.7 % completed, 5.193 minutes elapsed, 0.016 minutes remaining
# 99.8 % completed, 5.198 minutes elapsed, 0.01 minutes remaining
# 99.9 % completed, 5.204 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 200, 1000, 3000] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Save figure as PDF
fig.savefig('dPy-mix_results.pdf')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
#Save figure as PDF
f.savefig('dPy-mix_objective_function_distributions.pdf')

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
#Save figure as PDF
f.savefig('dPy-mix_distribution_comparisons.pdf')

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
#Save figure as PDF
f.savefig('dPy-mix_spatial_comparison.pdf')

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
file_name = 'dPy-mix_results.xlsx'

dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                    obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                    bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                    doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                    mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                    worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
# Out:
# Workbook saved
