# %% [markdown]
# # DetritalPy Mixing code for the Mataquito River: Every Scenario

# %% [markdown]
# ## detritalPy-mix
# #### Glenn R. Sharman and Sam A. Johnstone
# #### Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty
# #### Version 0.1 (Beta)
# ##### Updated Feb 9, 2024
# ##### Requires detritalPy v1.4.0 or later
# ##### This is a Beta release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.
# ##### If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044)

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import os
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).
#
# Change parent and child list to see mixing results for CT-1 through CT-11

# %%
dataToLoad = ['/Users/Glong1/Desktop/Andes/AndesTG/Mataquito/Zircon/Spreadsheets/CT-1-11_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

""" 
Plug in the two / three parents that you want followed by all the children associated with all the parents. The options below are set up for easy use.
You will choose what parents you want and the associated child. Comment in/out whichever you want
"""
# Child options where parent list is CT-7, CT-1
#parent_list = ['CT-7', 'CT-1']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Child options where parent list is CT-5, CT-6
parent_list = ['CT-5', 'CT-6']
    # children options
#child_list = ['CT-4']
child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Parent list options where Child is CT-2
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-2']

# Parent list options where Child is CT-9
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#parent_list = ['CT-2', 'CT-3']
#child_list = ['CT-9']

# Three to one mixtures
    # Parent list options where Child is CT-2
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-2']

    # Parent list options where Child is CT-9
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-9']

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 2 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.1304147039483598
#             Iterations: 7
#             Function evaluations: 31
#             Gradient evaluations: 7
# Completed mixing children.
# Time elapsed: 0.06 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-10
# Best-fit vmax : 0.13
# Mixing coefficients
# --- CT-5 : 0.664
# --- CT-6 : 0.336

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 5000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-10 ( 1 of 1 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 5.968 minutes remaining
# 0.2 % completed, 0.006 minutes elapsed, 2.924 minutes remaining
# 0.4 % completed, 0.012 minutes elapsed, 2.757 minutes remaining
# 0.6 % completed, 0.017 minutes elapsed, 2.705 minutes remaining
# 0.8 % completed, 0.022 minutes elapsed, 2.672 minutes remaining
# 1.0 % completed, 0.027 minutes elapsed, 2.637 minutes remaining
# 1.2 % completed, 0.032 minutes elapsed, 2.611 minutes remaining
# 1.4 % completed, 0.037 minutes elapsed, 2.599 minutes remaining
# 1.6 % completed, 0.043 minutes elapsed, 2.583 minutes remaining
# 1.8 % completed, 0.048 minutes elapsed, 2.569 minutes remaining
# 2.0 % completed, 0.053 minutes elapsed, 2.562 minutes remaining
# 2.2 % completed, 0.058 minutes elapsed, 2.55 minutes remaining
# 2.4 % completed, 0.063 minutes elapsed, 2.537 minutes remaining
# 2.6 % completed, 0.068 minutes elapsed, 2.528 minutes remaining
# 2.8 % completed, 0.073 minutes elapsed, 2.525 minutes remaining
# 3.0 % completed, 0.078 minutes elapsed, 2.513 minutes remaining
# 3.2 % completed, 0.083 minutes elapsed, 2.507 minutes remaining
# 3.4 % completed, 0.088 minutes elapsed, 2.496 minutes remaining
# 3.6 % completed, 0.093 minutes elapsed, 2.49 minutes remaining
# 3.8 % completed, 0.099 minutes elapsed, 2.485 minutes remaining
# 4.0 % completed, 0.104 minutes elapsed, 2.477 minutes remaining
# 4.2 % completed, 0.109 minutes elapsed, 2.472 minutes remaining
# 4.4 % completed, 0.114 minutes elapsed, 2.464 minutes remaining
# 4.6 % completed, 0.119 minutes elapsed, 2.46 minutes remaining
# 4.8 % completed, 0.124 minutes elapsed, 2.452 minutes remaining
# 5.0 % completed, 0.129 minutes elapsed, 2.445 minutes remaining
# 5.2 % completed, 0.134 minutes elapsed, 2.438 minutes remaining
# 5.4 % completed, 0.139 minutes elapsed, 2.431 minutes remaining
# 5.6 % completed, 0.144 minutes elapsed, 2.424 minutes remaining
# 5.8 % completed, 0.149 minutes elapsed, 2.417 minutes remaining
# 6.0 % completed, 0.154 minutes elapsed, 2.408 minutes remaining
# 6.2 % completed, 0.159 minutes elapsed, 2.403 minutes remaining
# 6.4 % completed, 0.164 minutes elapsed, 2.397 minutes remaining
# 6.6 % completed, 0.17 minutes elapsed, 2.395 minutes remaining
# 6.8 % completed, 0.175 minutes elapsed, 2.391 minutes remaining
# 7.0 % completed, 0.18 minutes elapsed, 2.385 minutes remaining
# 7.2 % completed, 0.185 minutes elapsed, 2.381 minutes remaining
# 7.4 % completed, 0.19 minutes elapsed, 2.376 minutes remaining
# 7.6 % completed, 0.196 minutes elapsed, 2.371 minutes remaining
# 7.8 % completed, 0.201 minutes elapsed, 2.367 minutes remaining
# 8.0 % completed, 0.206 minutes elapsed, 2.363 minutes remaining
# 8.2 % completed, 0.211 minutes elapsed, 2.358 minutes remaining
# 8.4 % completed, 0.216 minutes elapsed, 2.353 minutes remaining
# 8.6 % completed, 0.222 minutes elapsed, 2.349 minutes remaining
# 8.8 % completed, 0.227 minutes elapsed, 2.344 minutes remaining
# 9.0 % completed, 0.232 minutes elapsed, 2.338 minutes remaining
# 9.2 % completed, 0.237 minutes elapsed, 2.332 minutes remaining
# 9.4 % completed, 0.242 minutes elapsed, 2.328 minutes remaining
# 9.6 % completed, 0.247 minutes elapsed, 2.323 minutes remaining
# 9.8 % completed, 0.252 minutes elapsed, 2.318 minutes remaining
# 10.0 % completed, 0.258 minutes elapsed, 2.313 minutes remaining
# 10.2 % completed, 0.263 minutes elapsed, 2.308 minutes remaining
# 10.4 % completed, 0.268 minutes elapsed, 2.304 minutes remaining
# 10.6 % completed, 0.273 minutes elapsed, 2.298 minutes remaining
# 10.8 % completed, 0.278 minutes elapsed, 2.293 minutes remaining
# 11.0 % completed, 0.283 minutes elapsed, 2.287 minutes remaining
# 11.2 % completed, 0.288 minutes elapsed, 2.281 minutes remaining
# 11.4 % completed, 0.293 minutes elapsed, 2.276 minutes remaining
# 11.6 % completed, 0.298 minutes elapsed, 2.271 minutes remaining
# 11.8 % completed, 0.303 minutes elapsed, 2.265 minutes remaining
# 12.0 % completed, 0.309 minutes elapsed, 2.26 minutes remaining
# 12.2 % completed, 0.314 minutes elapsed, 2.256 minutes remaining
# 12.4 % completed, 0.319 minutes elapsed, 2.251 minutes remaining
# 12.6 % completed, 0.324 minutes elapsed, 2.245 minutes remaining
# 12.8 % completed, 0.329 minutes elapsed, 2.241 minutes remaining
# 13.0 % completed, 0.335 minutes elapsed, 2.236 minutes remaining
# 13.2 % completed, 0.34 minutes elapsed, 2.23 minutes remaining
# 13.4 % completed, 0.345 minutes elapsed, 2.225 minutes remaining
# 13.6 % completed, 0.35 minutes elapsed, 2.219 minutes remaining
# 13.8 % completed, 0.355 minutes elapsed, 2.214 minutes remaining
# 14.0 % completed, 0.36 minutes elapsed, 2.208 minutes remaining
# 14.2 % completed, 0.365 minutes elapsed, 2.203 minutes remaining
# 14.4 % completed, 0.37 minutes elapsed, 2.197 minutes remaining
# 14.6 % completed, 0.375 minutes elapsed, 2.192 minutes remaining
# 14.8 % completed, 0.38 minutes elapsed, 2.187 minutes remaining
# 15.0 % completed, 0.386 minutes elapsed, 2.183 minutes remaining
# 15.2 % completed, 0.391 minutes elapsed, 2.177 minutes remaining
# 15.4 % completed, 0.396 minutes elapsed, 2.172 minutes remaining
# 15.6 % completed, 0.401 minutes elapsed, 2.167 minutes remaining
# 15.8 % completed, 0.406 minutes elapsed, 2.162 minutes remaining
# 16.0 % completed, 0.411 minutes elapsed, 2.156 minutes remaining
# 16.2 % completed, 0.416 minutes elapsed, 2.151 minutes remaining
# 16.4 % completed, 0.421 minutes elapsed, 2.146 minutes remaining
# 16.6 % completed, 0.427 minutes elapsed, 2.141 minutes remaining
# 16.8 % completed, 0.432 minutes elapsed, 2.136 minutes remaining
# 17.0 % completed, 0.437 minutes elapsed, 2.13 minutes remaining
# 17.2 % completed, 0.442 minutes elapsed, 2.125 minutes remaining
# 17.4 % completed, 0.447 minutes elapsed, 2.12 minutes remaining
# 17.6 % completed, 0.452 minutes elapsed, 2.115 minutes remaining
# 17.8 % completed, 0.457 minutes elapsed, 2.109 minutes remaining
# 18.0 % completed, 0.463 minutes elapsed, 2.105 minutes remaining
# 18.2 % completed, 0.468 minutes elapsed, 2.099 minutes remaining
# 18.4 % completed, 0.473 minutes elapsed, 2.094 minutes remaining
# 18.6 % completed, 0.478 minutes elapsed, 2.089 minutes remaining
# 18.8 % completed, 0.483 minutes elapsed, 2.083 minutes remaining
# 19.0 % completed, 0.488 minutes elapsed, 2.078 minutes remaining
# 19.2 % completed, 0.493 minutes elapsed, 2.073 minutes remaining
# 19.4 % completed, 0.498 minutes elapsed, 2.067 minutes remaining
# 19.6 % completed, 0.503 minutes elapsed, 2.061 minutes remaining
# 19.8 % completed, 0.508 minutes elapsed, 2.056 minutes remaining
# 20.0 % completed, 0.513 minutes elapsed, 2.05 minutes remaining
# 20.2 % completed, 0.518 minutes elapsed, 2.045 minutes remaining
# 20.4 % completed, 0.523 minutes elapsed, 2.04 minutes remaining
# 20.6 % completed, 0.528 minutes elapsed, 2.035 minutes remaining
# 20.8 % completed, 0.534 minutes elapsed, 2.03 minutes remaining
# 21.0 % completed, 0.539 minutes elapsed, 2.024 minutes remaining
# 21.2 % completed, 0.544 minutes elapsed, 2.019 minutes remaining
# 21.4 % completed, 0.549 minutes elapsed, 2.013 minutes remaining
# 21.6 % completed, 0.554 minutes elapsed, 2.008 minutes remaining
# 21.8 % completed, 0.559 minutes elapsed, 2.002 minutes remaining
# 22.0 % completed, 0.564 minutes elapsed, 1.997 minutes remaining
# 22.2 % completed, 0.569 minutes elapsed, 1.991 minutes remaining
# 22.4 % completed, 0.574 minutes elapsed, 1.986 minutes remaining
# 22.6 % completed, 0.579 minutes elapsed, 1.98 minutes remaining
# 22.8 % completed, 0.584 minutes elapsed, 1.975 minutes remaining
# 23.0 % completed, 0.589 minutes elapsed, 1.97 minutes remaining
# 23.2 % completed, 0.594 minutes elapsed, 1.965 minutes remaining
# 23.4 % completed, 0.599 minutes elapsed, 1.96 minutes remaining
# 23.6 % completed, 0.604 minutes elapsed, 1.955 minutes remaining
# 23.8 % completed, 0.609 minutes elapsed, 1.95 minutes remaining
# 24.0 % completed, 0.614 minutes elapsed, 1.944 minutes remaining
# 24.2 % completed, 0.62 minutes elapsed, 1.939 minutes remaining
# 24.4 % completed, 0.625 minutes elapsed, 1.934 minutes remaining
# 24.6 % completed, 0.63 minutes elapsed, 1.928 minutes remaining
# 24.8 % completed, 0.635 minutes elapsed, 1.923 minutes remaining
# 25.0 % completed, 0.64 minutes elapsed, 1.918 minutes remaining
# 25.2 % completed, 0.645 minutes elapsed, 1.913 minutes remaining
# 25.4 % completed, 0.65 minutes elapsed, 1.908 minutes remaining
# 25.6 % completed, 0.655 minutes elapsed, 1.902 minutes remaining
# 25.8 % completed, 0.66 minutes elapsed, 1.897 minutes remaining
# 26.0 % completed, 0.665 minutes elapsed, 1.892 minutes remaining
# 26.2 % completed, 0.67 minutes elapsed, 1.887 minutes remaining
# 26.4 % completed, 0.675 minutes elapsed, 1.881 minutes remaining
# 26.6 % completed, 0.68 minutes elapsed, 1.876 minutes remaining
# 26.8 % completed, 0.685 minutes elapsed, 1.87 minutes remaining
# 27.0 % completed, 0.69 minutes elapsed, 1.865 minutes remaining
# 27.2 % completed, 0.695 minutes elapsed, 1.86 minutes remaining
# 27.4 % completed, 0.7 minutes elapsed, 1.855 minutes remaining
# 27.6 % completed, 0.705 minutes elapsed, 1.849 minutes remaining
# 27.8 % completed, 0.71 minutes elapsed, 1.844 minutes remaining
# 28.0 % completed, 0.716 minutes elapsed, 1.839 minutes remaining
# 28.2 % completed, 0.721 minutes elapsed, 1.833 minutes remaining
# 28.4 % completed, 0.726 minutes elapsed, 1.828 minutes remaining
# 28.6 % completed, 0.731 minutes elapsed, 1.823 minutes remaining
# 28.8 % completed, 0.736 minutes elapsed, 1.818 minutes remaining
# 29.0 % completed, 0.741 minutes elapsed, 1.812 minutes remaining
# 29.2 % completed, 0.746 minutes elapsed, 1.808 minutes remaining
# 29.4 % completed, 0.751 minutes elapsed, 1.802 minutes remaining
# 29.6 % completed, 0.756 minutes elapsed, 1.797 minutes remaining
# 29.8 % completed, 0.761 minutes elapsed, 1.792 minutes remaining
# 30.0 % completed, 0.766 minutes elapsed, 1.786 minutes remaining
# 30.2 % completed, 0.771 minutes elapsed, 1.781 minutes remaining
# 30.4 % completed, 0.776 minutes elapsed, 1.776 minutes remaining
# 30.6 % completed, 0.781 minutes elapsed, 1.771 minutes remaining
# 30.8 % completed, 0.786 minutes elapsed, 1.766 minutes remaining
# 31.0 % completed, 0.791 minutes elapsed, 1.76 minutes remaining
# 31.2 % completed, 0.796 minutes elapsed, 1.755 minutes remaining
# 31.4 % completed, 0.801 minutes elapsed, 1.75 minutes remaining
# 31.6 % completed, 0.807 minutes elapsed, 1.745 minutes remaining
# 31.8 % completed, 0.812 minutes elapsed, 1.739 minutes remaining
# 32.0 % completed, 0.817 minutes elapsed, 1.734 minutes remaining
# 32.2 % completed, 0.822 minutes elapsed, 1.729 minutes remaining
# 32.4 % completed, 0.827 minutes elapsed, 1.724 minutes remaining
# 32.6 % completed, 0.832 minutes elapsed, 1.719 minutes remaining
# 32.8 % completed, 0.837 minutes elapsed, 1.714 minutes remaining
# 33.0 % completed, 0.842 minutes elapsed, 1.708 minutes remaining
# 33.2 % completed, 0.847 minutes elapsed, 1.703 minutes remaining
# 33.4 % completed, 0.852 minutes elapsed, 1.698 minutes remaining
# 33.6 % completed, 0.857 minutes elapsed, 1.693 minutes remaining
# 33.8 % completed, 0.862 minutes elapsed, 1.688 minutes remaining
# 34.0 % completed, 0.867 minutes elapsed, 1.682 minutes remaining
# 34.2 % completed, 0.872 minutes elapsed, 1.677 minutes remaining
# 34.4 % completed, 0.878 minutes elapsed, 1.672 minutes remaining
# 34.6 % completed, 0.883 minutes elapsed, 1.667 minutes remaining
# 34.8 % completed, 0.888 minutes elapsed, 1.662 minutes remaining
# 35.0 % completed, 0.893 minutes elapsed, 1.657 minutes remaining
# 35.2 % completed, 0.898 minutes elapsed, 1.652 minutes remaining
# 35.4 % completed, 0.903 minutes elapsed, 1.647 minutes remaining
# 35.6 % completed, 0.908 minutes elapsed, 1.642 minutes remaining
# 35.8 % completed, 0.913 minutes elapsed, 1.636 minutes remaining
# 36.0 % completed, 0.918 minutes elapsed, 1.631 minutes remaining
# 36.2 % completed, 0.923 minutes elapsed, 1.626 minutes remaining
# 36.4 % completed, 0.928 minutes elapsed, 1.621 minutes remaining
# 36.6 % completed, 0.933 minutes elapsed, 1.616 minutes remaining
# 36.8 % completed, 0.938 minutes elapsed, 1.611 minutes remaining
# 37.0 % completed, 0.944 minutes elapsed, 1.606 minutes remaining
# 37.2 % completed, 0.949 minutes elapsed, 1.601 minutes remaining
# 37.4 % completed, 0.954 minutes elapsed, 1.596 minutes remaining
# 37.6 % completed, 0.959 minutes elapsed, 1.59 minutes remaining
# 37.8 % completed, 0.964 minutes elapsed, 1.585 minutes remaining
# 38.0 % completed, 0.969 minutes elapsed, 1.58 minutes remaining
# 38.2 % completed, 0.974 minutes elapsed, 1.575 minutes remaining
# 38.4 % completed, 0.979 minutes elapsed, 1.57 minutes remaining
# 38.6 % completed, 0.984 minutes elapsed, 1.565 minutes remaining
# 38.8 % completed, 0.989 minutes elapsed, 1.559 minutes remaining
# 39.0 % completed, 0.994 minutes elapsed, 1.554 minutes remaining
# 39.2 % completed, 0.999 minutes elapsed, 1.549 minutes remaining
# 39.4 % completed, 1.004 minutes elapsed, 1.544 minutes remaining
# 39.6 % completed, 1.01 minutes elapsed, 1.539 minutes remaining
# 39.8 % completed, 1.015 minutes elapsed, 1.534 minutes remaining
# 40.0 % completed, 1.02 minutes elapsed, 1.529 minutes remaining
# 40.2 % completed, 1.025 minutes elapsed, 1.524 minutes remaining
# 40.4 % completed, 1.03 minutes elapsed, 1.519 minutes remaining
# 40.6 % completed, 1.035 minutes elapsed, 1.513 minutes remaining
# 40.8 % completed, 1.04 minutes elapsed, 1.508 minutes remaining
# 41.0 % completed, 1.045 minutes elapsed, 1.503 minutes remaining
# 41.2 % completed, 1.05 minutes elapsed, 1.498 minutes remaining
# 41.4 % completed, 1.055 minutes elapsed, 1.493 minutes remaining
# 41.6 % completed, 1.06 minutes elapsed, 1.488 minutes remaining
# 41.8 % completed, 1.065 minutes elapsed, 1.483 minutes remaining
# 42.0 % completed, 1.07 minutes elapsed, 1.478 minutes remaining
# 42.2 % completed, 1.076 minutes elapsed, 1.473 minutes remaining
# 42.4 % completed, 1.081 minutes elapsed, 1.467 minutes remaining
# 42.6 % completed, 1.086 minutes elapsed, 1.462 minutes remaining
# 42.8 % completed, 1.091 minutes elapsed, 1.457 minutes remaining
# 43.0 % completed, 1.096 minutes elapsed, 1.452 minutes remaining
# 43.2 % completed, 1.101 minutes elapsed, 1.447 minutes remaining
# 43.4 % completed, 1.106 minutes elapsed, 1.442 minutes remaining
# 43.6 % completed, 1.111 minutes elapsed, 1.437 minutes remaining
# 43.8 % completed, 1.117 minutes elapsed, 1.432 minutes remaining
# 44.0 % completed, 1.122 minutes elapsed, 1.427 minutes remaining
# 44.2 % completed, 1.127 minutes elapsed, 1.422 minutes remaining
# 44.4 % completed, 1.132 minutes elapsed, 1.417 minutes remaining
# 44.6 % completed, 1.137 minutes elapsed, 1.412 minutes remaining
# 44.8 % completed, 1.145 minutes elapsed, 1.41 minutes remaining
# 45.0 % completed, 1.15 minutes elapsed, 1.405 minutes remaining
# 45.2 % completed, 1.155 minutes elapsed, 1.4 minutes remaining
# 45.4 % completed, 1.16 minutes elapsed, 1.394 minutes remaining
# 45.6 % completed, 1.165 minutes elapsed, 1.389 minutes remaining
# 45.8 % completed, 1.17 minutes elapsed, 1.384 minutes remaining
# 46.0 % completed, 1.175 minutes elapsed, 1.379 minutes remaining
# 46.2 % completed, 1.18 minutes elapsed, 1.374 minutes remaining
# 46.4 % completed, 1.185 minutes elapsed, 1.369 minutes remaining
# 46.6 % completed, 1.191 minutes elapsed, 1.364 minutes remaining
# 46.8 % completed, 1.196 minutes elapsed, 1.359 minutes remaining
# 47.0 % completed, 1.201 minutes elapsed, 1.353 minutes remaining
# 47.2 % completed, 1.206 minutes elapsed, 1.348 minutes remaining
# 47.4 % completed, 1.211 minutes elapsed, 1.343 minutes remaining
# 47.6 % completed, 1.216 minutes elapsed, 1.338 minutes remaining
# 47.8 % completed, 1.221 minutes elapsed, 1.333 minutes remaining
# 48.0 % completed, 1.226 minutes elapsed, 1.328 minutes remaining
# 48.2 % completed, 1.231 minutes elapsed, 1.323 minutes remaining
# 48.4 % completed, 1.237 minutes elapsed, 1.318 minutes remaining
# 48.6 % completed, 1.242 minutes elapsed, 1.313 minutes remaining
# 48.8 % completed, 1.247 minutes elapsed, 1.308 minutes remaining
# 49.0 % completed, 1.252 minutes elapsed, 1.303 minutes remaining
# 49.2 % completed, 1.257 minutes elapsed, 1.298 minutes remaining
# 49.4 % completed, 1.262 minutes elapsed, 1.293 minutes remaining
# 49.6 % completed, 1.268 minutes elapsed, 1.287 minutes remaining
# 49.8 % completed, 1.273 minutes elapsed, 1.282 minutes remaining
# 50.0 % completed, 1.278 minutes elapsed, 1.277 minutes remaining
# 50.2 % completed, 1.283 minutes elapsed, 1.272 minutes remaining
# 50.4 % completed, 1.288 minutes elapsed, 1.267 minutes remaining
# 50.6 % completed, 1.293 minutes elapsed, 1.262 minutes remaining
# 50.8 % completed, 1.298 minutes elapsed, 1.257 minutes remaining
# 51.0 % completed, 1.303 minutes elapsed, 1.252 minutes remaining
# 51.2 % completed, 1.308 minutes elapsed, 1.247 minutes remaining
# 51.4 % completed, 1.314 minutes elapsed, 1.242 minutes remaining
# 51.6 % completed, 1.319 minutes elapsed, 1.236 minutes remaining
# 51.8 % completed, 1.324 minutes elapsed, 1.231 minutes remaining
# 52.0 % completed, 1.329 minutes elapsed, 1.226 minutes remaining
# 52.2 % completed, 1.334 minutes elapsed, 1.221 minutes remaining
# 52.4 % completed, 1.339 minutes elapsed, 1.216 minutes remaining
# 52.6 % completed, 1.344 minutes elapsed, 1.211 minutes remaining
# 52.8 % completed, 1.35 minutes elapsed, 1.206 minutes remaining
# 53.0 % completed, 1.355 minutes elapsed, 1.201 minutes remaining
# 53.2 % completed, 1.36 minutes elapsed, 1.196 minutes remaining
# 53.4 % completed, 1.365 minutes elapsed, 1.191 minutes remaining
# 53.6 % completed, 1.37 minutes elapsed, 1.185 minutes remaining
# 53.8 % completed, 1.375 minutes elapsed, 1.18 minutes remaining
# 54.0 % completed, 1.38 minutes elapsed, 1.175 minutes remaining
# 54.2 % completed, 1.385 minutes elapsed, 1.17 minutes remaining
# 54.4 % completed, 1.39 minutes elapsed, 1.165 minutes remaining
# 54.6 % completed, 1.395 minutes elapsed, 1.16 minutes remaining
# 54.8 % completed, 1.4 minutes elapsed, 1.155 minutes remaining
# 55.0 % completed, 1.406 minutes elapsed, 1.15 minutes remaining
# 55.2 % completed, 1.411 minutes elapsed, 1.145 minutes remaining
# 55.4 % completed, 1.416 minutes elapsed, 1.139 minutes remaining
# 55.6 % completed, 1.421 minutes elapsed, 1.134 minutes remaining
# 55.8 % completed, 1.426 minutes elapsed, 1.129 minutes remaining
# 56.0 % completed, 1.431 minutes elapsed, 1.124 minutes remaining
# 56.2 % completed, 1.436 minutes elapsed, 1.119 minutes remaining
# 56.4 % completed, 1.441 minutes elapsed, 1.114 minutes remaining
# 56.6 % completed, 1.447 minutes elapsed, 1.109 minutes remaining
# 56.8 % completed, 1.452 minutes elapsed, 1.104 minutes remaining
# 57.0 % completed, 1.457 minutes elapsed, 1.099 minutes remaining
# 57.2 % completed, 1.462 minutes elapsed, 1.093 minutes remaining
# 57.4 % completed, 1.467 minutes elapsed, 1.088 minutes remaining
# 57.6 % completed, 1.472 minutes elapsed, 1.083 minutes remaining
# 57.8 % completed, 1.477 minutes elapsed, 1.078 minutes remaining
# 58.0 % completed, 1.482 minutes elapsed, 1.073 minutes remaining
# 58.2 % completed, 1.488 minutes elapsed, 1.068 minutes remaining
# 58.4 % completed, 1.493 minutes elapsed, 1.063 minutes remaining
# 58.6 % completed, 1.498 minutes elapsed, 1.058 minutes remaining
# 58.8 % completed, 1.503 minutes elapsed, 1.053 minutes remaining
# 59.0 % completed, 1.508 minutes elapsed, 1.048 minutes remaining
# 59.2 % completed, 1.513 minutes elapsed, 1.042 minutes remaining
# 59.4 % completed, 1.518 minutes elapsed, 1.037 minutes remaining
# 59.6 % completed, 1.523 minutes elapsed, 1.032 minutes remaining
# 59.8 % completed, 1.528 minutes elapsed, 1.027 minutes remaining
# 60.0 % completed, 1.533 minutes elapsed, 1.022 minutes remaining
# 60.2 % completed, 1.539 minutes elapsed, 1.017 minutes remaining
# 60.4 % completed, 1.544 minutes elapsed, 1.012 minutes remaining
# 60.6 % completed, 1.549 minutes elapsed, 1.007 minutes remaining
# 60.8 % completed, 1.554 minutes elapsed, 1.001 minutes remaining
# 61.0 % completed, 1.559 minutes elapsed, 0.996 minutes remaining
# 61.2 % completed, 1.564 minutes elapsed, 0.991 minutes remaining
# 61.4 % completed, 1.569 minutes elapsed, 0.986 minutes remaining
# 61.6 % completed, 1.574 minutes elapsed, 0.981 minutes remaining
# 61.8 % completed, 1.579 minutes elapsed, 0.976 minutes remaining
# 62.0 % completed, 1.584 minutes elapsed, 0.971 minutes remaining
# 62.2 % completed, 1.59 minutes elapsed, 0.966 minutes remaining
# 62.4 % completed, 1.595 minutes elapsed, 0.961 minutes remaining
# 62.6 % completed, 1.6 minutes elapsed, 0.955 minutes remaining
# 62.8 % completed, 1.605 minutes elapsed, 0.95 minutes remaining
# 63.0 % completed, 1.61 minutes elapsed, 0.945 minutes remaining
# 63.2 % completed, 1.615 minutes elapsed, 0.94 minutes remaining
# 63.4 % completed, 1.62 minutes elapsed, 0.935 minutes remaining
# 63.6 % completed, 1.625 minutes elapsed, 0.93 minutes remaining
# 63.8 % completed, 1.63 minutes elapsed, 0.925 minutes remaining
# 64.0 % completed, 1.636 minutes elapsed, 0.92 minutes remaining
# 64.2 % completed, 1.641 minutes elapsed, 0.915 minutes remaining
# 64.4 % completed, 1.646 minutes elapsed, 0.91 minutes remaining
# 64.6 % completed, 1.651 minutes elapsed, 0.904 minutes remaining
# 64.8 % completed, 1.656 minutes elapsed, 0.899 minutes remaining
# 65.0 % completed, 1.661 minutes elapsed, 0.894 minutes remaining
# 65.2 % completed, 1.666 minutes elapsed, 0.889 minutes remaining
# 65.4 % completed, 1.671 minutes elapsed, 0.884 minutes remaining
# 65.6 % completed, 1.677 minutes elapsed, 0.879 minutes remaining
# 65.8 % completed, 1.682 minutes elapsed, 0.874 minutes remaining
# 66.0 % completed, 1.687 minutes elapsed, 0.869 minutes remaining
# 66.2 % completed, 1.692 minutes elapsed, 0.864 minutes remaining
# 66.4 % completed, 1.697 minutes elapsed, 0.858 minutes remaining
# 66.6 % completed, 1.702 minutes elapsed, 0.853 minutes remaining
# 66.8 % completed, 1.707 minutes elapsed, 0.848 minutes remaining
# 67.0 % completed, 1.713 minutes elapsed, 0.843 minutes remaining
# 67.2 % completed, 1.718 minutes elapsed, 0.838 minutes remaining
# 67.4 % completed, 1.723 minutes elapsed, 0.833 minutes remaining
# 67.6 % completed, 1.728 minutes elapsed, 0.828 minutes remaining
# 67.8 % completed, 1.733 minutes elapsed, 0.823 minutes remaining
# 68.0 % completed, 1.738 minutes elapsed, 0.818 minutes remaining
# 68.2 % completed, 1.743 minutes elapsed, 0.813 minutes remaining
# 68.4 % completed, 1.748 minutes elapsed, 0.807 minutes remaining
# 68.6 % completed, 1.754 minutes elapsed, 0.802 minutes remaining
# 68.8 % completed, 1.759 minutes elapsed, 0.797 minutes remaining
# 69.0 % completed, 1.764 minutes elapsed, 0.792 minutes remaining
# 69.2 % completed, 1.769 minutes elapsed, 0.787 minutes remaining
# 69.4 % completed, 1.774 minutes elapsed, 0.782 minutes remaining
# 69.6 % completed, 1.779 minutes elapsed, 0.777 minutes remaining
# 69.8 % completed, 1.784 minutes elapsed, 0.772 minutes remaining
# 70.0 % completed, 1.789 minutes elapsed, 0.767 minutes remaining
# 70.2 % completed, 1.794 minutes elapsed, 0.762 minutes remaining
# 70.4 % completed, 1.8 minutes elapsed, 0.756 minutes remaining
# 70.6 % completed, 1.805 minutes elapsed, 0.751 minutes remaining
# 70.8 % completed, 1.81 minutes elapsed, 0.746 minutes remaining
# 71.0 % completed, 1.815 minutes elapsed, 0.741 minutes remaining
# 71.2 % completed, 1.82 minutes elapsed, 0.736 minutes remaining
# 71.4 % completed, 1.825 minutes elapsed, 0.731 minutes remaining
# 71.6 % completed, 1.83 minutes elapsed, 0.726 minutes remaining
# 71.8 % completed, 1.836 minutes elapsed, 0.721 minutes remaining
# 72.0 % completed, 1.841 minutes elapsed, 0.716 minutes remaining
# 72.2 % completed, 1.846 minutes elapsed, 0.711 minutes remaining
# 72.4 % completed, 1.851 minutes elapsed, 0.705 minutes remaining
# 72.6 % completed, 1.856 minutes elapsed, 0.7 minutes remaining
# 72.8 % completed, 1.861 minutes elapsed, 0.695 minutes remaining
# 73.0 % completed, 1.866 minutes elapsed, 0.69 minutes remaining
# 73.2 % completed, 1.871 minutes elapsed, 0.685 minutes remaining
# 73.4 % completed, 1.877 minutes elapsed, 0.68 minutes remaining
# 73.6 % completed, 1.882 minutes elapsed, 0.675 minutes remaining
# 73.8 % completed, 1.887 minutes elapsed, 0.67 minutes remaining
# 74.0 % completed, 1.892 minutes elapsed, 0.664 minutes remaining
# 74.2 % completed, 1.897 minutes elapsed, 0.659 minutes remaining
# 74.4 % completed, 1.902 minutes elapsed, 0.654 minutes remaining
# 74.6 % completed, 1.907 minutes elapsed, 0.649 minutes remaining
# 74.8 % completed, 1.912 minutes elapsed, 0.644 minutes remaining
# 75.0 % completed, 1.917 minutes elapsed, 0.639 minutes remaining
# 75.2 % completed, 1.923 minutes elapsed, 0.634 minutes remaining
# 75.4 % completed, 1.928 minutes elapsed, 0.629 minutes remaining
# 75.6 % completed, 1.933 minutes elapsed, 0.624 minutes remaining
# 75.8 % completed, 1.938 minutes elapsed, 0.618 minutes remaining
# 76.0 % completed, 1.943 minutes elapsed, 0.613 minutes remaining
# 76.2 % completed, 1.948 minutes elapsed, 0.608 minutes remaining
# 76.4 % completed, 1.953 minutes elapsed, 0.603 minutes remaining
# 76.6 % completed, 1.958 minutes elapsed, 0.598 minutes remaining
# 76.8 % completed, 1.964 minutes elapsed, 0.593 minutes remaining
# 77.0 % completed, 1.969 minutes elapsed, 0.588 minutes remaining
# 77.2 % completed, 1.974 minutes elapsed, 0.583 minutes remaining
# 77.4 % completed, 1.979 minutes elapsed, 0.578 minutes remaining
# 77.6 % completed, 1.984 minutes elapsed, 0.573 minutes remaining
# 77.8 % completed, 1.989 minutes elapsed, 0.567 minutes remaining
# 78.0 % completed, 1.994 minutes elapsed, 0.562 minutes remaining
# 78.2 % completed, 2.0 minutes elapsed, 0.557 minutes remaining
# 78.4 % completed, 2.005 minutes elapsed, 0.552 minutes remaining
# 78.6 % completed, 2.01 minutes elapsed, 0.547 minutes remaining
# 78.8 % completed, 2.015 minutes elapsed, 0.542 minutes remaining
# 79.0 % completed, 2.02 minutes elapsed, 0.537 minutes remaining
# 79.2 % completed, 2.025 minutes elapsed, 0.532 minutes remaining
# 79.4 % completed, 2.03 minutes elapsed, 0.527 minutes remaining
# 79.6 % completed, 2.035 minutes elapsed, 0.521 minutes remaining
# 79.8 % completed, 2.04 minutes elapsed, 0.516 minutes remaining
# 80.0 % completed, 2.046 minutes elapsed, 0.511 minutes remaining
# 80.2 % completed, 2.051 minutes elapsed, 0.506 minutes remaining
# 80.4 % completed, 2.056 minutes elapsed, 0.501 minutes remaining
# 80.6 % completed, 2.061 minutes elapsed, 0.496 minutes remaining
# 80.8 % completed, 2.066 minutes elapsed, 0.491 minutes remaining
# 81.0 % completed, 2.071 minutes elapsed, 0.486 minutes remaining
# 81.2 % completed, 2.076 minutes elapsed, 0.481 minutes remaining
# 81.4 % completed, 2.082 minutes elapsed, 0.476 minutes remaining
# 81.6 % completed, 2.087 minutes elapsed, 0.47 minutes remaining
# 81.8 % completed, 2.092 minutes elapsed, 0.465 minutes remaining
# 82.0 % completed, 2.097 minutes elapsed, 0.46 minutes remaining
# 82.2 % completed, 2.102 minutes elapsed, 0.455 minutes remaining
# 82.4 % completed, 2.107 minutes elapsed, 0.45 minutes remaining
# 82.6 % completed, 2.112 minutes elapsed, 0.445 minutes remaining
# 82.8 % completed, 2.118 minutes elapsed, 0.44 minutes remaining
# 83.0 % completed, 2.123 minutes elapsed, 0.435 minutes remaining
# 83.2 % completed, 2.128 minutes elapsed, 0.43 minutes remaining
# 83.4 % completed, 2.133 minutes elapsed, 0.424 minutes remaining
# 83.6 % completed, 2.138 minutes elapsed, 0.419 minutes remaining
# 83.8 % completed, 2.143 minutes elapsed, 0.414 minutes remaining
# 84.0 % completed, 2.148 minutes elapsed, 0.409 minutes remaining
# 84.2 % completed, 2.154 minutes elapsed, 0.404 minutes remaining
# 84.4 % completed, 2.159 minutes elapsed, 0.399 minutes remaining
# 84.6 % completed, 2.164 minutes elapsed, 0.394 minutes remaining
# 84.8 % completed, 2.169 minutes elapsed, 0.389 minutes remaining
# 85.0 % completed, 2.174 minutes elapsed, 0.384 minutes remaining
# 85.2 % completed, 2.179 minutes elapsed, 0.378 minutes remaining
# 85.4 % completed, 2.184 minutes elapsed, 0.373 minutes remaining
# 85.6 % completed, 2.19 minutes elapsed, 0.368 minutes remaining
# 85.8 % completed, 2.195 minutes elapsed, 0.363 minutes remaining
# 86.0 % completed, 2.2 minutes elapsed, 0.358 minutes remaining
# 86.2 % completed, 2.205 minutes elapsed, 0.353 minutes remaining
# 86.4 % completed, 2.21 minutes elapsed, 0.348 minutes remaining
# 86.6 % completed, 2.215 minutes elapsed, 0.343 minutes remaining
# 86.8 % completed, 2.22 minutes elapsed, 0.338 minutes remaining
# 87.0 % completed, 2.225 minutes elapsed, 0.332 minutes remaining
# 87.2 % completed, 2.231 minutes elapsed, 0.327 minutes remaining
# 87.4 % completed, 2.236 minutes elapsed, 0.322 minutes remaining
# 87.6 % completed, 2.241 minutes elapsed, 0.317 minutes remaining
# 87.8 % completed, 2.246 minutes elapsed, 0.312 minutes remaining
# 88.0 % completed, 2.251 minutes elapsed, 0.307 minutes remaining
# 88.2 % completed, 2.256 minutes elapsed, 0.302 minutes remaining
# 88.4 % completed, 2.262 minutes elapsed, 0.297 minutes remaining
# 88.6 % completed, 2.267 minutes elapsed, 0.292 minutes remaining
# 88.8 % completed, 2.272 minutes elapsed, 0.286 minutes remaining
# 89.0 % completed, 2.277 minutes elapsed, 0.281 minutes remaining
# 89.2 % completed, 2.282 minutes elapsed, 0.276 minutes remaining
# 89.4 % completed, 2.287 minutes elapsed, 0.271 minutes remaining
# 89.6 % completed, 2.293 minutes elapsed, 0.266 minutes remaining
# 89.8 % completed, 2.298 minutes elapsed, 0.261 minutes remaining
# 90.0 % completed, 2.303 minutes elapsed, 0.256 minutes remaining
# 90.2 % completed, 2.308 minutes elapsed, 0.251 minutes remaining
# 90.4 % completed, 2.313 minutes elapsed, 0.246 minutes remaining
# 90.6 % completed, 2.319 minutes elapsed, 0.241 minutes remaining
# 90.8 % completed, 2.324 minutes elapsed, 0.235 minutes remaining
# 91.0 % completed, 2.329 minutes elapsed, 0.23 minutes remaining
# 91.2 % completed, 2.334 minutes elapsed, 0.225 minutes remaining
# 91.4 % completed, 2.339 minutes elapsed, 0.22 minutes remaining
# 91.6 % completed, 2.344 minutes elapsed, 0.215 minutes remaining
# 91.8 % completed, 2.35 minutes elapsed, 0.21 minutes remaining
# 92.0 % completed, 2.355 minutes elapsed, 0.205 minutes remaining
# 92.2 % completed, 2.36 minutes elapsed, 0.2 minutes remaining
# 92.4 % completed, 2.365 minutes elapsed, 0.194 minutes remaining
# 92.6 % completed, 2.37 minutes elapsed, 0.189 minutes remaining
# 92.8 % completed, 2.375 minutes elapsed, 0.184 minutes remaining
# 93.0 % completed, 2.38 minutes elapsed, 0.179 minutes remaining
# 93.2 % completed, 2.386 minutes elapsed, 0.174 minutes remaining
# 93.4 % completed, 2.391 minutes elapsed, 0.169 minutes remaining
# 93.6 % completed, 2.396 minutes elapsed, 0.164 minutes remaining
# 93.8 % completed, 2.401 minutes elapsed, 0.159 minutes remaining
# 94.0 % completed, 2.406 minutes elapsed, 0.154 minutes remaining
# 94.2 % completed, 2.411 minutes elapsed, 0.148 minutes remaining
# 94.4 % completed, 2.416 minutes elapsed, 0.143 minutes remaining
# 94.6 % completed, 2.421 minutes elapsed, 0.138 minutes remaining
# 94.8 % completed, 2.426 minutes elapsed, 0.133 minutes remaining
# 95.0 % completed, 2.432 minutes elapsed, 0.128 minutes remaining
# 95.2 % completed, 2.437 minutes elapsed, 0.123 minutes remaining
# 95.4 % completed, 2.442 minutes elapsed, 0.118 minutes remaining
# 95.6 % completed, 2.448 minutes elapsed, 0.113 minutes remaining
# 95.8 % completed, 2.453 minutes elapsed, 0.108 minutes remaining
# 96.0 % completed, 2.458 minutes elapsed, 0.102 minutes remaining
# 96.2 % completed, 2.463 minutes elapsed, 0.097 minutes remaining
# 96.4 % completed, 2.469 minutes elapsed, 0.092 minutes remaining
# 96.6 % completed, 2.474 minutes elapsed, 0.087 minutes remaining
# 96.8 % completed, 2.479 minutes elapsed, 0.082 minutes remaining
# 97.0 % completed, 2.484 minutes elapsed, 0.077 minutes remaining
# 97.2 % completed, 2.489 minutes elapsed, 0.072 minutes remaining
# 97.4 % completed, 2.494 minutes elapsed, 0.067 minutes remaining
# 97.6 % completed, 2.499 minutes elapsed, 0.061 minutes remaining
# 97.8 % completed, 2.505 minutes elapsed, 0.056 minutes remaining
# 98.0 % completed, 2.51 minutes elapsed, 0.051 minutes remaining
# 98.2 % completed, 2.515 minutes elapsed, 0.046 minutes remaining
# 98.4 % completed, 2.52 minutes elapsed, 0.041 minutes remaining
# 98.6 % completed, 2.525 minutes elapsed, 0.036 minutes remaining
# 98.8 % completed, 2.53 minutes elapsed, 0.031 minutes remaining
# 99.0 % completed, 2.535 minutes elapsed, 0.026 minutes remaining
# 99.2 % completed, 2.541 minutes elapsed, 0.02 minutes remaining
# 99.4 % completed, 2.546 minutes elapsed, 0.015 minutes remaining
# 99.6 % completed, 2.551 minutes elapsed, 0.01 minutes remaining
# 99.8 % completed, 2.556 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %%
print(mix_coeffs_all)
# Out:
# [array([[0.78209866, 0.08343788, 0.13446346],
#        [0.39814814, 0.4774057 , 0.12444615],
#        [0.44189772, 0.38010832, 0.17799396],
#        ...,
#        [0.75196277, 0.1138571 , 0.13418013],
#        [0.49881363, 0.40044736, 0.10073901],
#        [0.5063168 , 0.31114955, 0.18253364]])]

# %%
print(f"Number of items: {len(mix_coeffs_all[0])}")
print(f"Array shape: {mix_coeffs_all[0].shape}")
# Out:
# Number of items: 5000
# Array shape: (5000, 3)

# %% [markdown]
# ### Export csv file of mix_coeffs_all for use in the zircon fertility analysis

# %%
# Converting the mix_coeffs_all to a 2D array so that we can run all 5000 pairs of w1 and w2 through to understand the
# distribution through the bootstraping analyses. 
try:
    # Convert list to NumPy array
    array = np.array(mix_coeffs_all)
    # Flatten the array
    flattened_array = array.reshape(-1, array.shape[-1])
    # Determine column names based on the number of coefficients
    num_coeffs = flattened_array.shape[1]
    if num_coeffs == 2:
        column_names = ['Column1', 'Column2']
    elif num_coeffs == 3:
        column_names = ['Column1', 'Column2', 'Column3']
    else:
        # Fallback for other numbers of coefficients
        column_names = [f'Column{i+1}' for i in range(num_coeffs)]
    # Convert to DataFrame
    df = pd.DataFrame(flattened_array, columns=column_names)
    # Save to CSV in a "Spreadsheets" folder
    folder_path = "Spreadsheets"
    # Change name to current mixture
    filename = "mix_coeffs_all_ct-5_ct-6_ct-3_to_ct-9.csv"
    # Create folder if it doesn't exist
    os.makedirs(folder_path, exist_ok=True)
    # Create full path and save
    full_path = os.path.join(folder_path, filename)
    df.to_csv(full_path, index=False)
    print("Saved")
    
except Exception as e:
    print(f"Not saved: {e}")
    # Optional: Print array shape for debugging
    if 'array' in locals():
        print(f"Array shape: {array.shape}")
    if 'flattened_array' in locals():
        print(f"Flattened array shape: {flattened_array.shape}")
# Out:
# Saved

# %%
# Plot histograms of all coefficients on same plot to visualize the distributions
plt.figure(figsize=(10, 6))

# Define colors for up to 6 coefficients (extend as needed)
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown']

# Get the number of coefficient columns
num_coeffs = len([col for col in df.columns if col.startswith('Column')])

# Plot histogram for each coefficient
for i in range(num_coeffs):
    col_name = f'Column{i+1}'
    color = colors[i % len(colors)]  # Cycle through colors if more coefficients than colors
    label = f'w{i+1}'
    
    plt.hist(df[col_name], bins=50, alpha=0.8, color=color, edgecolor='black', 
             linewidth=0.5, label=label)

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mix Coefficients')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 20, 100, 200] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Saves figure to a folder named 'Figures'
os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_age_distribution.svg')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_objective_function_distributions.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_distribution_comparisons.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_spatial_comparison.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
os.makedirs('Spreadsheets', exist_ok=True)
file_name = 'Spreadsheets/dPy-mix_ct-5_ct-6_ct-3_to_ct-9_results.xlsx'
dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                   obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                   bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                   doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                   mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                   worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
# Out:
# Workbook saved
