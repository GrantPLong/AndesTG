# %% [markdown]
# # DetritalPy Mixing code for the Mataquito River: Every Scenario

# %% [markdown]
# ## detritalPy-mix
# #### Glenn R. Sharman and Sam A. Johnstone
# #### Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty
# #### Version 0.1 (Beta)
# ##### Updated Feb 9, 2024
# ##### Requires detritalPy v1.4.0 or later
# ##### This is a Beta release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.
# ##### If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044)

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import os
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).
#
# Change parent and child list to see mixing results for CT-1 through CT-11

# %%
dataToLoad = ['/Users/Glong1/Desktop/Andes/AndesTG/Mataquito/Zircon/Spreadsheets/CT-1-11_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

""" 
Plug in the two / three parents that you want followed by all the children associated with all the parents. The options below are set up for easy use.
You will choose what parents you want and the associated child. Comment in/out whichever you want
"""
# Child options where parent list is CT-7, CT-1
#parent_list = ['CT-7', 'CT-1']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Child options where parent list is CT-5, CT-6
#parent_list = ['CT-5', 'CT-6']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Parent list options where Child is CT-2
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-2']

# Parent list options where Child is CT-9
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
parent_list = ['CT-2', 'CT-3']
child_list = ['CT-9']

# Three to one mixtures
    # Parent list options where Child is CT-2
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-2']

    # Parent list options where Child is CT-9
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-9']

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 2 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.18517279118094554
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Completed mixing children.
# Time elapsed: 0.038 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-9
# Best-fit vmax : 0.185
# Mixing coefficients
# --- CT-2 : 0.999
# --- CT-3 : 0.001

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 10000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-9 ( 1 of 1 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 6.841 minutes remaining
# 0.1 % completed, 0.006 minutes elapsed, 5.264 minutes remaining
# 0.2 % completed, 0.011 minutes elapsed, 5.067 minutes remaining
# 0.3 % completed, 0.016 minutes elapsed, 5.027 minutes remaining
# 0.4 % completed, 0.021 minutes elapsed, 5.003 minutes remaining
# 0.5 % completed, 0.027 minutes elapsed, 5.194 minutes remaining
# 0.6 % completed, 0.032 minutes elapsed, 5.152 minutes remaining
# 0.7 % completed, 0.037 minutes elapsed, 5.107 minutes remaining
# 0.8 % completed, 0.041 minutes elapsed, 5.08 minutes remaining
# 0.9 % completed, 0.046 minutes elapsed, 5.058 minutes remaining
# 1.0 % completed, 0.051 minutes elapsed, 5.035 minutes remaining
# 1.1 % completed, 0.056 minutes elapsed, 5.014 minutes remaining
# 1.2 % completed, 0.061 minutes elapsed, 5.001 minutes remaining
# 1.3 % completed, 0.066 minutes elapsed, 4.988 minutes remaining
# 1.4 % completed, 0.071 minutes elapsed, 4.972 minutes remaining
# 1.5 % completed, 0.076 minutes elapsed, 4.96 minutes remaining
# 1.6 % completed, 0.081 minutes elapsed, 4.956 minutes remaining
# 1.7 % completed, 0.086 minutes elapsed, 4.947 minutes remaining
# 1.8 % completed, 0.091 minutes elapsed, 4.94 minutes remaining
# 1.9 % completed, 0.096 minutes elapsed, 4.935 minutes remaining
# 2.0 % completed, 0.101 minutes elapsed, 4.928 minutes remaining
# 2.1 % completed, 0.106 minutes elapsed, 4.925 minutes remaining
# 2.2 % completed, 0.111 minutes elapsed, 4.916 minutes remaining
# 2.3 % completed, 0.116 minutes elapsed, 4.909 minutes remaining
# 2.4 % completed, 0.121 minutes elapsed, 4.905 minutes remaining
# 2.5 % completed, 0.126 minutes elapsed, 4.895 minutes remaining
# 2.6 % completed, 0.131 minutes elapsed, 4.889 minutes remaining
# 2.7 % completed, 0.136 minutes elapsed, 4.884 minutes remaining
# 2.8 % completed, 0.141 minutes elapsed, 4.879 minutes remaining
# 2.9 % completed, 0.146 minutes elapsed, 4.872 minutes remaining
# 3.0 % completed, 0.151 minutes elapsed, 4.865 minutes remaining
# 3.1 % completed, 0.156 minutes elapsed, 4.86 minutes remaining
# 3.2 % completed, 0.161 minutes elapsed, 4.856 minutes remaining
# 3.3 % completed, 0.166 minutes elapsed, 4.85 minutes remaining
# 3.4 % completed, 0.171 minutes elapsed, 4.845 minutes remaining
# 3.5 % completed, 0.176 minutes elapsed, 4.837 minutes remaining
# 3.6 % completed, 0.181 minutes elapsed, 4.83 minutes remaining
# 3.7 % completed, 0.186 minutes elapsed, 4.829 minutes remaining
# 3.8 % completed, 0.191 minutes elapsed, 4.823 minutes remaining
# 3.9 % completed, 0.196 minutes elapsed, 4.82 minutes remaining
# 4.0 % completed, 0.201 minutes elapsed, 4.818 minutes remaining
# 4.1 % completed, 0.206 minutes elapsed, 4.812 minutes remaining
# 4.2 % completed, 0.211 minutes elapsed, 4.807 minutes remaining
# 4.3 % completed, 0.216 minutes elapsed, 4.8 minutes remaining
# 4.4 % completed, 0.221 minutes elapsed, 4.793 minutes remaining
# 4.5 % completed, 0.226 minutes elapsed, 4.786 minutes remaining
# 4.6 % completed, 0.231 minutes elapsed, 4.779 minutes remaining
# 4.7 % completed, 0.236 minutes elapsed, 4.772 minutes remaining
# 4.8 % completed, 0.241 minutes elapsed, 4.765 minutes remaining
# 4.9 % completed, 0.246 minutes elapsed, 4.758 minutes remaining
# 5.0 % completed, 0.251 minutes elapsed, 4.752 minutes remaining
# 5.1 % completed, 0.255 minutes elapsed, 4.744 minutes remaining
# 5.2 % completed, 0.26 minutes elapsed, 4.738 minutes remaining
# 5.3 % completed, 0.265 minutes elapsed, 4.731 minutes remaining
# 5.4 % completed, 0.27 minutes elapsed, 4.725 minutes remaining
# 5.5 % completed, 0.275 minutes elapsed, 4.718 minutes remaining
# 5.6 % completed, 0.28 minutes elapsed, 4.713 minutes remaining
# 5.7 % completed, 0.285 minutes elapsed, 4.708 minutes remaining
# 5.8 % completed, 0.29 minutes elapsed, 4.701 minutes remaining
# 5.9 % completed, 0.295 minutes elapsed, 4.695 minutes remaining
# 6.0 % completed, 0.3 minutes elapsed, 4.69 minutes remaining
# 6.1 % completed, 0.305 minutes elapsed, 4.683 minutes remaining
# 6.2 % completed, 0.31 minutes elapsed, 4.677 minutes remaining
# 6.3 % completed, 0.315 minutes elapsed, 4.671 minutes remaining
# 6.4 % completed, 0.319 minutes elapsed, 4.665 minutes remaining
# 6.5 % completed, 0.325 minutes elapsed, 4.661 minutes remaining
# 6.6 % completed, 0.33 minutes elapsed, 4.656 minutes remaining
# 6.7 % completed, 0.335 minutes elapsed, 4.651 minutes remaining
# 6.8 % completed, 0.339 minutes elapsed, 4.645 minutes remaining
# 6.9 % completed, 0.344 minutes elapsed, 4.64 minutes remaining
# 7.0 % completed, 0.349 minutes elapsed, 4.636 minutes remaining
# 7.1 % completed, 0.354 minutes elapsed, 4.63 minutes remaining
# 7.2 % completed, 0.359 minutes elapsed, 4.625 minutes remaining
# 7.3 % completed, 0.364 minutes elapsed, 4.62 minutes remaining
# 7.4 % completed, 0.369 minutes elapsed, 4.616 minutes remaining
# 7.5 % completed, 0.374 minutes elapsed, 4.61 minutes remaining
# 7.6 % completed, 0.379 minutes elapsed, 4.605 minutes remaining
# 7.7 % completed, 0.384 minutes elapsed, 4.6 minutes remaining
# 7.8 % completed, 0.389 minutes elapsed, 4.595 minutes remaining
# 7.9 % completed, 0.394 minutes elapsed, 4.589 minutes remaining
# 8.0 % completed, 0.399 minutes elapsed, 4.583 minutes remaining
# 8.1 % completed, 0.404 minutes elapsed, 4.577 minutes remaining
# 8.2 % completed, 0.409 minutes elapsed, 4.572 minutes remaining
# 8.3 % completed, 0.414 minutes elapsed, 4.567 minutes remaining
# 8.4 % completed, 0.419 minutes elapsed, 4.561 minutes remaining
# 8.5 % completed, 0.424 minutes elapsed, 4.555 minutes remaining
# 8.6 % completed, 0.429 minutes elapsed, 4.55 minutes remaining
# 8.7 % completed, 0.433 minutes elapsed, 4.544 minutes remaining
# 8.8 % completed, 0.438 minutes elapsed, 4.539 minutes remaining
# 8.9 % completed, 0.443 minutes elapsed, 4.534 minutes remaining
# 9.0 % completed, 0.448 minutes elapsed, 4.527 minutes remaining
# 9.1 % completed, 0.453 minutes elapsed, 4.522 minutes remaining
# 9.2 % completed, 0.458 minutes elapsed, 4.517 minutes remaining
# 9.3 % completed, 0.463 minutes elapsed, 4.512 minutes remaining
# 9.4 % completed, 0.468 minutes elapsed, 4.507 minutes remaining
# 9.5 % completed, 0.473 minutes elapsed, 4.502 minutes remaining
# 9.6 % completed, 0.478 minutes elapsed, 4.496 minutes remaining
# 9.7 % completed, 0.483 minutes elapsed, 4.491 minutes remaining
# 9.8 % completed, 0.488 minutes elapsed, 4.485 minutes remaining
# 9.9 % completed, 0.493 minutes elapsed, 4.479 minutes remaining
# 10.0 % completed, 0.497 minutes elapsed, 4.473 minutes remaining
# 10.1 % completed, 0.502 minutes elapsed, 4.468 minutes remaining
# 10.2 % completed, 0.507 minutes elapsed, 4.462 minutes remaining
# 10.3 % completed, 0.512 minutes elapsed, 4.456 minutes remaining
# 10.4 % completed, 0.517 minutes elapsed, 4.451 minutes remaining
# 10.5 % completed, 0.522 minutes elapsed, 4.446 minutes remaining
# 10.6 % completed, 0.527 minutes elapsed, 4.44 minutes remaining
# 10.7 % completed, 0.532 minutes elapsed, 4.435 minutes remaining
# 10.8 % completed, 0.537 minutes elapsed, 4.43 minutes remaining
# 10.9 % completed, 0.542 minutes elapsed, 4.425 minutes remaining
# 11.0 % completed, 0.547 minutes elapsed, 4.42 minutes remaining
# 11.1 % completed, 0.552 minutes elapsed, 4.414 minutes remaining
# 11.2 % completed, 0.557 minutes elapsed, 4.409 minutes remaining
# 11.3 % completed, 0.561 minutes elapsed, 4.403 minutes remaining
# 11.4 % completed, 0.566 minutes elapsed, 4.398 minutes remaining
# 11.5 % completed, 0.571 minutes elapsed, 4.393 minutes remaining
# 11.6 % completed, 0.576 minutes elapsed, 4.388 minutes remaining
# 11.7 % completed, 0.581 minutes elapsed, 4.383 minutes remaining
# 11.8 % completed, 0.586 minutes elapsed, 4.377 minutes remaining
# 11.9 % completed, 0.591 minutes elapsed, 4.371 minutes remaining
# 12.0 % completed, 0.596 minutes elapsed, 4.366 minutes remaining
# 12.1 % completed, 0.601 minutes elapsed, 4.36 minutes remaining
# 12.2 % completed, 0.606 minutes elapsed, 4.355 minutes remaining
# 12.3 % completed, 0.611 minutes elapsed, 4.35 minutes remaining
# 12.4 % completed, 0.615 minutes elapsed, 4.344 minutes remaining
# 12.5 % completed, 0.62 minutes elapsed, 4.338 minutes remaining
# 12.6 % completed, 0.625 minutes elapsed, 4.333 minutes remaining
# 12.7 % completed, 0.63 minutes elapsed, 4.327 minutes remaining
# 12.8 % completed, 0.635 minutes elapsed, 4.322 minutes remaining
# 12.9 % completed, 0.64 minutes elapsed, 4.317 minutes remaining
# 13.0 % completed, 0.645 minutes elapsed, 4.312 minutes remaining
# 13.1 % completed, 0.65 minutes elapsed, 4.306 minutes remaining
# 13.2 % completed, 0.655 minutes elapsed, 4.301 minutes remaining
# 13.3 % completed, 0.659 minutes elapsed, 4.295 minutes remaining
# 13.4 % completed, 0.664 minutes elapsed, 4.29 minutes remaining
# 13.5 % completed, 0.669 minutes elapsed, 4.285 minutes remaining
# 13.6 % completed, 0.674 minutes elapsed, 4.28 minutes remaining
# 13.7 % completed, 0.679 minutes elapsed, 4.275 minutes remaining
# 13.8 % completed, 0.684 minutes elapsed, 4.27 minutes remaining
# 13.9 % completed, 0.689 minutes elapsed, 4.265 minutes remaining
# 14.0 % completed, 0.694 minutes elapsed, 4.26 minutes remaining
# 14.1 % completed, 0.699 minutes elapsed, 4.254 minutes remaining
# 14.2 % completed, 0.704 minutes elapsed, 4.249 minutes remaining
# 14.3 % completed, 0.709 minutes elapsed, 4.244 minutes remaining
# 14.4 % completed, 0.714 minutes elapsed, 4.239 minutes remaining
# 14.5 % completed, 0.719 minutes elapsed, 4.234 minutes remaining
# 14.6 % completed, 0.723 minutes elapsed, 4.229 minutes remaining
# 14.7 % completed, 0.728 minutes elapsed, 4.223 minutes remaining
# 14.8 % completed, 0.733 minutes elapsed, 4.218 minutes remaining
# 14.9 % completed, 0.738 minutes elapsed, 4.213 minutes remaining
# 15.0 % completed, 0.743 minutes elapsed, 4.208 minutes remaining
# 15.1 % completed, 0.748 minutes elapsed, 4.203 minutes remaining
# 15.2 % completed, 0.753 minutes elapsed, 4.197 minutes remaining
# 15.3 % completed, 0.758 minutes elapsed, 4.193 minutes remaining
# 15.4 % completed, 0.763 minutes elapsed, 4.187 minutes remaining
# 15.5 % completed, 0.768 minutes elapsed, 4.182 minutes remaining
# 15.6 % completed, 0.773 minutes elapsed, 4.177 minutes remaining
# 15.7 % completed, 0.778 minutes elapsed, 4.172 minutes remaining
# 15.8 % completed, 0.782 minutes elapsed, 4.167 minutes remaining
# 15.9 % completed, 0.787 minutes elapsed, 4.162 minutes remaining
# 16.0 % completed, 0.794 minutes elapsed, 4.163 minutes remaining
# 16.1 % completed, 0.798 minutes elapsed, 4.158 minutes remaining
# 16.2 % completed, 0.803 minutes elapsed, 4.153 minutes remaining
# 16.3 % completed, 0.808 minutes elapsed, 4.147 minutes remaining
# 16.4 % completed, 0.813 minutes elapsed, 4.142 minutes remaining
# 16.5 % completed, 0.818 minutes elapsed, 4.137 minutes remaining
# 16.6 % completed, 0.823 minutes elapsed, 4.132 minutes remaining
# 16.7 % completed, 0.828 minutes elapsed, 4.126 minutes remaining
# 16.8 % completed, 0.833 minutes elapsed, 4.121 minutes remaining
# 16.9 % completed, 0.837 minutes elapsed, 4.115 minutes remaining
# 17.0 % completed, 0.842 minutes elapsed, 4.11 minutes remaining
# 17.1 % completed, 0.847 minutes elapsed, 4.105 minutes remaining
# 17.2 % completed, 0.852 minutes elapsed, 4.099 minutes remaining
# 17.3 % completed, 0.857 minutes elapsed, 4.094 minutes remaining
# 17.4 % completed, 0.862 minutes elapsed, 4.088 minutes remaining
# 17.5 % completed, 0.867 minutes elapsed, 4.083 minutes remaining
# 17.6 % completed, 0.872 minutes elapsed, 4.078 minutes remaining
# 17.7 % completed, 0.877 minutes elapsed, 4.074 minutes remaining
# 17.8 % completed, 0.882 minutes elapsed, 4.069 minutes remaining
# 17.9 % completed, 0.887 minutes elapsed, 4.065 minutes remaining
# 18.0 % completed, 0.892 minutes elapsed, 4.06 minutes remaining
# 18.1 % completed, 0.897 minutes elapsed, 4.055 minutes remaining
# 18.2 % completed, 0.901 minutes elapsed, 4.05 minutes remaining
# 18.3 % completed, 0.906 minutes elapsed, 4.045 minutes remaining
# 18.4 % completed, 0.911 minutes elapsed, 4.039 minutes remaining
# 18.5 % completed, 0.916 minutes elapsed, 4.034 minutes remaining
# 18.6 % completed, 0.921 minutes elapsed, 4.029 minutes remaining
# 18.7 % completed, 0.926 minutes elapsed, 4.024 minutes remaining
# 18.8 % completed, 0.931 minutes elapsed, 4.02 minutes remaining
# 18.9 % completed, 0.936 minutes elapsed, 4.015 minutes remaining
# 19.0 % completed, 0.941 minutes elapsed, 4.01 minutes remaining
# 19.1 % completed, 0.946 minutes elapsed, 4.005 minutes remaining
# 19.2 % completed, 0.951 minutes elapsed, 4.0 minutes remaining
# 19.3 % completed, 0.956 minutes elapsed, 3.996 minutes remaining
# 19.4 % completed, 0.961 minutes elapsed, 3.992 minutes remaining
# 19.5 % completed, 0.966 minutes elapsed, 3.988 minutes remaining
# 19.6 % completed, 0.971 minutes elapsed, 3.982 minutes remaining
# 19.7 % completed, 0.976 minutes elapsed, 3.977 minutes remaining
# 19.8 % completed, 0.981 minutes elapsed, 3.972 minutes remaining
# 19.9 % completed, 0.986 minutes elapsed, 3.967 minutes remaining
# 20.0 % completed, 0.991 minutes elapsed, 3.963 minutes remaining
# 20.1 % completed, 0.996 minutes elapsed, 3.958 minutes remaining
# 20.2 % completed, 1.001 minutes elapsed, 3.953 minutes remaining
# 20.3 % completed, 1.006 minutes elapsed, 3.948 minutes remaining
# 20.4 % completed, 1.011 minutes elapsed, 3.943 minutes remaining
# 20.5 % completed, 1.016 minutes elapsed, 3.938 minutes remaining
# 20.6 % completed, 1.021 minutes elapsed, 3.933 minutes remaining
# 20.7 % completed, 1.026 minutes elapsed, 3.928 minutes remaining
# 20.8 % completed, 1.031 minutes elapsed, 3.923 minutes remaining
# 20.9 % completed, 1.036 minutes elapsed, 3.918 minutes remaining
# 21.0 % completed, 1.041 minutes elapsed, 3.913 minutes remaining
# 21.1 % completed, 1.046 minutes elapsed, 3.908 minutes remaining
# 21.2 % completed, 1.05 minutes elapsed, 3.903 minutes remaining
# 21.3 % completed, 1.055 minutes elapsed, 3.898 minutes remaining
# 21.4 % completed, 1.06 minutes elapsed, 3.893 minutes remaining
# 21.5 % completed, 1.066 minutes elapsed, 3.889 minutes remaining
# 21.6 % completed, 1.07 minutes elapsed, 3.884 minutes remaining
# 21.7 % completed, 1.075 minutes elapsed, 3.878 minutes remaining
# 21.8 % completed, 1.08 minutes elapsed, 3.873 minutes remaining
# 21.9 % completed, 1.085 minutes elapsed, 3.868 minutes remaining
# 22.0 % completed, 1.09 minutes elapsed, 3.863 minutes remaining
# 22.1 % completed, 1.095 minutes elapsed, 3.859 minutes remaining
# 22.2 % completed, 1.1 minutes elapsed, 3.854 minutes remaining
# 22.3 % completed, 1.105 minutes elapsed, 3.849 minutes remaining
# 22.4 % completed, 1.11 minutes elapsed, 3.843 minutes remaining
# 22.5 % completed, 1.115 minutes elapsed, 3.839 minutes remaining
# 22.6 % completed, 1.12 minutes elapsed, 3.834 minutes remaining
# 22.7 % completed, 1.125 minutes elapsed, 3.829 minutes remaining
# 22.8 % completed, 1.13 minutes elapsed, 3.824 minutes remaining
# 22.9 % completed, 1.135 minutes elapsed, 3.82 minutes remaining
# 23.0 % completed, 1.14 minutes elapsed, 3.815 minutes remaining
# 23.1 % completed, 1.145 minutes elapsed, 3.81 minutes remaining
# 23.2 % completed, 1.15 minutes elapsed, 3.805 minutes remaining
# 23.3 % completed, 1.155 minutes elapsed, 3.8 minutes remaining
# 23.4 % completed, 1.16 minutes elapsed, 3.795 minutes remaining
# 23.5 % completed, 1.165 minutes elapsed, 3.79 minutes remaining
# 23.6 % completed, 1.17 minutes elapsed, 3.785 minutes remaining
# 23.7 % completed, 1.175 minutes elapsed, 3.781 minutes remaining
# 23.8 % completed, 1.18 minutes elapsed, 3.777 minutes remaining
# 23.9 % completed, 1.185 minutes elapsed, 3.772 minutes remaining
# 24.0 % completed, 1.19 minutes elapsed, 3.768 minutes remaining
# 24.1 % completed, 1.195 minutes elapsed, 3.763 minutes remaining
# 24.2 % completed, 1.201 minutes elapsed, 3.759 minutes remaining
# 24.3 % completed, 1.206 minutes elapsed, 3.755 minutes remaining
# 24.4 % completed, 1.211 minutes elapsed, 3.75 minutes remaining
# 24.5 % completed, 1.216 minutes elapsed, 3.745 minutes remaining
# 24.6 % completed, 1.221 minutes elapsed, 3.74 minutes remaining
# 24.7 % completed, 1.226 minutes elapsed, 3.735 minutes remaining
# 24.8 % completed, 1.231 minutes elapsed, 3.73 minutes remaining
# 24.9 % completed, 1.235 minutes elapsed, 3.725 minutes remaining
# 25.0 % completed, 1.24 minutes elapsed, 3.72 minutes remaining
# 25.1 % completed, 1.245 minutes elapsed, 3.715 minutes remaining
# 25.2 % completed, 1.25 minutes elapsed, 3.709 minutes remaining
# 25.3 % completed, 1.255 minutes elapsed, 3.704 minutes remaining
# 25.4 % completed, 1.26 minutes elapsed, 3.699 minutes remaining
# 25.5 % completed, 1.265 minutes elapsed, 3.694 minutes remaining
# 25.6 % completed, 1.27 minutes elapsed, 3.689 minutes remaining
# 25.7 % completed, 1.275 minutes elapsed, 3.684 minutes remaining
# 25.8 % completed, 1.28 minutes elapsed, 3.679 minutes remaining
# 25.9 % completed, 1.285 minutes elapsed, 3.674 minutes remaining
# 26.0 % completed, 1.289 minutes elapsed, 3.669 minutes remaining
# 26.1 % completed, 1.294 minutes elapsed, 3.664 minutes remaining
# 26.2 % completed, 1.299 minutes elapsed, 3.658 minutes remaining
# 26.3 % completed, 1.304 minutes elapsed, 3.653 minutes remaining
# 26.4 % completed, 1.309 minutes elapsed, 3.648 minutes remaining
# 26.5 % completed, 1.314 minutes elapsed, 3.643 minutes remaining
# 26.6 % completed, 1.319 minutes elapsed, 3.638 minutes remaining
# 26.7 % completed, 1.324 minutes elapsed, 3.633 minutes remaining
# 26.8 % completed, 1.329 minutes elapsed, 3.628 minutes remaining
# 26.9 % completed, 1.334 minutes elapsed, 3.623 minutes remaining
# 27.0 % completed, 1.338 minutes elapsed, 3.618 minutes remaining
# 27.1 % completed, 1.343 minutes elapsed, 3.612 minutes remaining
# 27.2 % completed, 1.348 minutes elapsed, 3.607 minutes remaining
# 27.3 % completed, 1.353 minutes elapsed, 3.602 minutes remaining
# 27.4 % completed, 1.358 minutes elapsed, 3.597 minutes remaining
# 27.5 % completed, 1.363 minutes elapsed, 3.592 minutes remaining
# 27.6 % completed, 1.368 minutes elapsed, 3.587 minutes remaining
# 27.7 % completed, 1.373 minutes elapsed, 3.582 minutes remaining
# 27.8 % completed, 1.378 minutes elapsed, 3.577 minutes remaining
# 27.9 % completed, 1.383 minutes elapsed, 3.572 minutes remaining
# 28.0 % completed, 1.388 minutes elapsed, 3.567 minutes remaining
# 28.1 % completed, 1.393 minutes elapsed, 3.562 minutes remaining
# 28.2 % completed, 1.398 minutes elapsed, 3.557 minutes remaining
# 28.3 % completed, 1.403 minutes elapsed, 3.552 minutes remaining
# 28.4 % completed, 1.407 minutes elapsed, 3.547 minutes remaining
# 28.5 % completed, 1.412 minutes elapsed, 3.542 minutes remaining
# 28.6 % completed, 1.417 minutes elapsed, 3.537 minutes remaining
# 28.7 % completed, 1.422 minutes elapsed, 3.532 minutes remaining
# 28.8 % completed, 1.427 minutes elapsed, 3.527 minutes remaining
# 28.9 % completed, 1.432 minutes elapsed, 3.522 minutes remaining
# 29.0 % completed, 1.437 minutes elapsed, 3.517 minutes remaining
# 29.1 % completed, 1.442 minutes elapsed, 3.512 minutes remaining
# 29.2 % completed, 1.447 minutes elapsed, 3.507 minutes remaining
# 29.3 % completed, 1.452 minutes elapsed, 3.502 minutes remaining
# 29.4 % completed, 1.457 minutes elapsed, 3.497 minutes remaining
# 29.5 % completed, 1.462 minutes elapsed, 3.492 minutes remaining
# 29.6 % completed, 1.467 minutes elapsed, 3.487 minutes remaining
# 29.7 % completed, 1.472 minutes elapsed, 3.482 minutes remaining
# 29.8 % completed, 1.477 minutes elapsed, 3.477 minutes remaining
# 29.9 % completed, 1.482 minutes elapsed, 3.472 minutes remaining
# 30.0 % completed, 1.487 minutes elapsed, 3.467 minutes remaining
# 30.1 % completed, 1.491 minutes elapsed, 3.462 minutes remaining
# 30.2 % completed, 1.496 minutes elapsed, 3.458 minutes remaining
# 30.3 % completed, 1.501 minutes elapsed, 3.453 minutes remaining
# 30.4 % completed, 1.506 minutes elapsed, 3.448 minutes remaining
# 30.5 % completed, 1.511 minutes elapsed, 3.443 minutes remaining
# 30.6 % completed, 1.516 minutes elapsed, 3.438 minutes remaining
# 30.7 % completed, 1.521 minutes elapsed, 3.433 minutes remaining
# 30.8 % completed, 1.526 minutes elapsed, 3.428 minutes remaining
# 30.9 % completed, 1.531 minutes elapsed, 3.423 minutes remaining
# 31.0 % completed, 1.536 minutes elapsed, 3.418 minutes remaining
# 31.1 % completed, 1.541 minutes elapsed, 3.413 minutes remaining
# 31.2 % completed, 1.546 minutes elapsed, 3.408 minutes remaining
# 31.3 % completed, 1.551 minutes elapsed, 3.403 minutes remaining
# 31.4 % completed, 1.556 minutes elapsed, 3.398 minutes remaining
# 31.5 % completed, 1.561 minutes elapsed, 3.393 minutes remaining
# 31.6 % completed, 1.566 minutes elapsed, 3.388 minutes remaining
# 31.7 % completed, 1.571 minutes elapsed, 3.383 minutes remaining
# 31.8 % completed, 1.577 minutes elapsed, 3.38 minutes remaining
# 31.9 % completed, 1.582 minutes elapsed, 3.376 minutes remaining
# 32.0 % completed, 1.587 minutes elapsed, 3.371 minutes remaining
# 32.1 % completed, 1.592 minutes elapsed, 3.366 minutes remaining
# 32.2 % completed, 1.597 minutes elapsed, 3.361 minutes remaining
# 32.3 % completed, 1.602 minutes elapsed, 3.356 minutes remaining
# 32.4 % completed, 1.606 minutes elapsed, 3.351 minutes remaining
# 32.5 % completed, 1.612 minutes elapsed, 3.346 minutes remaining
# 32.6 % completed, 1.617 minutes elapsed, 3.341 minutes remaining
# 32.7 % completed, 1.622 minutes elapsed, 3.336 minutes remaining
# 32.8 % completed, 1.627 minutes elapsed, 3.331 minutes remaining
# 32.9 % completed, 1.631 minutes elapsed, 3.326 minutes remaining
# 33.0 % completed, 1.636 minutes elapsed, 3.321 minutes remaining
# 33.1 % completed, 1.641 minutes elapsed, 3.316 minutes remaining
# 33.2 % completed, 1.646 minutes elapsed, 3.311 minutes remaining
# 33.3 % completed, 1.651 minutes elapsed, 3.306 minutes remaining
# 33.4 % completed, 1.656 minutes elapsed, 3.302 minutes remaining
# 33.5 % completed, 1.661 minutes elapsed, 3.297 minutes remaining
# 33.6 % completed, 1.666 minutes elapsed, 3.292 minutes remaining
# 33.7 % completed, 1.671 minutes elapsed, 3.287 minutes remaining
# 33.8 % completed, 1.676 minutes elapsed, 3.282 minutes remaining
# 33.9 % completed, 1.681 minutes elapsed, 3.277 minutes remaining
# 34.0 % completed, 1.686 minutes elapsed, 3.272 minutes remaining
# 34.1 % completed, 1.691 minutes elapsed, 3.267 minutes remaining
# 34.2 % completed, 1.696 minutes elapsed, 3.263 minutes remaining
# 34.3 % completed, 1.701 minutes elapsed, 3.257 minutes remaining
# 34.4 % completed, 1.706 minutes elapsed, 3.253 minutes remaining
# 34.5 % completed, 1.711 minutes elapsed, 3.248 minutes remaining
# 34.6 % completed, 1.716 minutes elapsed, 3.243 minutes remaining
# 34.7 % completed, 1.721 minutes elapsed, 3.238 minutes remaining
# 34.8 % completed, 1.726 minutes elapsed, 3.233 minutes remaining
# 34.9 % completed, 1.731 minutes elapsed, 3.228 minutes remaining
# 35.0 % completed, 1.736 minutes elapsed, 3.223 minutes remaining
# 35.1 % completed, 1.741 minutes elapsed, 3.218 minutes remaining
# 35.2 % completed, 1.746 minutes elapsed, 3.213 minutes remaining
# 35.3 % completed, 1.751 minutes elapsed, 3.208 minutes remaining
# 35.4 % completed, 1.756 minutes elapsed, 3.203 minutes remaining
# 35.5 % completed, 1.761 minutes elapsed, 3.198 minutes remaining
# 35.6 % completed, 1.766 minutes elapsed, 3.193 minutes remaining
# 35.7 % completed, 1.771 minutes elapsed, 3.188 minutes remaining
# 35.8 % completed, 1.776 minutes elapsed, 3.184 minutes remaining
# 35.9 % completed, 1.781 minutes elapsed, 3.179 minutes remaining
# 36.0 % completed, 1.786 minutes elapsed, 3.174 minutes remaining
# 36.1 % completed, 1.791 minutes elapsed, 3.169 minutes remaining
# 36.2 % completed, 1.796 minutes elapsed, 3.164 minutes remaining
# 36.3 % completed, 1.8 minutes elapsed, 3.159 minutes remaining
# 36.4 % completed, 1.805 minutes elapsed, 3.154 minutes remaining
# 36.5 % completed, 1.81 minutes elapsed, 3.149 minutes remaining
# 36.6 % completed, 1.815 minutes elapsed, 3.144 minutes remaining
# 36.7 % completed, 1.82 minutes elapsed, 3.139 minutes remaining
# 36.8 % completed, 1.825 minutes elapsed, 3.134 minutes remaining
# 36.9 % completed, 1.83 minutes elapsed, 3.129 minutes remaining
# 37.0 % completed, 1.835 minutes elapsed, 3.124 minutes remaining
# 37.1 % completed, 1.84 minutes elapsed, 3.119 minutes remaining
# 37.2 % completed, 1.845 minutes elapsed, 3.114 minutes remaining
# 37.3 % completed, 1.85 minutes elapsed, 3.109 minutes remaining
# 37.4 % completed, 1.855 minutes elapsed, 3.104 minutes remaining
# 37.5 % completed, 1.86 minutes elapsed, 3.099 minutes remaining
# 37.6 % completed, 1.865 minutes elapsed, 3.094 minutes remaining
# 37.7 % completed, 1.87 minutes elapsed, 3.089 minutes remaining
# 37.8 % completed, 1.875 minutes elapsed, 3.084 minutes remaining
# 37.9 % completed, 1.879 minutes elapsed, 3.079 minutes remaining
# 38.0 % completed, 1.884 minutes elapsed, 3.074 minutes remaining
# 38.1 % completed, 1.889 minutes elapsed, 3.069 minutes remaining
# 38.2 % completed, 1.894 minutes elapsed, 3.064 minutes remaining
# 38.3 % completed, 1.899 minutes elapsed, 3.059 minutes remaining
# 38.4 % completed, 1.904 minutes elapsed, 3.054 minutes remaining
# 38.5 % completed, 1.909 minutes elapsed, 3.049 minutes remaining
# 38.6 % completed, 1.914 minutes elapsed, 3.044 minutes remaining
# 38.7 % completed, 1.919 minutes elapsed, 3.039 minutes remaining
# 38.8 % completed, 1.924 minutes elapsed, 3.034 minutes remaining
# 38.9 % completed, 1.929 minutes elapsed, 3.029 minutes remaining
# 39.0 % completed, 1.934 minutes elapsed, 3.024 minutes remaining
# 39.1 % completed, 1.939 minutes elapsed, 3.019 minutes remaining
# 39.2 % completed, 1.944 minutes elapsed, 3.014 minutes remaining
# 39.3 % completed, 1.949 minutes elapsed, 3.009 minutes remaining
# 39.4 % completed, 1.953 minutes elapsed, 3.004 minutes remaining
# 39.5 % completed, 1.958 minutes elapsed, 2.999 minutes remaining
# 39.6 % completed, 1.963 minutes elapsed, 2.994 minutes remaining
# 39.7 % completed, 1.968 minutes elapsed, 2.989 minutes remaining
# 39.8 % completed, 1.973 minutes elapsed, 2.984 minutes remaining
# 39.9 % completed, 1.978 minutes elapsed, 2.979 minutes remaining
# 40.0 % completed, 1.983 minutes elapsed, 2.974 minutes remaining
# 40.1 % completed, 1.988 minutes elapsed, 2.969 minutes remaining
# 40.2 % completed, 1.993 minutes elapsed, 2.964 minutes remaining
# 40.3 % completed, 1.998 minutes elapsed, 2.959 minutes remaining
# 40.4 % completed, 2.003 minutes elapsed, 2.954 minutes remaining
# 40.5 % completed, 2.008 minutes elapsed, 2.949 minutes remaining
# 40.6 % completed, 2.013 minutes elapsed, 2.944 minutes remaining
# 40.7 % completed, 2.018 minutes elapsed, 2.939 minutes remaining
# 40.8 % completed, 2.023 minutes elapsed, 2.934 minutes remaining
# 40.9 % completed, 2.028 minutes elapsed, 2.93 minutes remaining
# 41.0 % completed, 2.033 minutes elapsed, 2.925 minutes remaining
# 41.1 % completed, 2.038 minutes elapsed, 2.92 minutes remaining
# 41.2 % completed, 2.043 minutes elapsed, 2.915 minutes remaining
# 41.3 % completed, 2.048 minutes elapsed, 2.91 minutes remaining
# 41.4 % completed, 2.053 minutes elapsed, 2.905 minutes remaining
# 41.5 % completed, 2.058 minutes elapsed, 2.9 minutes remaining
# 41.6 % completed, 2.063 minutes elapsed, 2.895 minutes remaining
# 41.7 % completed, 2.068 minutes elapsed, 2.89 minutes remaining
# 41.8 % completed, 2.073 minutes elapsed, 2.885 minutes remaining
# 41.9 % completed, 2.077 minutes elapsed, 2.88 minutes remaining
# 42.0 % completed, 2.082 minutes elapsed, 2.875 minutes remaining
# 42.1 % completed, 2.087 minutes elapsed, 2.87 minutes remaining
# 42.2 % completed, 2.092 minutes elapsed, 2.865 minutes remaining
# 42.3 % completed, 2.097 minutes elapsed, 2.86 minutes remaining
# 42.4 % completed, 2.102 minutes elapsed, 2.855 minutes remaining
# 42.5 % completed, 2.107 minutes elapsed, 2.85 minutes remaining
# 42.6 % completed, 2.112 minutes elapsed, 2.845 minutes remaining
# 42.7 % completed, 2.117 minutes elapsed, 2.84 minutes remaining
# 42.8 % completed, 2.122 minutes elapsed, 2.835 minutes remaining
# 42.9 % completed, 2.127 minutes elapsed, 2.83 minutes remaining
# 43.0 % completed, 2.132 minutes elapsed, 2.825 minutes remaining
# 43.1 % completed, 2.137 minutes elapsed, 2.82 minutes remaining
# 43.2 % completed, 2.142 minutes elapsed, 2.815 minutes remaining
# 43.3 % completed, 2.147 minutes elapsed, 2.81 minutes remaining
# 43.4 % completed, 2.151 minutes elapsed, 2.805 minutes remaining
# 43.5 % completed, 2.156 minutes elapsed, 2.8 minutes remaining
# 43.6 % completed, 2.161 minutes elapsed, 2.795 minutes remaining
# 43.7 % completed, 2.166 minutes elapsed, 2.79 minutes remaining
# 43.8 % completed, 2.171 minutes elapsed, 2.785 minutes remaining
# 43.9 % completed, 2.176 minutes elapsed, 2.78 minutes remaining
# 44.0 % completed, 2.181 minutes elapsed, 2.775 minutes remaining
# 44.1 % completed, 2.186 minutes elapsed, 2.77 minutes remaining
# 44.2 % completed, 2.191 minutes elapsed, 2.765 minutes remaining
# 44.3 % completed, 2.196 minutes elapsed, 2.76 minutes remaining
# 44.4 % completed, 2.201 minutes elapsed, 2.755 minutes remaining
# 44.5 % completed, 2.206 minutes elapsed, 2.751 minutes remaining
# 44.6 % completed, 2.211 minutes elapsed, 2.746 minutes remaining
# 44.7 % completed, 2.216 minutes elapsed, 2.741 minutes remaining
# 44.8 % completed, 2.221 minutes elapsed, 2.736 minutes remaining
# 44.9 % completed, 2.226 minutes elapsed, 2.731 minutes remaining
# 45.0 % completed, 2.231 minutes elapsed, 2.726 minutes remaining
# 45.1 % completed, 2.236 minutes elapsed, 2.721 minutes remaining
# 45.2 % completed, 2.241 minutes elapsed, 2.716 minutes remaining
# 45.3 % completed, 2.246 minutes elapsed, 2.711 minutes remaining
# 45.4 % completed, 2.251 minutes elapsed, 2.706 minutes remaining
# 45.5 % completed, 2.256 minutes elapsed, 2.701 minutes remaining
# 45.6 % completed, 2.261 minutes elapsed, 2.696 minutes remaining
# 45.7 % completed, 2.266 minutes elapsed, 2.691 minutes remaining
# 45.8 % completed, 2.271 minutes elapsed, 2.686 minutes remaining
# 45.9 % completed, 2.276 minutes elapsed, 2.682 minutes remaining
# 46.0 % completed, 2.281 minutes elapsed, 2.677 minutes remaining
# 46.1 % completed, 2.285 minutes elapsed, 2.672 minutes remaining
# 46.2 % completed, 2.29 minutes elapsed, 2.667 minutes remaining
# 46.3 % completed, 2.295 minutes elapsed, 2.662 minutes remaining
# 46.4 % completed, 2.3 minutes elapsed, 2.657 minutes remaining
# 46.5 % completed, 2.305 minutes elapsed, 2.652 minutes remaining
# 46.6 % completed, 2.31 minutes elapsed, 2.647 minutes remaining
# 46.7 % completed, 2.315 minutes elapsed, 2.642 minutes remaining
# 46.8 % completed, 2.32 minutes elapsed, 2.637 minutes remaining
# 46.9 % completed, 2.325 minutes elapsed, 2.632 minutes remaining
# 47.0 % completed, 2.331 minutes elapsed, 2.628 minutes remaining
# 47.1 % completed, 2.336 minutes elapsed, 2.623 minutes remaining
# 47.2 % completed, 2.341 minutes elapsed, 2.618 minutes remaining
# 47.3 % completed, 2.346 minutes elapsed, 2.613 minutes remaining
# 47.4 % completed, 2.351 minutes elapsed, 2.608 minutes remaining
# 47.5 % completed, 2.356 minutes elapsed, 2.603 minutes remaining
# 47.6 % completed, 2.361 minutes elapsed, 2.598 minutes remaining
# 47.7 % completed, 2.366 minutes elapsed, 2.593 minutes remaining
# 47.8 % completed, 2.371 minutes elapsed, 2.588 minutes remaining
# 47.9 % completed, 2.376 minutes elapsed, 2.583 minutes remaining
# 48.0 % completed, 2.38 minutes elapsed, 2.578 minutes remaining
# 48.1 % completed, 2.385 minutes elapsed, 2.573 minutes remaining
# 48.2 % completed, 2.39 minutes elapsed, 2.568 minutes remaining
# 48.3 % completed, 2.395 minutes elapsed, 2.563 minutes remaining
# 48.4 % completed, 2.4 minutes elapsed, 2.558 minutes remaining
# 48.5 % completed, 2.405 minutes elapsed, 2.554 minutes remaining
# 48.6 % completed, 2.41 minutes elapsed, 2.549 minutes remaining
# 48.7 % completed, 2.415 minutes elapsed, 2.544 minutes remaining
# 48.8 % completed, 2.42 minutes elapsed, 2.538 minutes remaining
# 48.9 % completed, 2.425 minutes elapsed, 2.534 minutes remaining
# 49.0 % completed, 2.43 minutes elapsed, 2.529 minutes remaining
# 49.1 % completed, 2.435 minutes elapsed, 2.524 minutes remaining
# 49.2 % completed, 2.44 minutes elapsed, 2.519 minutes remaining
# 49.3 % completed, 2.445 minutes elapsed, 2.514 minutes remaining
# 49.4 % completed, 2.45 minutes elapsed, 2.509 minutes remaining
# 49.5 % completed, 2.455 minutes elapsed, 2.504 minutes remaining
# 49.6 % completed, 2.46 minutes elapsed, 2.499 minutes remaining
# 49.7 % completed, 2.465 minutes elapsed, 2.494 minutes remaining
# 49.8 % completed, 2.47 minutes elapsed, 2.489 minutes remaining
# 49.9 % completed, 2.474 minutes elapsed, 2.484 minutes remaining
# 50.0 % completed, 2.479 minutes elapsed, 2.479 minutes remaining
# 50.1 % completed, 2.484 minutes elapsed, 2.474 minutes remaining
# 50.2 % completed, 2.489 minutes elapsed, 2.469 minutes remaining
# 50.3 % completed, 2.494 minutes elapsed, 2.464 minutes remaining
# 50.4 % completed, 2.499 minutes elapsed, 2.459 minutes remaining
# 50.5 % completed, 2.504 minutes elapsed, 2.454 minutes remaining
# 50.6 % completed, 2.509 minutes elapsed, 2.449 minutes remaining
# 50.7 % completed, 2.514 minutes elapsed, 2.444 minutes remaining
# 50.8 % completed, 2.519 minutes elapsed, 2.439 minutes remaining
# 50.9 % completed, 2.524 minutes elapsed, 2.435 minutes remaining
# 51.0 % completed, 2.529 minutes elapsed, 2.43 minutes remaining
# 51.1 % completed, 2.534 minutes elapsed, 2.425 minutes remaining
# 51.2 % completed, 2.539 minutes elapsed, 2.42 minutes remaining
# 51.3 % completed, 2.544 minutes elapsed, 2.415 minutes remaining
# 51.4 % completed, 2.549 minutes elapsed, 2.41 minutes remaining
# 51.5 % completed, 2.554 minutes elapsed, 2.405 minutes remaining
# 51.6 % completed, 2.559 minutes elapsed, 2.4 minutes remaining
# 51.7 % completed, 2.564 minutes elapsed, 2.395 minutes remaining
# 51.8 % completed, 2.569 minutes elapsed, 2.39 minutes remaining
# 51.9 % completed, 2.574 minutes elapsed, 2.385 minutes remaining
# 52.0 % completed, 2.579 minutes elapsed, 2.38 minutes remaining
# 52.1 % completed, 2.584 minutes elapsed, 2.375 minutes remaining
# 52.2 % completed, 2.589 minutes elapsed, 2.37 minutes remaining
# 52.3 % completed, 2.594 minutes elapsed, 2.365 minutes remaining
# 52.4 % completed, 2.599 minutes elapsed, 2.36 minutes remaining
# 52.5 % completed, 2.604 minutes elapsed, 2.355 minutes remaining
# 52.6 % completed, 2.609 minutes elapsed, 2.35 minutes remaining
# 52.7 % completed, 2.614 minutes elapsed, 2.345 minutes remaining
# 52.8 % completed, 2.619 minutes elapsed, 2.34 minutes remaining
# 52.9 % completed, 2.623 minutes elapsed, 2.335 minutes remaining
# 53.0 % completed, 2.628 minutes elapsed, 2.33 minutes remaining
# 53.1 % completed, 2.633 minutes elapsed, 2.325 minutes remaining
# 53.2 % completed, 2.638 minutes elapsed, 2.32 minutes remaining
# 53.3 % completed, 2.643 minutes elapsed, 2.315 minutes remaining
# 53.4 % completed, 2.648 minutes elapsed, 2.31 minutes remaining
# 53.5 % completed, 2.653 minutes elapsed, 2.305 minutes remaining
# 53.6 % completed, 2.658 minutes elapsed, 2.301 minutes remaining
# 53.7 % completed, 2.663 minutes elapsed, 2.296 minutes remaining
# 53.8 % completed, 2.668 minutes elapsed, 2.291 minutes remaining
# 53.9 % completed, 2.673 minutes elapsed, 2.286 minutes remaining
# 54.0 % completed, 2.678 minutes elapsed, 2.281 minutes remaining
# 54.1 % completed, 2.683 minutes elapsed, 2.276 minutes remaining
# 54.2 % completed, 2.688 minutes elapsed, 2.271 minutes remaining
# 54.3 % completed, 2.693 minutes elapsed, 2.266 minutes remaining
# 54.4 % completed, 2.698 minutes elapsed, 2.261 minutes remaining
# 54.5 % completed, 2.703 minutes elapsed, 2.256 minutes remaining
# 54.6 % completed, 2.708 minutes elapsed, 2.251 minutes remaining
# 54.7 % completed, 2.713 minutes elapsed, 2.246 minutes remaining
# 54.8 % completed, 2.718 minutes elapsed, 2.241 minutes remaining
# 54.9 % completed, 2.723 minutes elapsed, 2.236 minutes remaining
# 55.0 % completed, 2.727 minutes elapsed, 2.231 minutes remaining
# 55.1 % completed, 2.732 minutes elapsed, 2.226 minutes remaining
# 55.2 % completed, 2.737 minutes elapsed, 2.221 minutes remaining
# 55.3 % completed, 2.742 minutes elapsed, 2.216 minutes remaining
# 55.4 % completed, 2.747 minutes elapsed, 2.211 minutes remaining
# 55.5 % completed, 2.752 minutes elapsed, 2.206 minutes remaining
# 55.6 % completed, 2.757 minutes elapsed, 2.201 minutes remaining
# 55.7 % completed, 2.762 minutes elapsed, 2.196 minutes remaining
# 55.8 % completed, 2.767 minutes elapsed, 2.192 minutes remaining
# 55.9 % completed, 2.772 minutes elapsed, 2.187 minutes remaining
# 56.0 % completed, 2.777 minutes elapsed, 2.182 minutes remaining
# 56.1 % completed, 2.782 minutes elapsed, 2.177 minutes remaining
# 56.2 % completed, 2.787 minutes elapsed, 2.172 minutes remaining
# 56.3 % completed, 2.792 minutes elapsed, 2.167 minutes remaining
# 56.4 % completed, 2.797 minutes elapsed, 2.162 minutes remaining
# 56.5 % completed, 2.802 minutes elapsed, 2.157 minutes remaining
# 56.6 % completed, 2.807 minutes elapsed, 2.152 minutes remaining
# 56.7 % completed, 2.812 minutes elapsed, 2.147 minutes remaining
# 56.8 % completed, 2.816 minutes elapsed, 2.142 minutes remaining
# 56.9 % completed, 2.821 minutes elapsed, 2.137 minutes remaining
# 57.0 % completed, 2.826 minutes elapsed, 2.132 minutes remaining
# 57.1 % completed, 2.831 minutes elapsed, 2.127 minutes remaining
# 57.2 % completed, 2.836 minutes elapsed, 2.122 minutes remaining
# 57.3 % completed, 2.841 minutes elapsed, 2.117 minutes remaining
# 57.4 % completed, 2.846 minutes elapsed, 2.112 minutes remaining
# 57.5 % completed, 2.851 minutes elapsed, 2.107 minutes remaining
# 57.6 % completed, 2.856 minutes elapsed, 2.102 minutes remaining
# 57.7 % completed, 2.861 minutes elapsed, 2.097 minutes remaining
# 57.8 % completed, 2.866 minutes elapsed, 2.092 minutes remaining
# 57.9 % completed, 2.871 minutes elapsed, 2.087 minutes remaining
# 58.0 % completed, 2.876 minutes elapsed, 2.082 minutes remaining
# 58.1 % completed, 2.881 minutes elapsed, 2.077 minutes remaining
# 58.2 % completed, 2.886 minutes elapsed, 2.072 minutes remaining
# 58.3 % completed, 2.891 minutes elapsed, 2.067 minutes remaining
# 58.4 % completed, 2.896 minutes elapsed, 2.062 minutes remaining
# 58.5 % completed, 2.901 minutes elapsed, 2.057 minutes remaining
# 58.6 % completed, 2.906 minutes elapsed, 2.052 minutes remaining
# 58.7 % completed, 2.911 minutes elapsed, 2.047 minutes remaining
# 58.8 % completed, 2.916 minutes elapsed, 2.042 minutes remaining
# 58.9 % completed, 2.921 minutes elapsed, 2.038 minutes remaining
# 59.0 % completed, 2.926 minutes elapsed, 2.033 minutes remaining
# 59.1 % completed, 2.931 minutes elapsed, 2.028 minutes remaining
# 59.2 % completed, 2.936 minutes elapsed, 2.023 minutes remaining
# 59.3 % completed, 2.941 minutes elapsed, 2.018 minutes remaining
# 59.4 % completed, 2.945 minutes elapsed, 2.013 minutes remaining
# 59.5 % completed, 2.95 minutes elapsed, 2.008 minutes remaining
# 59.6 % completed, 2.955 minutes elapsed, 2.003 minutes remaining
# 59.7 % completed, 2.96 minutes elapsed, 1.998 minutes remaining
# 59.8 % completed, 2.965 minutes elapsed, 1.993 minutes remaining
# 59.9 % completed, 2.97 minutes elapsed, 1.988 minutes remaining
# 60.0 % completed, 2.975 minutes elapsed, 1.983 minutes remaining
# 60.1 % completed, 2.98 minutes elapsed, 1.978 minutes remaining
# 60.2 % completed, 2.985 minutes elapsed, 1.973 minutes remaining
# 60.3 % completed, 2.99 minutes elapsed, 1.968 minutes remaining
# 60.4 % completed, 2.995 minutes elapsed, 1.963 minutes remaining
# 60.5 % completed, 3.0 minutes elapsed, 1.958 minutes remaining
# 60.6 % completed, 3.005 minutes elapsed, 1.953 minutes remaining
# 60.7 % completed, 3.01 minutes elapsed, 1.948 minutes remaining
# 60.8 % completed, 3.015 minutes elapsed, 1.943 minutes remaining
# 60.9 % completed, 3.02 minutes elapsed, 1.938 minutes remaining
# 61.0 % completed, 3.025 minutes elapsed, 1.933 minutes remaining
# 61.1 % completed, 3.03 minutes elapsed, 1.928 minutes remaining
# 61.2 % completed, 3.034 minutes elapsed, 1.923 minutes remaining
# 61.3 % completed, 3.039 minutes elapsed, 1.919 minutes remaining
# 61.4 % completed, 3.044 minutes elapsed, 1.914 minutes remaining
# 61.5 % completed, 3.049 minutes elapsed, 1.909 minutes remaining
# 61.6 % completed, 3.054 minutes elapsed, 1.904 minutes remaining
# 61.7 % completed, 3.059 minutes elapsed, 1.899 minutes remaining
# 61.8 % completed, 3.064 minutes elapsed, 1.894 minutes remaining
# 61.9 % completed, 3.069 minutes elapsed, 1.889 minutes remaining
# 62.0 % completed, 3.074 minutes elapsed, 1.884 minutes remaining
# 62.1 % completed, 3.079 minutes elapsed, 1.879 minutes remaining
# 62.2 % completed, 3.084 minutes elapsed, 1.874 minutes remaining
# 62.3 % completed, 3.089 minutes elapsed, 1.869 minutes remaining
# 62.4 % completed, 3.095 minutes elapsed, 1.865 minutes remaining
# 62.5 % completed, 3.1 minutes elapsed, 1.86 minutes remaining
# 62.6 % completed, 3.105 minutes elapsed, 1.855 minutes remaining
# 62.7 % completed, 3.11 minutes elapsed, 1.85 minutes remaining
# 62.8 % completed, 3.115 minutes elapsed, 1.845 minutes remaining
# 62.9 % completed, 3.119 minutes elapsed, 1.84 minutes remaining
# 63.0 % completed, 3.124 minutes elapsed, 1.835 minutes remaining
# 63.1 % completed, 3.129 minutes elapsed, 1.83 minutes remaining
# 63.2 % completed, 3.134 minutes elapsed, 1.825 minutes remaining
# 63.3 % completed, 3.139 minutes elapsed, 1.82 minutes remaining
# 63.4 % completed, 3.144 minutes elapsed, 1.815 minutes remaining
# 63.5 % completed, 3.149 minutes elapsed, 1.81 minutes remaining
# 63.6 % completed, 3.154 minutes elapsed, 1.805 minutes remaining
# 63.7 % completed, 3.159 minutes elapsed, 1.8 minutes remaining
# 63.8 % completed, 3.164 minutes elapsed, 1.795 minutes remaining
# 63.9 % completed, 3.169 minutes elapsed, 1.79 minutes remaining
# 64.0 % completed, 3.174 minutes elapsed, 1.785 minutes remaining
# 64.1 % completed, 3.179 minutes elapsed, 1.78 minutes remaining
# 64.2 % completed, 3.184 minutes elapsed, 1.775 minutes remaining
# 64.3 % completed, 3.189 minutes elapsed, 1.77 minutes remaining
# 64.4 % completed, 3.194 minutes elapsed, 1.765 minutes remaining
# 64.5 % completed, 3.199 minutes elapsed, 1.76 minutes remaining
# 64.6 % completed, 3.204 minutes elapsed, 1.755 minutes remaining
# 64.7 % completed, 3.209 minutes elapsed, 1.75 minutes remaining
# 64.8 % completed, 3.214 minutes elapsed, 1.745 minutes remaining
# 64.9 % completed, 3.219 minutes elapsed, 1.74 minutes remaining
# 65.0 % completed, 3.224 minutes elapsed, 1.736 minutes remaining
# 65.1 % completed, 3.229 minutes elapsed, 1.731 minutes remaining
# 65.2 % completed, 3.233 minutes elapsed, 1.726 minutes remaining
# 65.3 % completed, 3.238 minutes elapsed, 1.721 minutes remaining
# 65.4 % completed, 3.243 minutes elapsed, 1.716 minutes remaining
# 65.5 % completed, 3.248 minutes elapsed, 1.711 minutes remaining
# 65.6 % completed, 3.253 minutes elapsed, 1.706 minutes remaining
# 65.7 % completed, 3.258 minutes elapsed, 1.701 minutes remaining
# 65.8 % completed, 3.263 minutes elapsed, 1.696 minutes remaining
# 65.9 % completed, 3.268 minutes elapsed, 1.691 minutes remaining
# 66.0 % completed, 3.273 minutes elapsed, 1.686 minutes remaining
# 66.1 % completed, 3.278 minutes elapsed, 1.681 minutes remaining
# 66.2 % completed, 3.283 minutes elapsed, 1.676 minutes remaining
# 66.3 % completed, 3.288 minutes elapsed, 1.671 minutes remaining
# 66.4 % completed, 3.293 minutes elapsed, 1.666 minutes remaining
# 66.5 % completed, 3.298 minutes elapsed, 1.661 minutes remaining
# 66.6 % completed, 3.303 minutes elapsed, 1.656 minutes remaining
# 66.7 % completed, 3.308 minutes elapsed, 1.651 minutes remaining
# 66.8 % completed, 3.312 minutes elapsed, 1.646 minutes remaining
# 66.9 % completed, 3.317 minutes elapsed, 1.641 minutes remaining
# 67.0 % completed, 3.322 minutes elapsed, 1.636 minutes remaining
# 67.1 % completed, 3.327 minutes elapsed, 1.631 minutes remaining
# 67.2 % completed, 3.332 minutes elapsed, 1.626 minutes remaining
# 67.3 % completed, 3.337 minutes elapsed, 1.621 minutes remaining
# 67.4 % completed, 3.342 minutes elapsed, 1.616 minutes remaining
# 67.5 % completed, 3.347 minutes elapsed, 1.611 minutes remaining
# 67.6 % completed, 3.352 minutes elapsed, 1.606 minutes remaining
# 67.7 % completed, 3.357 minutes elapsed, 1.601 minutes remaining
# 67.8 % completed, 3.362 minutes elapsed, 1.596 minutes remaining
# 67.9 % completed, 3.367 minutes elapsed, 1.591 minutes remaining
# 68.0 % completed, 3.372 minutes elapsed, 1.586 minutes remaining
# 68.1 % completed, 3.376 minutes elapsed, 1.581 minutes remaining
# 68.2 % completed, 3.381 minutes elapsed, 1.576 minutes remaining
# 68.3 % completed, 3.386 minutes elapsed, 1.571 minutes remaining
# 68.4 % completed, 3.391 minutes elapsed, 1.566 minutes remaining
# 68.5 % completed, 3.396 minutes elapsed, 1.562 minutes remaining
# 68.6 % completed, 3.401 minutes elapsed, 1.557 minutes remaining
# 68.7 % completed, 3.406 minutes elapsed, 1.552 minutes remaining
# 68.8 % completed, 3.411 minutes elapsed, 1.547 minutes remaining
# 68.9 % completed, 3.416 minutes elapsed, 1.542 minutes remaining
# 69.0 % completed, 3.421 minutes elapsed, 1.537 minutes remaining
# 69.1 % completed, 3.426 minutes elapsed, 1.532 minutes remaining
# 69.2 % completed, 3.431 minutes elapsed, 1.527 minutes remaining
# 69.3 % completed, 3.436 minutes elapsed, 1.522 minutes remaining
# 69.4 % completed, 3.44 minutes elapsed, 1.517 minutes remaining
# 69.5 % completed, 3.445 minutes elapsed, 1.512 minutes remaining
# 69.6 % completed, 3.45 minutes elapsed, 1.507 minutes remaining
# 69.7 % completed, 3.455 minutes elapsed, 1.502 minutes remaining
# 69.8 % completed, 3.46 minutes elapsed, 1.497 minutes remaining
# 69.9 % completed, 3.465 minutes elapsed, 1.492 minutes remaining
# 70.0 % completed, 3.47 minutes elapsed, 1.487 minutes remaining
# 70.1 % completed, 3.475 minutes elapsed, 1.482 minutes remaining
# 70.2 % completed, 3.48 minutes elapsed, 1.477 minutes remaining
# 70.3 % completed, 3.485 minutes elapsed, 1.472 minutes remaining
# 70.4 % completed, 3.49 minutes elapsed, 1.467 minutes remaining
# 70.5 % completed, 3.495 minutes elapsed, 1.462 minutes remaining
# 70.6 % completed, 3.5 minutes elapsed, 1.457 minutes remaining
# 70.7 % completed, 3.505 minutes elapsed, 1.452 minutes remaining
# 70.8 % completed, 3.51 minutes elapsed, 1.447 minutes remaining
# 70.9 % completed, 3.515 minutes elapsed, 1.442 minutes remaining
# 71.0 % completed, 3.52 minutes elapsed, 1.437 minutes remaining
# 71.1 % completed, 3.525 minutes elapsed, 1.432 minutes remaining
# 71.2 % completed, 3.529 minutes elapsed, 1.427 minutes remaining
# 71.3 % completed, 3.534 minutes elapsed, 1.422 minutes remaining
# 71.4 % completed, 3.539 minutes elapsed, 1.417 minutes remaining
# 71.5 % completed, 3.544 minutes elapsed, 1.413 minutes remaining
# 71.6 % completed, 3.549 minutes elapsed, 1.408 minutes remaining
# 71.7 % completed, 3.554 minutes elapsed, 1.403 minutes remaining
# 71.8 % completed, 3.559 minutes elapsed, 1.398 minutes remaining
# 71.9 % completed, 3.564 minutes elapsed, 1.393 minutes remaining
# 72.0 % completed, 3.569 minutes elapsed, 1.388 minutes remaining
# 72.1 % completed, 3.574 minutes elapsed, 1.383 minutes remaining
# 72.2 % completed, 3.579 minutes elapsed, 1.378 minutes remaining
# 72.3 % completed, 3.584 minutes elapsed, 1.373 minutes remaining
# 72.4 % completed, 3.589 minutes elapsed, 1.368 minutes remaining
# 72.5 % completed, 3.594 minutes elapsed, 1.363 minutes remaining
# 72.6 % completed, 3.598 minutes elapsed, 1.358 minutes remaining
# 72.7 % completed, 3.603 minutes elapsed, 1.353 minutes remaining
# 72.8 % completed, 3.608 minutes elapsed, 1.348 minutes remaining
# 72.9 % completed, 3.614 minutes elapsed, 1.343 minutes remaining
# 73.0 % completed, 3.619 minutes elapsed, 1.338 minutes remaining
# 73.1 % completed, 3.624 minutes elapsed, 1.333 minutes remaining
# 73.2 % completed, 3.628 minutes elapsed, 1.328 minutes remaining
# 73.3 % completed, 3.633 minutes elapsed, 1.323 minutes remaining
# 73.4 % completed, 3.638 minutes elapsed, 1.318 minutes remaining
# 73.5 % completed, 3.643 minutes elapsed, 1.313 minutes remaining
# 73.6 % completed, 3.648 minutes elapsed, 1.308 minutes remaining
# 73.7 % completed, 3.653 minutes elapsed, 1.304 minutes remaining
# 73.8 % completed, 3.658 minutes elapsed, 1.299 minutes remaining
# 73.9 % completed, 3.663 minutes elapsed, 1.294 minutes remaining
# 74.0 % completed, 3.668 minutes elapsed, 1.289 minutes remaining
# ...
# 75.3 % completed, 3.734 minutes elapsed, 1.225 minutes remaining
# 75.4 % completed, 3.739 minutes elapsed, 1.22 minutes remaining
# 75.5 % completed, 3.744 minutes elapsed, 1.215 minutes remaining
# 75.6 % completed, 3.749 minutes elapsed, 1.21 minutes remaining
# 75.7 % completed, 3.754 minutes elapsed, 1.205 minutes remaining
# 75.8 % completed, 3.759 minutes elapsed, 1.2 minutes remaining
# 75.9 % completed, 3.763 minutes elapsed, 1.195 minutes remaining
# 76.0 % completed, 3.769 minutes elapsed, 1.19 minutes remaining
# 76.1 % completed, 3.774 minutes elapsed, 1.185 minutes remaining
# 76.2 % completed, 3.778 minutes elapsed, 1.18 minutes remaining
# 76.3 % completed, 3.783 minutes elapsed, 1.175 minutes remaining
# 76.4 % completed, 3.788 minutes elapsed, 1.17 minutes remaining
# 76.5 % completed, 3.793 minutes elapsed, 1.165 minutes remaining
# 76.6 % completed, 3.798 minutes elapsed, 1.16 minutes remaining
# 76.7 % completed, 3.803 minutes elapsed, 1.155 minutes remaining
# 76.8 % completed, 3.809 minutes elapsed, 1.15 minutes remaining
# 76.9 % completed, 3.814 minutes elapsed, 1.145 minutes remaining
# 77.0 % completed, 3.818 minutes elapsed, 1.14 minutes remaining
# 77.1 % completed, 3.824 minutes elapsed, 1.135 minutes remaining
# 77.2 % completed, 3.828 minutes elapsed, 1.131 minutes remaining
# 77.3 % completed, 3.834 minutes elapsed, 1.126 minutes remaining
# 77.4 % completed, 3.839 minutes elapsed, 1.121 minutes remaining
# 77.5 % completed, 3.844 minutes elapsed, 1.116 minutes remaining
# 77.6 % completed, 3.85 minutes elapsed, 1.111 minutes remaining
# 77.7 % completed, 3.855 minutes elapsed, 1.106 minutes remaining
# 77.8 % completed, 3.86 minutes elapsed, 1.101 minutes remaining
# 77.9 % completed, 3.865 minutes elapsed, 1.096 minutes remaining
# 78.0 % completed, 3.87 minutes elapsed, 1.091 minutes remaining
# 78.1 % completed, 3.874 minutes elapsed, 1.086 minutes remaining
# 78.2 % completed, 3.88 minutes elapsed, 1.081 minutes remaining
# 78.3 % completed, 3.885 minutes elapsed, 1.076 minutes remaining
# 78.4 % completed, 3.889 minutes elapsed, 1.071 minutes remaining
# 78.5 % completed, 3.894 minutes elapsed, 1.066 minutes remaining
# 78.6 % completed, 3.899 minutes elapsed, 1.062 minutes remaining
# 78.7 % completed, 3.904 minutes elapsed, 1.057 minutes remaining
# 78.8 % completed, 3.909 minutes elapsed, 1.052 minutes remaining
# 78.9 % completed, 3.914 minutes elapsed, 1.047 minutes remaining
# 79.0 % completed, 3.919 minutes elapsed, 1.042 minutes remaining
# 79.1 % completed, 3.924 minutes elapsed, 1.037 minutes remaining
# 79.2 % completed, 3.929 minutes elapsed, 1.032 minutes remaining
# 79.3 % completed, 3.934 minutes elapsed, 1.027 minutes remaining
# 79.4 % completed, 3.94 minutes elapsed, 1.022 minutes remaining
# 79.5 % completed, 3.945 minutes elapsed, 1.017 minutes remaining
# 79.6 % completed, 3.95 minutes elapsed, 1.012 minutes remaining
# 79.7 % completed, 3.955 minutes elapsed, 1.007 minutes remaining
# 79.8 % completed, 3.96 minutes elapsed, 1.002 minutes remaining
# 79.9 % completed, 3.965 minutes elapsed, 0.997 minutes remaining
# 80.0 % completed, 3.97 minutes elapsed, 0.992 minutes remaining
# 80.1 % completed, 3.975 minutes elapsed, 0.987 minutes remaining
# 80.2 % completed, 3.98 minutes elapsed, 0.982 minutes remaining
# 80.3 % completed, 3.985 minutes elapsed, 0.977 minutes remaining
# 80.4 % completed, 3.99 minutes elapsed, 0.973 minutes remaining
# 80.5 % completed, 3.995 minutes elapsed, 0.968 minutes remaining
# 80.6 % completed, 4.0 minutes elapsed, 0.963 minutes remaining
# 80.7 % completed, 4.005 minutes elapsed, 0.958 minutes remaining
# 80.8 % completed, 4.01 minutes elapsed, 0.953 minutes remaining
# 80.9 % completed, 4.015 minutes elapsed, 0.948 minutes remaining
# 81.0 % completed, 4.019 minutes elapsed, 0.943 minutes remaining
# 81.1 % completed, 4.024 minutes elapsed, 0.938 minutes remaining
# 81.2 % completed, 4.029 minutes elapsed, 0.933 minutes remaining
# 81.3 % completed, 4.034 minutes elapsed, 0.928 minutes remaining
# 81.4 % completed, 4.039 minutes elapsed, 0.923 minutes remaining
# 81.5 % completed, 4.044 minutes elapsed, 0.918 minutes remaining
# 81.6 % completed, 4.049 minutes elapsed, 0.913 minutes remaining
# 81.7 % completed, 4.054 minutes elapsed, 0.908 minutes remaining
# 81.8 % completed, 4.059 minutes elapsed, 0.903 minutes remaining
# 81.9 % completed, 4.064 minutes elapsed, 0.898 minutes remaining
# 82.0 % completed, 4.069 minutes elapsed, 0.893 minutes remaining
# 82.1 % completed, 4.074 minutes elapsed, 0.888 minutes remaining
# 82.2 % completed, 4.079 minutes elapsed, 0.883 minutes remaining
# 82.3 % completed, 4.084 minutes elapsed, 0.878 minutes remaining
# 82.4 % completed, 4.089 minutes elapsed, 0.873 minutes remaining
# 82.5 % completed, 4.094 minutes elapsed, 0.868 minutes remaining
# 82.6 % completed, 4.099 minutes elapsed, 0.863 minutes remaining
# 82.7 % completed, 4.104 minutes elapsed, 0.859 minutes remaining
# 82.8 % completed, 4.109 minutes elapsed, 0.854 minutes remaining
# 82.9 % completed, 4.115 minutes elapsed, 0.849 minutes remaining
# 83.0 % completed, 4.12 minutes elapsed, 0.844 minutes remaining
# 83.1 % completed, 4.125 minutes elapsed, 0.839 minutes remaining
# 83.2 % completed, 4.13 minutes elapsed, 0.834 minutes remaining
# 83.3 % completed, 4.135 minutes elapsed, 0.829 minutes remaining
# 83.4 % completed, 4.14 minutes elapsed, 0.824 minutes remaining
# 83.5 % completed, 4.145 minutes elapsed, 0.819 minutes remaining
# 83.6 % completed, 4.15 minutes elapsed, 0.814 minutes remaining
# 83.7 % completed, 4.155 minutes elapsed, 0.809 minutes remaining
# 83.8 % completed, 4.16 minutes elapsed, 0.804 minutes remaining
# 83.9 % completed, 4.165 minutes elapsed, 0.799 minutes remaining
# 84.0 % completed, 4.17 minutes elapsed, 0.794 minutes remaining
# 84.1 % completed, 4.175 minutes elapsed, 0.789 minutes remaining
# 84.2 % completed, 4.18 minutes elapsed, 0.784 minutes remaining
# 84.3 % completed, 4.185 minutes elapsed, 0.779 minutes remaining
# 84.4 % completed, 4.19 minutes elapsed, 0.774 minutes remaining
# 84.5 % completed, 4.195 minutes elapsed, 0.769 minutes remaining
# 84.6 % completed, 4.2 minutes elapsed, 0.764 minutes remaining
# 84.7 % completed, 4.205 minutes elapsed, 0.759 minutes remaining
# 84.8 % completed, 4.21 minutes elapsed, 0.755 minutes remaining
# 84.9 % completed, 4.215 minutes elapsed, 0.75 minutes remaining
# 85.0 % completed, 4.22 minutes elapsed, 0.745 minutes remaining
# 85.1 % completed, 4.225 minutes elapsed, 0.74 minutes remaining
# 85.2 % completed, 4.23 minutes elapsed, 0.735 minutes remaining
# 85.3 % completed, 4.235 minutes elapsed, 0.73 minutes remaining
# 85.4 % completed, 4.24 minutes elapsed, 0.725 minutes remaining
# 85.5 % completed, 4.245 minutes elapsed, 0.72 minutes remaining
# 85.6 % completed, 4.25 minutes elapsed, 0.715 minutes remaining
# 85.7 % completed, 4.255 minutes elapsed, 0.71 minutes remaining
# 85.8 % completed, 4.26 minutes elapsed, 0.705 minutes remaining
# 85.9 % completed, 4.265 minutes elapsed, 0.7 minutes remaining
# 86.0 % completed, 4.27 minutes elapsed, 0.695 minutes remaining
# 86.1 % completed, 4.275 minutes elapsed, 0.69 minutes remaining
# 86.2 % completed, 4.28 minutes elapsed, 0.685 minutes remaining
# 86.3 % completed, 4.285 minutes elapsed, 0.68 minutes remaining
# 86.4 % completed, 4.29 minutes elapsed, 0.675 minutes remaining
# 86.5 % completed, 4.295 minutes elapsed, 0.67 minutes remaining
# 86.6 % completed, 4.3 minutes elapsed, 0.665 minutes remaining
# 86.7 % completed, 4.305 minutes elapsed, 0.66 minutes remaining
# 86.8 % completed, 4.31 minutes elapsed, 0.655 minutes remaining
# 86.9 % completed, 4.315 minutes elapsed, 0.65 minutes remaining
# 87.0 % completed, 4.321 minutes elapsed, 0.646 minutes remaining
# 87.1 % completed, 4.325 minutes elapsed, 0.641 minutes remaining
# 87.2 % completed, 4.33 minutes elapsed, 0.636 minutes remaining
# 87.3 % completed, 4.335 minutes elapsed, 0.631 minutes remaining
# 87.4 % completed, 4.34 minutes elapsed, 0.626 minutes remaining
# 87.5 % completed, 4.345 minutes elapsed, 0.621 minutes remaining
# 87.6 % completed, 4.35 minutes elapsed, 0.616 minutes remaining
# 87.7 % completed, 4.355 minutes elapsed, 0.611 minutes remaining
# 87.8 % completed, 4.36 minutes elapsed, 0.606 minutes remaining
# 87.9 % completed, 4.365 minutes elapsed, 0.601 minutes remaining
# 88.0 % completed, 4.37 minutes elapsed, 0.596 minutes remaining
# 88.1 % completed, 4.375 minutes elapsed, 0.591 minutes remaining
# 88.2 % completed, 4.38 minutes elapsed, 0.586 minutes remaining
# 88.3 % completed, 4.385 minutes elapsed, 0.581 minutes remaining
# 88.4 % completed, 4.39 minutes elapsed, 0.576 minutes remaining
# 88.5 % completed, 4.395 minutes elapsed, 0.571 minutes remaining
# 88.6 % completed, 4.4 minutes elapsed, 0.566 minutes remaining
# 88.7 % completed, 4.405 minutes elapsed, 0.561 minutes remaining
# 88.8 % completed, 4.41 minutes elapsed, 0.556 minutes remaining
# 88.9 % completed, 4.415 minutes elapsed, 0.551 minutes remaining
# 89.0 % completed, 4.42 minutes elapsed, 0.546 minutes remaining
# 89.1 % completed, 4.425 minutes elapsed, 0.541 minutes remaining
# 89.2 % completed, 4.43 minutes elapsed, 0.536 minutes remaining
# 89.3 % completed, 4.435 minutes elapsed, 0.531 minutes remaining
# 89.4 % completed, 4.44 minutes elapsed, 0.526 minutes remaining
# 89.5 % completed, 4.445 minutes elapsed, 0.521 minutes remaining
# 89.6 % completed, 4.45 minutes elapsed, 0.516 minutes remaining
# 89.7 % completed, 4.455 minutes elapsed, 0.511 minutes remaining
# 89.8 % completed, 4.46 minutes elapsed, 0.507 minutes remaining
# 89.9 % completed, 4.465 minutes elapsed, 0.502 minutes remaining
# 90.0 % completed, 4.47 minutes elapsed, 0.497 minutes remaining
# 90.1 % completed, 4.475 minutes elapsed, 0.492 minutes remaining
# 90.2 % completed, 4.48 minutes elapsed, 0.487 minutes remaining
# 90.3 % completed, 4.485 minutes elapsed, 0.482 minutes remaining
# 90.4 % completed, 4.49 minutes elapsed, 0.477 minutes remaining
# 90.5 % completed, 4.495 minutes elapsed, 0.472 minutes remaining
# 90.6 % completed, 4.5 minutes elapsed, 0.467 minutes remaining
# 90.7 % completed, 4.504 minutes elapsed, 0.462 minutes remaining
# 90.8 % completed, 4.51 minutes elapsed, 0.457 minutes remaining
# 90.9 % completed, 4.515 minutes elapsed, 0.452 minutes remaining
# 91.0 % completed, 4.519 minutes elapsed, 0.447 minutes remaining
# 91.1 % completed, 4.524 minutes elapsed, 0.442 minutes remaining
# 91.2 % completed, 4.529 minutes elapsed, 0.437 minutes remaining
# 91.3 % completed, 4.534 minutes elapsed, 0.432 minutes remaining
# 91.4 % completed, 4.539 minutes elapsed, 0.427 minutes remaining
# 91.5 % completed, 4.544 minutes elapsed, 0.422 minutes remaining
# 91.6 % completed, 4.549 minutes elapsed, 0.417 minutes remaining
# 91.7 % completed, 4.554 minutes elapsed, 0.412 minutes remaining
# 91.8 % completed, 4.559 minutes elapsed, 0.407 minutes remaining
# 91.9 % completed, 4.564 minutes elapsed, 0.402 minutes remaining
# 92.0 % completed, 4.569 minutes elapsed, 0.397 minutes remaining
# 92.1 % completed, 4.574 minutes elapsed, 0.392 minutes remaining
# 92.2 % completed, 4.579 minutes elapsed, 0.387 minutes remaining
# 92.3 % completed, 4.584 minutes elapsed, 0.382 minutes remaining
# 92.4 % completed, 4.589 minutes elapsed, 0.377 minutes remaining
# 92.5 % completed, 4.594 minutes elapsed, 0.372 minutes remaining
# 92.6 % completed, 4.599 minutes elapsed, 0.367 minutes remaining
# 92.7 % completed, 4.604 minutes elapsed, 0.363 minutes remaining
# 92.8 % completed, 4.61 minutes elapsed, 0.358 minutes remaining
# 92.9 % completed, 4.615 minutes elapsed, 0.353 minutes remaining
# 93.0 % completed, 4.62 minutes elapsed, 0.348 minutes remaining
# 93.1 % completed, 4.625 minutes elapsed, 0.343 minutes remaining
# 93.2 % completed, 4.63 minutes elapsed, 0.338 minutes remaining
# 93.3 % completed, 4.635 minutes elapsed, 0.333 minutes remaining
# 93.4 % completed, 4.64 minutes elapsed, 0.328 minutes remaining
# 93.5 % completed, 4.645 minutes elapsed, 0.323 minutes remaining
# 93.6 % completed, 4.65 minutes elapsed, 0.318 minutes remaining
# 93.7 % completed, 4.655 minutes elapsed, 0.313 minutes remaining
# 93.8 % completed, 4.66 minutes elapsed, 0.308 minutes remaining
# 93.9 % completed, 4.665 minutes elapsed, 0.303 minutes remaining
# 94.0 % completed, 4.67 minutes elapsed, 0.298 minutes remaining
# 94.1 % completed, 4.674 minutes elapsed, 0.293 minutes remaining
# 94.2 % completed, 4.679 minutes elapsed, 0.288 minutes remaining
# 94.3 % completed, 4.684 minutes elapsed, 0.283 minutes remaining
# 94.4 % completed, 4.69 minutes elapsed, 0.278 minutes remaining
# 94.5 % completed, 4.695 minutes elapsed, 0.273 minutes remaining
# 94.6 % completed, 4.7 minutes elapsed, 0.268 minutes remaining
# 94.7 % completed, 4.705 minutes elapsed, 0.263 minutes remaining
# 94.8 % completed, 4.71 minutes elapsed, 0.258 minutes remaining
# 94.9 % completed, 4.715 minutes elapsed, 0.253 minutes remaining
# 95.0 % completed, 4.719 minutes elapsed, 0.248 minutes remaining
# 95.1 % completed, 4.724 minutes elapsed, 0.243 minutes remaining
# 95.2 % completed, 4.729 minutes elapsed, 0.238 minutes remaining
# 95.3 % completed, 4.734 minutes elapsed, 0.233 minutes remaining
# 95.4 % completed, 4.739 minutes elapsed, 0.229 minutes remaining
# 95.5 % completed, 4.744 minutes elapsed, 0.224 minutes remaining
# 95.6 % completed, 4.749 minutes elapsed, 0.219 minutes remaining
# 95.7 % completed, 4.754 minutes elapsed, 0.214 minutes remaining
# 95.8 % completed, 4.759 minutes elapsed, 0.209 minutes remaining
# 95.9 % completed, 4.764 minutes elapsed, 0.204 minutes remaining
# 96.0 % completed, 4.77 minutes elapsed, 0.199 minutes remaining
# 96.1 % completed, 4.775 minutes elapsed, 0.194 minutes remaining
# 96.2 % completed, 4.78 minutes elapsed, 0.189 minutes remaining
# 96.3 % completed, 4.785 minutes elapsed, 0.184 minutes remaining
# 96.4 % completed, 4.79 minutes elapsed, 0.179 minutes remaining
# 96.5 % completed, 4.795 minutes elapsed, 0.174 minutes remaining
# 96.6 % completed, 4.8 minutes elapsed, 0.169 minutes remaining
# 96.7 % completed, 4.805 minutes elapsed, 0.164 minutes remaining
# 96.8 % completed, 4.81 minutes elapsed, 0.159 minutes remaining
# 96.9 % completed, 4.815 minutes elapsed, 0.154 minutes remaining
# 97.0 % completed, 4.82 minutes elapsed, 0.149 minutes remaining
# 97.1 % completed, 4.825 minutes elapsed, 0.144 minutes remaining
# 97.2 % completed, 4.83 minutes elapsed, 0.139 minutes remaining
# 97.3 % completed, 4.835 minutes elapsed, 0.134 minutes remaining
# 97.4 % completed, 4.84 minutes elapsed, 0.129 minutes remaining
# 97.5 % completed, 4.845 minutes elapsed, 0.124 minutes remaining
# 97.6 % completed, 4.85 minutes elapsed, 0.119 minutes remaining
# 97.7 % completed, 4.855 minutes elapsed, 0.114 minutes remaining
# 97.8 % completed, 4.86 minutes elapsed, 0.109 minutes remaining
# 97.9 % completed, 4.865 minutes elapsed, 0.104 minutes remaining
# 98.0 % completed, 4.87 minutes elapsed, 0.099 minutes remaining
# 98.1 % completed, 4.875 minutes elapsed, 0.094 minutes remaining
# 98.2 % completed, 4.88 minutes elapsed, 0.089 minutes remaining
# 98.3 % completed, 4.885 minutes elapsed, 0.084 minutes remaining
# 98.4 % completed, 4.89 minutes elapsed, 0.079 minutes remaining
# 98.5 % completed, 4.895 minutes elapsed, 0.075 minutes remaining
# 98.6 % completed, 4.9 minutes elapsed, 0.07 minutes remaining
# 98.7 % completed, 4.905 minutes elapsed, 0.065 minutes remaining
# 98.8 % completed, 4.91 minutes elapsed, 0.06 minutes remaining
# 98.9 % completed, 4.915 minutes elapsed, 0.055 minutes remaining
# 99.0 % completed, 4.92 minutes elapsed, 0.05 minutes remaining
# 99.1 % completed, 4.925 minutes elapsed, 0.045 minutes remaining
# 99.2 % completed, 4.93 minutes elapsed, 0.04 minutes remaining
# 99.3 % completed, 4.935 minutes elapsed, 0.035 minutes remaining
# 99.4 % completed, 4.94 minutes elapsed, 0.03 minutes remaining
# 99.5 % completed, 4.944 minutes elapsed, 0.025 minutes remaining
# 99.6 % completed, 4.949 minutes elapsed, 0.02 minutes remaining
# 99.7 % completed, 4.954 minutes elapsed, 0.015 minutes remaining
# 99.8 % completed, 4.96 minutes elapsed, 0.01 minutes remaining
# 99.9 % completed, 4.965 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %%
#print(mix_coeffs_all)

# %%
print(f"Number of items: {len(mix_coeffs_all[0])}")
print(f"Array shape: {mix_coeffs_all[0].shape}")
# Out:
# Number of items: 10000
# Array shape: (10000, 2)

# %% [markdown]
# ### Export csv file of mix_coeffs_all for use in the zircon fertility analysis

# %%
# Converting the mix_coeffs_all to a 2D array so that we can run all 10,000 pairs of w1 and w2 through to understand the
# distribution through the bootstraping analyses. 
try:
    # Convert list to NumPy array
    array = np.array(mix_coeffs_all)
    # Flatten the array
    flattened_array = array.reshape(-1, array.shape[-1])
    # Determine column names based on the number of coefficients
    num_coeffs = flattened_array.shape[1]
    if num_coeffs == 2:
        column_names = ['Column1', 'Column2']
    elif num_coeffs == 3:
        column_names = ['Column1', 'Column2', 'Column3']
    else:
        # Fallback for other numbers of coefficients
        column_names = [f'Column{i+1}' for i in range(num_coeffs)]
    # Convert to DataFrame
    df = pd.DataFrame(flattened_array, columns=column_names)
    # Save to CSV in a "Spreadsheets" folder
    folder_path = "Spreadsheets"
    # Change name to current mixture
    filename = "mix_coeffs_all_ct-2_ct-3_to_ct-9.csv"
    # Create folder if it doesn't exist
    os.makedirs(folder_path, exist_ok=True)
    # Create full path and save
    full_path = os.path.join(folder_path, filename)
    df.to_csv(full_path, index=False)
    print("Saved")
    
except Exception as e:
    print(f"Not saved: {e}")
    # Optional: Print array shape for debugging
    if 'array' in locals():
        print(f"Array shape: {array.shape}")
    if 'flattened_array' in locals():
        print(f"Flattened array shape: {flattened_array.shape}")
# Out:
# Saved

# %%
# Plot histograms of all coefficients on same plot to visualize the distributions
plt.figure(figsize=(10, 6))

# Define colors for up to 6 coefficients (extend as needed)
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown']

# Get the number of coefficient columns
num_coeffs = len([col for col in df.columns if col.startswith('Column')])

# Plot histogram for each coefficient
for i in range(num_coeffs):
    col_name = f'Column{i+1}'
    color = colors[i % len(colors)]  # Cycle through colors if more coefficients than colors
    label = f'w{i+1}'
    
    plt.hist(df[col_name], bins=50, alpha=0.8, color=color, edgecolor='black', 
             linewidth=0.5, label=label)

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mix Coefficients')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 20, 100, 200] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Saves figure to a folder named 'Figures'
os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
fig.savefig('Figures/dPy-mix_ct-2_ct-3_to_ct-9_age_distribution.svg')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_objective_function_distributions.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_distribution_comparisons.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_spatial_comparison.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
os.makedirs('Spreadsheets', exist_ok=True)
file_name = 'Spreadsheets/dPy-mix_ct-2_ct-3_to_ct-9_results.xlsx'
dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                   obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                   bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                   doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                   mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                   worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
# Out:
# Workbook saved
