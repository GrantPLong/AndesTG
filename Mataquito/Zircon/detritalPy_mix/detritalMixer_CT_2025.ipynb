# %% [markdown]
# # DetritalPy Mixing code for the Mataquito River: Every Scenario

# %% [markdown]
# ## detritalPy-mix
# #### Glenn R. Sharman and Sam A. Johnstone
# #### Code for conducting 'top-down', or forward, mixture modeling of detrital zircon U-Pb ages that incorporates a bootstrapping-derived estimate of uncertainty
# #### Version 0.1 (Beta)
# ##### Updated Feb 9, 2024
# ##### Requires detritalPy v1.4.0 or later
# ##### This is a Beta release detritalPy-mix. Please contact Glenn Sharman (gsharman@uark.edu) if you encounter any errors or problems.
# ##### If you find this code helpful in your research, please consider citing Malkowski et al. (2019): American Journal of Science (https://doi.org/10.2475/10.2019.02) and/or Sharman and Johnstone (2017): Earth and Planetary Science Letters (https://doi.org/10.1016/j.epsl.2017.07.044)

# %% [markdown]
# ### I. Import required modules
# This step must by run initially, but then does not need to be run again for the remainder of the analysis session.
# <i>Hint: select a cell with code and Shift+Enter to execute it</i>

# %%
import detritalpy
from detritalpy import detritalFuncs as dFunc
from detritalpy import detritalMixer as dMix
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import os
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # For improving matplotlib figure resolution
matplotlib.rcParams['pdf.fonttype'] = 42 # For allowing preservation of fonts upon importing into Adobe Illustrator
matplotlib.rcParams['ps.fonttype'] = 42
print('detritalPy version: ',detritalpy.__version__)
# Out:
# detritalPy version:  1.4.3

# %% [markdown]
# ### II. Import the dataset as an Excel file
# This step must by run initially, and should be repeated if any changes are made to the dataset in Excel. The simplest way to load data is to place the Excel file(s) in the same directory or a sub-directory of the Jupyter Notebook file. For more options, please refer to dataLoading.ipynb.

# %% [markdown]
# Parent samples are those that will be mixed together. Child samples are the samples that are assumed to be mixtures of the parents. Individual samples or groups of samples can be selected by entering their unique Sample ID's in an array or tuple (see examples below for the correct syntax).
#
# Change parent and child list to see mixing results for CT-1 through CT-11

# %%
dataToLoad = ['/Users/Glong1/Desktop/Andes/AndesTG/Mataquito/Zircon/Spreadsheets/CT-1-11_ZrUPb_datasheets.xlsx']
main_df, main_byid_df, samples_df, analyses_df = dFunc.loadDataExcel(dataToLoad, dataSheet='ZrUPb')

""" 
Plug in the two / three parents that you want followed by all the children associated with all the parents. The options below are set up for easy use.
You will choose what parents you want and the associated child. Comment in/out whichever you want
"""
# Child options where parent list is CT-7, CT-1
#parent_list = ['CT-7', 'CT-1']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
#child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Child options where parent list is CT-5, CT-6
parent_list = ['CT-5', 'CT-6']
    # children options
#child_list = ['CT-4']
#child_list = ['CT-10']
child_list = ['CT-11']
#child_list = ['CT-8.2']
#child_list = ['CT-2']
#child_list = ['CT-9']

# Parent list options where Child is CT-2
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#child_list = ['CT-2']

# Parent list options where Child is CT-9
#parent_list = ['CT-4', 'CT-3']
#parent_list = ['CT-10', 'CT-3']
#parent_list = ['CT-11', 'CT-3']
#parent_list = ['CT-8.2', 'CT-3']
#parent_list = ['CT-2', 'CT-3']
#child_list = ['CT-9']

# Three to one mixtures
    # Parent list options where Child is CT-2
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#child_list = ['CT-2']

    # Parent list options where Child is CT-9
#parent_list = ['CT-1', 'CT-7', 'CT-3']
#parent_list = ['CT-5', 'CT-6', 'CT-3']
#child_list = ['CT-9']

# %% [markdown]
# ### Calculate best-fit mixture

# %% [markdown]
# **Selecting your definition for 'best-fit'**
#
# detritalPy-mix provides a few options for assessing (and minimizing) the difference between observed and modelled distributions. We refer to these functions as 'objective_metric', you can select from the different values printed below. We suggest reviewing Saylor and Sundell (2016): Geosphere (doi:10.1130/GES01237.1) for an overview of these metrics. Note that the 'ss' option is the square root of the sum of squared residuals bewteen the two empirical CDFs (i.e., L2 norm).

# %%
print('Options for objective_metric available in detritalPy-Mix:')
print(dMix.AVAILABLE_METRICS)
# Out:
# Options for objective_metric available in detritalPy-Mix:
# ['dmax', 'vmax', 'similarity-pdp', 'likeness-pdp', 'r2-pdp', 'similarity-kde', 'likeness-kde', 'r2-kde', 'ss']

# %% [markdown]
# The options below specify how the mixture modeling will be conducted. Please choose these parameters carefully, as the result will depend on the objective metric chosen and the choice of KDE parameters (bandwidth), if using one of the KDE-based objective metrics (e.g., r2-kde).

# %%
# What is the comparison metric to use, could be 'dmax','vmax', 'ss', 'r2-pdp','likeness-pdp', 'similarity-pdp', 'r2-kde','likeness-kde', 'similarity-kde', or 'L1norm'
objective_metric = 'vmax' # This determines if a PDF of a CDF is used to mix and compare data

# Specify the age range (Myr) over which you want to conduct mixture modeling
x1 = 0 # Strongly recommended value of 0 Ma
x2 = 4500 # Strongly recommended value of 4500 Ma

# If using a KDE-based objective metric (e.g., 'r2-kde'), the mixture modeling results will depend on choice of bandwidth
bw = 2 # Bandwidth of gaussian KDE in Myr (only used if a KDE is constructed to apply the chosen comparison metric)
bw_x = None # X-axis location of bandwidth split (only used if multiple KDE values are specified). Set to None if not using a split bandwidth.

# Specify the interval (Myr) over which distributions are calculated
xdif = 1 # Note: an interval of 1 Myr is recommended 


mix_coeffs_bf, obj_func_val, best_mixed_dist = dMix.find_best_fit_mix(parent_list, child_list, main_byid_df, sigma='1sigma', objective_metric=objective_metric,
                      x1=x1, x2=x2, xdif=xdif, bw=bw, bw_x=bw_x, verbose=True)
# Out:
# Starting: CT-11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.1287978621132226
#             Iterations: 7
#             Function evaluations: 46
#             Gradient evaluations: 7
# Completed mixing children.
# Time elapsed: 0.035 seconds

# %% [markdown]
# Optional: Running the code below will list the best-fit mixture of each of the sources for each child sample

# %%
dMix.print_best_fit_mixture(parent_list, child_list, objective_metric, obj_func_val, mix_coeffs_bf)
# Out:
# Sample: CT-11
# Best-fit vmax : 0.129
# Mixing coefficients
# --- CT-5 : 0.495
# --- CT-6 : 0.505

# %% [markdown]
# <b>Recommended exercise: </b> Try a different objective_metric option to see if you get a different result.

# %% [markdown]
# ### Construct many bootstrapped estimates of mixing coefficients
# Rather than rely on a single best-fit mixture, bootstrapping allows for an estimate of uncertainty in the mixing prediction. Bootstrapping is accomplished by calculating the best-fit mixture multiple times, after resampling with replacement both parent and child sample(s).

# %% [markdown]
# <b>Note:</b> 100 iterations takes about a minute. Use fewer boostrapps for testing, and then when you are ready, perform a large number (e.g., 5000) and let it run overnight

# %%
# How many bootstrap iterations should we preform. In practice 1000s is a good idea, but use fewer
# during testing to speed things up
nBootstrapIterations = 5000

# Do we want to only resample with replacement? Or should original observed ages additionally be redrawn
# based on the observed error
doPerturbResampledAges = False

# Do we want to construct bootstrapped estimates by drawing a specific number of grains from each sample?
# If None, defaults to the observed number of grains
nGrainsToResample = None

# Uncertainly level of input data (options: '1sigma' or '2sigma')
sigma = '2sigma' 

# Perform bootstrapped mixture modelling for each of the samples
mix_coeffs_all, obj_vals_all, child_modelled_distributions = dMix.bootstrap_solve_mixture_models(parent_list,
                                                                           child_list,main_byid_df,
                                                                            sigma = sigma,
                                                                            objective_metric = objective_metric,
                                                                            nBootstrapIterations = nBootstrapIterations, 
                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                            nGrainsToResample = nGrainsToResample,
                                                                            x1=x1, x2=x2, xdif=xdif,bw = bw, bw_x = bw_x,
                                                                                                verbose = True, update_freq = 10)

# Create a bootstrapped distribution of the children as well
selfCompMetrics_bs_set, childDists_bs_set = dMix.bootstrapped_self_comparisons_many_samples(main_byid_df,child_list,
                                                                                            doPerturbResampledAges = doPerturbResampledAges,
                                                                                            objective_metric = objective_metric,sigma = sigma,
                                                                                            x1 = x1, x2 = x2,xdif = xdif, bw = bw, bw_x = bw_x,
                                                                                            nBootstrapIterations = nBootstrapIterations)

# Calculate whether the best-fit mixture is a 'good' mixture by comparing the best-fit metric
# with the 5% poorest objective functions from resampling the child
obj_func_crit, worse_than_crit = dMix.calc_model_fit(child_list, obj_func_val, obj_vals_all, selfCompMetrics_bs_set, objective_metric=objective_metric)
# Out:
# -----------------------------------------------------------------
# Starting : CT-11 ( 1 of 1 child samples)
# 0.0 % completed, 0.001 minutes elapsed, 3.753 minutes remaining
# 0.2 % completed, 0.006 minutes elapsed, 2.715 minutes remaining
# 0.4 % completed, 0.011 minutes elapsed, 2.683 minutes remaining
# 0.6 % completed, 0.016 minutes elapsed, 2.642 minutes remaining
# 0.8 % completed, 0.022 minutes elapsed, 2.665 minutes remaining
# 1.0 % completed, 0.027 minutes elapsed, 2.655 minutes remaining
# 1.2 % completed, 0.034 minutes elapsed, 2.761 minutes remaining
# 1.4 % completed, 0.039 minutes elapsed, 2.73 minutes remaining
# 1.6 % completed, 0.044 minutes elapsed, 2.701 minutes remaining
# 1.8 % completed, 0.05 minutes elapsed, 2.677 minutes remaining
# 2.0 % completed, 0.055 minutes elapsed, 2.651 minutes remaining
# 2.2 % completed, 0.06 minutes elapsed, 2.636 minutes remaining
# 2.4 % completed, 0.065 minutes elapsed, 2.617 minutes remaining
# 2.6 % completed, 0.07 minutes elapsed, 2.603 minutes remaining
# 2.8 % completed, 0.075 minutes elapsed, 2.594 minutes remaining
# 3.0 % completed, 0.08 minutes elapsed, 2.579 minutes remaining
# 3.2 % completed, 0.085 minutes elapsed, 2.568 minutes remaining
# 3.4 % completed, 0.091 minutes elapsed, 2.561 minutes remaining
# 3.6 % completed, 0.096 minutes elapsed, 2.547 minutes remaining
# 3.8 % completed, 0.101 minutes elapsed, 2.536 minutes remaining
# 4.0 % completed, 0.106 minutes elapsed, 2.528 minutes remaining
# 4.2 % completed, 0.111 minutes elapsed, 2.52 minutes remaining
# 4.4 % completed, 0.116 minutes elapsed, 2.511 minutes remaining
# 4.6 % completed, 0.121 minutes elapsed, 2.504 minutes remaining
# 4.8 % completed, 0.126 minutes elapsed, 2.496 minutes remaining
# 5.0 % completed, 0.131 minutes elapsed, 2.486 minutes remaining
# 5.2 % completed, 0.136 minutes elapsed, 2.478 minutes remaining
# 5.4 % completed, 0.142 minutes elapsed, 2.473 minutes remaining
# 5.6 % completed, 0.147 minutes elapsed, 2.465 minutes remaining
# 5.8 % completed, 0.152 minutes elapsed, 2.456 minutes remaining
# 6.0 % completed, 0.157 minutes elapsed, 2.446 minutes remaining
# 6.2 % completed, 0.162 minutes elapsed, 2.442 minutes remaining
# 6.4 % completed, 0.167 minutes elapsed, 2.435 minutes remaining
# 6.6 % completed, 0.172 minutes elapsed, 2.43 minutes remaining
# 6.8 % completed, 0.177 minutes elapsed, 2.422 minutes remaining
# 7.0 % completed, 0.182 minutes elapsed, 2.415 minutes remaining
# 7.2 % completed, 0.187 minutes elapsed, 2.408 minutes remaining
# 7.4 % completed, 0.192 minutes elapsed, 2.401 minutes remaining
# 7.6 % completed, 0.197 minutes elapsed, 2.394 minutes remaining
# 7.8 % completed, 0.202 minutes elapsed, 2.387 minutes remaining
# 8.0 % completed, 0.208 minutes elapsed, 2.381 minutes remaining
# 8.2 % completed, 0.213 minutes elapsed, 2.378 minutes remaining
# 8.4 % completed, 0.218 minutes elapsed, 2.371 minutes remaining
# 8.6 % completed, 0.223 minutes elapsed, 2.365 minutes remaining
# 8.8 % completed, 0.229 minutes elapsed, 2.365 minutes remaining
# 9.0 % completed, 0.234 minutes elapsed, 2.359 minutes remaining
# 9.2 % completed, 0.239 minutes elapsed, 2.354 minutes remaining
# 9.4 % completed, 0.244 minutes elapsed, 2.348 minutes remaining
# 9.6 % completed, 0.249 minutes elapsed, 2.342 minutes remaining
# 9.8 % completed, 0.254 minutes elapsed, 2.337 minutes remaining
# 10.0 % completed, 0.26 minutes elapsed, 2.331 minutes remaining
# 10.2 % completed, 0.265 minutes elapsed, 2.325 minutes remaining
# 10.4 % completed, 0.27 minutes elapsed, 2.319 minutes remaining
# 10.6 % completed, 0.275 minutes elapsed, 2.314 minutes remaining
# 10.8 % completed, 0.28 minutes elapsed, 2.308 minutes remaining
# 11.0 % completed, 0.285 minutes elapsed, 2.302 minutes remaining
# 11.2 % completed, 0.29 minutes elapsed, 2.298 minutes remaining
# 11.4 % completed, 0.296 minutes elapsed, 2.294 minutes remaining
# 11.6 % completed, 0.301 minutes elapsed, 2.288 minutes remaining
# 11.8 % completed, 0.306 minutes elapsed, 2.282 minutes remaining
# 12.0 % completed, 0.311 minutes elapsed, 2.276 minutes remaining
# 12.2 % completed, 0.316 minutes elapsed, 2.27 minutes remaining
# 12.4 % completed, 0.321 minutes elapsed, 2.266 minutes remaining
# 12.6 % completed, 0.326 minutes elapsed, 2.26 minutes remaining
# 12.8 % completed, 0.331 minutes elapsed, 2.254 minutes remaining
# 13.0 % completed, 0.336 minutes elapsed, 2.248 minutes remaining
# 13.2 % completed, 0.341 minutes elapsed, 2.242 minutes remaining
# 13.4 % completed, 0.347 minutes elapsed, 2.237 minutes remaining
# 13.6 % completed, 0.352 minutes elapsed, 2.231 minutes remaining
# 13.8 % completed, 0.357 minutes elapsed, 2.226 minutes remaining
# 14.0 % completed, 0.362 minutes elapsed, 2.22 minutes remaining
# 14.2 % completed, 0.367 minutes elapsed, 2.215 minutes remaining
# 14.4 % completed, 0.372 minutes elapsed, 2.209 minutes remaining
# 14.6 % completed, 0.377 minutes elapsed, 2.204 minutes remaining
# 14.8 % completed, 0.383 minutes elapsed, 2.2 minutes remaining
# 15.0 % completed, 0.388 minutes elapsed, 2.194 minutes remaining
# 15.2 % completed, 0.393 minutes elapsed, 2.189 minutes remaining
# 15.4 % completed, 0.398 minutes elapsed, 2.184 minutes remaining
# 15.6 % completed, 0.403 minutes elapsed, 2.178 minutes remaining
# 15.8 % completed, 0.408 minutes elapsed, 2.172 minutes remaining
# 16.0 % completed, 0.413 minutes elapsed, 2.167 minutes remaining
# 16.2 % completed, 0.418 minutes elapsed, 2.161 minutes remaining
# 16.4 % completed, 0.423 minutes elapsed, 2.156 minutes remaining
# 16.6 % completed, 0.429 minutes elapsed, 2.151 minutes remaining
# 16.8 % completed, 0.434 minutes elapsed, 2.147 minutes remaining
# 17.0 % completed, 0.439 minutes elapsed, 2.143 minutes remaining
# 17.2 % completed, 0.445 minutes elapsed, 2.138 minutes remaining
# 17.4 % completed, 0.45 minutes elapsed, 2.132 minutes remaining
# 17.6 % completed, 0.455 minutes elapsed, 2.127 minutes remaining
# 17.8 % completed, 0.46 minutes elapsed, 2.122 minutes remaining
# 18.0 % completed, 0.465 minutes elapsed, 2.118 minutes remaining
# 18.2 % completed, 0.471 minutes elapsed, 2.113 minutes remaining
# 18.4 % completed, 0.476 minutes elapsed, 2.107 minutes remaining
# 18.6 % completed, 0.481 minutes elapsed, 2.102 minutes remaining
# 18.8 % completed, 0.486 minutes elapsed, 2.097 minutes remaining
# 19.0 % completed, 0.491 minutes elapsed, 2.091 minutes remaining
# 19.2 % completed, 0.496 minutes elapsed, 2.086 minutes remaining
# 19.4 % completed, 0.501 minutes elapsed, 2.081 minutes remaining
# 19.6 % completed, 0.506 minutes elapsed, 2.076 minutes remaining
# 19.8 % completed, 0.512 minutes elapsed, 2.07 minutes remaining
# 20.0 % completed, 0.517 minutes elapsed, 2.065 minutes remaining
# 20.2 % completed, 0.522 minutes elapsed, 2.06 minutes remaining
# 20.4 % completed, 0.527 minutes elapsed, 2.055 minutes remaining
# 20.6 % completed, 0.533 minutes elapsed, 2.051 minutes remaining
# 20.8 % completed, 0.538 minutes elapsed, 2.046 minutes remaining
# 21.0 % completed, 0.543 minutes elapsed, 2.042 minutes remaining
# 21.2 % completed, 0.548 minutes elapsed, 2.036 minutes remaining
# 21.4 % completed, 0.553 minutes elapsed, 2.03 minutes remaining
# 21.6 % completed, 0.558 minutes elapsed, 2.024 minutes remaining
# 21.8 % completed, 0.563 minutes elapsed, 2.018 minutes remaining
# 22.0 % completed, 0.568 minutes elapsed, 2.013 minutes remaining
# 22.2 % completed, 0.574 minutes elapsed, 2.009 minutes remaining
# 22.4 % completed, 0.579 minutes elapsed, 2.003 minutes remaining
# 22.6 % completed, 0.584 minutes elapsed, 1.997 minutes remaining
# 22.8 % completed, 0.589 minutes elapsed, 1.992 minutes remaining
# 23.0 % completed, 0.594 minutes elapsed, 1.987 minutes remaining
# 23.2 % completed, 0.599 minutes elapsed, 1.981 minutes remaining
# 23.4 % completed, 0.604 minutes elapsed, 1.977 minutes remaining
# 23.6 % completed, 0.61 minutes elapsed, 1.972 minutes remaining
# 23.8 % completed, 0.615 minutes elapsed, 1.966 minutes remaining
# 24.0 % completed, 0.62 minutes elapsed, 1.961 minutes remaining
# 24.2 % completed, 0.625 minutes elapsed, 1.956 minutes remaining
# 24.4 % completed, 0.63 minutes elapsed, 1.95 minutes remaining
# 24.6 % completed, 0.635 minutes elapsed, 1.944 minutes remaining
# 24.8 % completed, 0.64 minutes elapsed, 1.939 minutes remaining
# 25.0 % completed, 0.645 minutes elapsed, 1.933 minutes remaining
# 25.2 % completed, 0.65 minutes elapsed, 1.927 minutes remaining
# 25.4 % completed, 0.655 minutes elapsed, 1.922 minutes remaining
# 25.6 % completed, 0.66 minutes elapsed, 1.917 minutes remaining
# 25.8 % completed, 0.665 minutes elapsed, 1.911 minutes remaining
# 26.0 % completed, 0.67 minutes elapsed, 1.906 minutes remaining
# 26.2 % completed, 0.675 minutes elapsed, 1.9 minutes remaining
# 26.4 % completed, 0.68 minutes elapsed, 1.895 minutes remaining
# 26.6 % completed, 0.685 minutes elapsed, 1.89 minutes remaining
# 26.8 % completed, 0.69 minutes elapsed, 1.884 minutes remaining
# 27.0 % completed, 0.695 minutes elapsed, 1.879 minutes remaining
# 27.2 % completed, 0.7 minutes elapsed, 1.873 minutes remaining
# 27.4 % completed, 0.705 minutes elapsed, 1.868 minutes remaining
# 27.6 % completed, 0.71 minutes elapsed, 1.862 minutes remaining
# 27.8 % completed, 0.716 minutes elapsed, 1.857 minutes remaining
# 28.0 % completed, 0.721 minutes elapsed, 1.852 minutes remaining
# 28.2 % completed, 0.726 minutes elapsed, 1.846 minutes remaining
# 28.4 % completed, 0.731 minutes elapsed, 1.841 minutes remaining
# 28.6 % completed, 0.736 minutes elapsed, 1.835 minutes remaining
# 28.8 % completed, 0.741 minutes elapsed, 1.83 minutes remaining
# 29.0 % completed, 0.746 minutes elapsed, 1.825 minutes remaining
# 29.2 % completed, 0.751 minutes elapsed, 1.819 minutes remaining
# 29.4 % completed, 0.756 minutes elapsed, 1.814 minutes remaining
# 29.6 % completed, 0.761 minutes elapsed, 1.809 minutes remaining
# 29.8 % completed, 0.766 minutes elapsed, 1.803 minutes remaining
# 30.0 % completed, 0.771 minutes elapsed, 1.798 minutes remaining
# 30.2 % completed, 0.776 minutes elapsed, 1.793 minutes remaining
# 30.4 % completed, 0.781 minutes elapsed, 1.788 minutes remaining
# 30.6 % completed, 0.787 minutes elapsed, 1.783 minutes remaining
# 30.8 % completed, 0.792 minutes elapsed, 1.778 minutes remaining
# 31.0 % completed, 0.797 minutes elapsed, 1.772 minutes remaining
# 31.2 % completed, 0.802 minutes elapsed, 1.767 minutes remaining
# 31.4 % completed, 0.807 minutes elapsed, 1.762 minutes remaining
# 31.6 % completed, 0.812 minutes elapsed, 1.757 minutes remaining
# 31.8 % completed, 0.817 minutes elapsed, 1.752 minutes remaining
# 32.0 % completed, 0.822 minutes elapsed, 1.746 minutes remaining
# 32.2 % completed, 0.827 minutes elapsed, 1.741 minutes remaining
# 32.4 % completed, 0.833 minutes elapsed, 1.736 minutes remaining
# 32.6 % completed, 0.838 minutes elapsed, 1.731 minutes remaining
# 32.8 % completed, 0.843 minutes elapsed, 1.726 minutes remaining
# 33.0 % completed, 0.848 minutes elapsed, 1.721 minutes remaining
# 33.2 % completed, 0.853 minutes elapsed, 1.716 minutes remaining
# 33.4 % completed, 0.859 minutes elapsed, 1.711 minutes remaining
# 33.6 % completed, 0.864 minutes elapsed, 1.706 minutes remaining
# 33.8 % completed, 0.87 minutes elapsed, 1.703 minutes remaining
# 34.0 % completed, 0.875 minutes elapsed, 1.698 minutes remaining
# 34.2 % completed, 0.881 minutes elapsed, 1.693 minutes remaining
# 34.4 % completed, 0.886 minutes elapsed, 1.688 minutes remaining
# 34.6 % completed, 0.891 minutes elapsed, 1.683 minutes remaining
# 34.8 % completed, 0.896 minutes elapsed, 1.678 minutes remaining
# 35.0 % completed, 0.902 minutes elapsed, 1.674 minutes remaining
# 35.2 % completed, 0.907 minutes elapsed, 1.669 minutes remaining
# 35.4 % completed, 0.912 minutes elapsed, 1.664 minutes remaining
# 35.6 % completed, 0.917 minutes elapsed, 1.658 minutes remaining
# 35.8 % completed, 0.922 minutes elapsed, 1.653 minutes remaining
# 36.0 % completed, 0.928 minutes elapsed, 1.648 minutes remaining
# 36.2 % completed, 0.933 minutes elapsed, 1.643 minutes remaining
# 36.4 % completed, 0.938 minutes elapsed, 1.638 minutes remaining
# 36.6 % completed, 0.943 minutes elapsed, 1.632 minutes remaining
# 36.8 % completed, 0.948 minutes elapsed, 1.627 minutes remaining
# 37.0 % completed, 0.953 minutes elapsed, 1.622 minutes remaining
# 37.2 % completed, 0.958 minutes elapsed, 1.617 minutes remaining
# 37.4 % completed, 0.963 minutes elapsed, 1.612 minutes remaining
# 37.6 % completed, 0.969 minutes elapsed, 1.606 minutes remaining
# 37.8 % completed, 0.974 minutes elapsed, 1.601 minutes remaining
# 38.0 % completed, 0.979 minutes elapsed, 1.596 minutes remaining
# 38.2 % completed, 0.984 minutes elapsed, 1.591 minutes remaining
# 38.4 % completed, 0.989 minutes elapsed, 1.586 minutes remaining
# 38.6 % completed, 0.994 minutes elapsed, 1.58 minutes remaining
# 38.8 % completed, 0.999 minutes elapsed, 1.575 minutes remaining
# 39.0 % completed, 1.004 minutes elapsed, 1.57 minutes remaining
# 39.2 % completed, 1.009 minutes elapsed, 1.565 minutes remaining
# 39.4 % completed, 1.015 minutes elapsed, 1.56 minutes remaining
# 39.6 % completed, 1.02 minutes elapsed, 1.555 minutes remaining
# 39.8 % completed, 1.025 minutes elapsed, 1.549 minutes remaining
# 40.0 % completed, 1.03 minutes elapsed, 1.544 minutes remaining
# 40.2 % completed, 1.035 minutes elapsed, 1.539 minutes remaining
# 40.4 % completed, 1.041 minutes elapsed, 1.535 minutes remaining
# 40.6 % completed, 1.046 minutes elapsed, 1.529 minutes remaining
# 40.8 % completed, 1.051 minutes elapsed, 1.525 minutes remaining
# 41.0 % completed, 1.056 minutes elapsed, 1.52 minutes remaining
# 41.2 % completed, 1.062 minutes elapsed, 1.514 minutes remaining
# 41.4 % completed, 1.067 minutes elapsed, 1.509 minutes remaining
# 41.6 % completed, 1.072 minutes elapsed, 1.504 minutes remaining
# 41.8 % completed, 1.077 minutes elapsed, 1.499 minutes remaining
# 42.0 % completed, 1.082 minutes elapsed, 1.494 minutes remaining
# 42.2 % completed, 1.088 minutes elapsed, 1.489 minutes remaining
# 42.4 % completed, 1.093 minutes elapsed, 1.484 minutes remaining
# 42.6 % completed, 1.098 minutes elapsed, 1.479 minutes remaining
# 42.8 % completed, 1.103 minutes elapsed, 1.474 minutes remaining
# 43.0 % completed, 1.109 minutes elapsed, 1.469 minutes remaining
# 43.2 % completed, 1.114 minutes elapsed, 1.464 minutes remaining
# 43.4 % completed, 1.119 minutes elapsed, 1.459 minutes remaining
# 43.6 % completed, 1.124 minutes elapsed, 1.454 minutes remaining
# 43.8 % completed, 1.129 minutes elapsed, 1.449 minutes remaining
# 44.0 % completed, 1.135 minutes elapsed, 1.443 minutes remaining
# 44.2 % completed, 1.14 minutes elapsed, 1.438 minutes remaining
# 44.4 % completed, 1.145 minutes elapsed, 1.433 minutes remaining
# 44.6 % completed, 1.15 minutes elapsed, 1.428 minutes remaining
# 44.8 % completed, 1.155 minutes elapsed, 1.422 minutes remaining
# 45.0 % completed, 1.16 minutes elapsed, 1.417 minutes remaining
# 45.2 % completed, 1.165 minutes elapsed, 1.412 minutes remaining
# 45.4 % completed, 1.17 minutes elapsed, 1.407 minutes remaining
# 45.6 % completed, 1.175 minutes elapsed, 1.401 minutes remaining
# 45.8 % completed, 1.18 minutes elapsed, 1.396 minutes remaining
# 46.0 % completed, 1.186 minutes elapsed, 1.391 minutes remaining
# 46.2 % completed, 1.191 minutes elapsed, 1.386 minutes remaining
# 46.4 % completed, 1.196 minutes elapsed, 1.381 minutes remaining
# 46.6 % completed, 1.201 minutes elapsed, 1.375 minutes remaining
# 46.8 % completed, 1.206 minutes elapsed, 1.37 minutes remaining
# 47.0 % completed, 1.211 minutes elapsed, 1.365 minutes remaining
# 47.2 % completed, 1.216 minutes elapsed, 1.36 minutes remaining
# 47.4 % completed, 1.221 minutes elapsed, 1.354 minutes remaining
# 47.6 % completed, 1.226 minutes elapsed, 1.349 minutes remaining
# 47.8 % completed, 1.231 minutes elapsed, 1.344 minutes remaining
# 48.0 % completed, 1.236 minutes elapsed, 1.339 minutes remaining
# 48.2 % completed, 1.242 minutes elapsed, 1.334 minutes remaining
# 48.4 % completed, 1.247 minutes elapsed, 1.329 minutes remaining
# 48.6 % completed, 1.252 minutes elapsed, 1.323 minutes remaining
# 48.8 % completed, 1.257 minutes elapsed, 1.318 minutes remaining
# 49.0 % completed, 1.262 minutes elapsed, 1.313 minutes remaining
# 49.2 % completed, 1.267 minutes elapsed, 1.308 minutes remaining
# 49.4 % completed, 1.272 minutes elapsed, 1.303 minutes remaining
# 49.6 % completed, 1.277 minutes elapsed, 1.298 minutes remaining
# 49.8 % completed, 1.283 minutes elapsed, 1.292 minutes remaining
# 50.0 % completed, 1.287 minutes elapsed, 1.287 minutes remaining
# 50.2 % completed, 1.293 minutes elapsed, 1.282 minutes remaining
# 50.4 % completed, 1.298 minutes elapsed, 1.277 minutes remaining
# 50.6 % completed, 1.303 minutes elapsed, 1.271 minutes remaining
# 50.8 % completed, 1.308 minutes elapsed, 1.267 minutes remaining
# 51.0 % completed, 1.314 minutes elapsed, 1.262 minutes remaining
# 51.2 % completed, 1.319 minutes elapsed, 1.256 minutes remaining
# 51.4 % completed, 1.324 minutes elapsed, 1.251 minutes remaining
# 51.6 % completed, 1.329 minutes elapsed, 1.246 minutes remaining
# 51.8 % completed, 1.334 minutes elapsed, 1.241 minutes remaining
# 52.0 % completed, 1.339 minutes elapsed, 1.236 minutes remaining
# 52.2 % completed, 1.344 minutes elapsed, 1.23 minutes remaining
# 52.4 % completed, 1.349 minutes elapsed, 1.225 minutes remaining
# 52.6 % completed, 1.354 minutes elapsed, 1.22 minutes remaining
# 52.8 % completed, 1.359 minutes elapsed, 1.215 minutes remaining
# 53.0 % completed, 1.365 minutes elapsed, 1.21 minutes remaining
# 53.2 % completed, 1.37 minutes elapsed, 1.204 minutes remaining
# 53.4 % completed, 1.375 minutes elapsed, 1.199 minutes remaining
# 53.6 % completed, 1.38 minutes elapsed, 1.194 minutes remaining
# 53.8 % completed, 1.385 minutes elapsed, 1.189 minutes remaining
# 54.0 % completed, 1.39 minutes elapsed, 1.184 minutes remaining
# 54.2 % completed, 1.396 minutes elapsed, 1.179 minutes remaining
# 54.4 % completed, 1.401 minutes elapsed, 1.174 minutes remaining
# 54.6 % completed, 1.406 minutes elapsed, 1.168 minutes remaining
# 54.8 % completed, 1.411 minutes elapsed, 1.163 minutes remaining
# 55.0 % completed, 1.416 minutes elapsed, 1.158 minutes remaining
# 55.2 % completed, 1.421 minutes elapsed, 1.153 minutes remaining
# 55.4 % completed, 1.426 minutes elapsed, 1.147 minutes remaining
# 55.6 % completed, 1.431 minutes elapsed, 1.142 minutes remaining
# 55.8 % completed, 1.436 minutes elapsed, 1.137 minutes remaining
# 56.0 % completed, 1.441 minutes elapsed, 1.132 minutes remaining
# 56.2 % completed, 1.446 minutes elapsed, 1.127 minutes remaining
# 56.4 % completed, 1.451 minutes elapsed, 1.122 minutes remaining
# 56.6 % completed, 1.456 minutes elapsed, 1.116 minutes remaining
# 56.8 % completed, 1.462 minutes elapsed, 1.111 minutes remaining
# 57.0 % completed, 1.467 minutes elapsed, 1.106 minutes remaining
# 57.2 % completed, 1.472 minutes elapsed, 1.101 minutes remaining
# 57.4 % completed, 1.477 minutes elapsed, 1.096 minutes remaining
# 57.6 % completed, 1.483 minutes elapsed, 1.091 minutes remaining
# 57.8 % completed, 1.488 minutes elapsed, 1.086 minutes remaining
# 58.0 % completed, 1.493 minutes elapsed, 1.081 minutes remaining
# 58.2 % completed, 1.498 minutes elapsed, 1.075 minutes remaining
# 58.4 % completed, 1.503 minutes elapsed, 1.07 minutes remaining
# 58.6 % completed, 1.508 minutes elapsed, 1.065 minutes remaining
# 58.8 % completed, 1.513 minutes elapsed, 1.06 minutes remaining
# 59.0 % completed, 1.518 minutes elapsed, 1.055 minutes remaining
# 59.2 % completed, 1.523 minutes elapsed, 1.05 minutes remaining
# 59.4 % completed, 1.529 minutes elapsed, 1.044 minutes remaining
# 59.6 % completed, 1.534 minutes elapsed, 1.039 minutes remaining
# 59.8 % completed, 1.539 minutes elapsed, 1.035 minutes remaining
# 60.0 % completed, 1.545 minutes elapsed, 1.029 minutes remaining
# 60.2 % completed, 1.55 minutes elapsed, 1.024 minutes remaining
# 60.4 % completed, 1.555 minutes elapsed, 1.019 minutes remaining
# 60.6 % completed, 1.56 minutes elapsed, 1.014 minutes remaining
# 60.8 % completed, 1.565 minutes elapsed, 1.009 minutes remaining
# 61.0 % completed, 1.57 minutes elapsed, 1.004 minutes remaining
# 61.2 % completed, 1.575 minutes elapsed, 0.998 minutes remaining
# 61.4 % completed, 1.58 minutes elapsed, 0.993 minutes remaining
# 61.6 % completed, 1.585 minutes elapsed, 0.988 minutes remaining
# 61.8 % completed, 1.59 minutes elapsed, 0.983 minutes remaining
# 62.0 % completed, 1.595 minutes elapsed, 0.977 minutes remaining
# 62.2 % completed, 1.6 minutes elapsed, 0.972 minutes remaining
# 62.4 % completed, 1.606 minutes elapsed, 0.967 minutes remaining
# 62.6 % completed, 1.611 minutes elapsed, 0.962 minutes remaining
# 62.8 % completed, 1.616 minutes elapsed, 0.957 minutes remaining
# 63.0 % completed, 1.621 minutes elapsed, 0.952 minutes remaining
# 63.2 % completed, 1.627 minutes elapsed, 0.947 minutes remaining
# 63.4 % completed, 1.632 minutes elapsed, 0.942 minutes remaining
# 63.6 % completed, 1.637 minutes elapsed, 0.936 minutes remaining
# 63.8 % completed, 1.642 minutes elapsed, 0.931 minutes remaining
# 64.0 % completed, 1.647 minutes elapsed, 0.926 minutes remaining
# 64.2 % completed, 1.652 minutes elapsed, 0.921 minutes remaining
# 64.4 % completed, 1.657 minutes elapsed, 0.916 minutes remaining
# 64.6 % completed, 1.662 minutes elapsed, 0.911 minutes remaining
# 64.8 % completed, 1.667 minutes elapsed, 0.905 minutes remaining
# 65.0 % completed, 1.672 minutes elapsed, 0.9 minutes remaining
# 65.2 % completed, 1.677 minutes elapsed, 0.895 minutes remaining
# 65.4 % completed, 1.682 minutes elapsed, 0.89 minutes remaining
# 65.6 % completed, 1.687 minutes elapsed, 0.885 minutes remaining
# 65.8 % completed, 1.692 minutes elapsed, 0.879 minutes remaining
# 66.0 % completed, 1.698 minutes elapsed, 0.874 minutes remaining
# 66.2 % completed, 1.703 minutes elapsed, 0.869 minutes remaining
# 66.4 % completed, 1.708 minutes elapsed, 0.864 minutes remaining
# 66.6 % completed, 1.713 minutes elapsed, 0.859 minutes remaining
# 66.8 % completed, 1.718 minutes elapsed, 0.854 minutes remaining
# 67.0 % completed, 1.723 minutes elapsed, 0.848 minutes remaining
# 67.2 % completed, 1.728 minutes elapsed, 0.843 minutes remaining
# 67.4 % completed, 1.733 minutes elapsed, 0.838 minutes remaining
# 67.6 % completed, 1.738 minutes elapsed, 0.833 minutes remaining
# 67.8 % completed, 1.743 minutes elapsed, 0.828 minutes remaining
# 68.0 % completed, 1.748 minutes elapsed, 0.822 minutes remaining
# 68.2 % completed, 1.753 minutes elapsed, 0.817 minutes remaining
# 68.4 % completed, 1.758 minutes elapsed, 0.812 minutes remaining
# 68.6 % completed, 1.763 minutes elapsed, 0.807 minutes remaining
# 68.8 % completed, 1.768 minutes elapsed, 0.802 minutes remaining
# 69.0 % completed, 1.773 minutes elapsed, 0.796 minutes remaining
# 69.2 % completed, 1.778 minutes elapsed, 0.791 minutes remaining
# 69.4 % completed, 1.783 minutes elapsed, 0.786 minutes remaining
# 69.6 % completed, 1.788 minutes elapsed, 0.781 minutes remaining
# 69.8 % completed, 1.793 minutes elapsed, 0.776 minutes remaining
# 70.0 % completed, 1.798 minutes elapsed, 0.771 minutes remaining
# 70.2 % completed, 1.803 minutes elapsed, 0.765 minutes remaining
# 70.4 % completed, 1.808 minutes elapsed, 0.76 minutes remaining
# 70.6 % completed, 1.813 minutes elapsed, 0.755 minutes remaining
# 70.8 % completed, 1.818 minutes elapsed, 0.75 minutes remaining
# 71.0 % completed, 1.823 minutes elapsed, 0.745 minutes remaining
# 71.2 % completed, 1.828 minutes elapsed, 0.739 minutes remaining
# 71.4 % completed, 1.833 minutes elapsed, 0.734 minutes remaining
# 71.6 % completed, 1.838 minutes elapsed, 0.729 minutes remaining
# 71.8 % completed, 1.844 minutes elapsed, 0.724 minutes remaining
# 72.0 % completed, 1.849 minutes elapsed, 0.719 minutes remaining
# 72.2 % completed, 1.854 minutes elapsed, 0.714 minutes remaining
# 72.4 % completed, 1.859 minutes elapsed, 0.709 minutes remaining
# 72.6 % completed, 1.865 minutes elapsed, 0.703 minutes remaining
# 72.8 % completed, 1.87 minutes elapsed, 0.698 minutes remaining
# 73.0 % completed, 1.875 minutes elapsed, 0.693 minutes remaining
# 73.2 % completed, 1.88 minutes elapsed, 0.688 minutes remaining
# 73.4 % completed, 1.885 minutes elapsed, 0.683 minutes remaining
# 73.6 % completed, 1.89 minutes elapsed, 0.678 minutes remaining
# 73.8 % completed, 1.895 minutes elapsed, 0.673 minutes remaining
# 74.0 % completed, 1.901 minutes elapsed, 0.668 minutes remaining
# 74.2 % completed, 1.906 minutes elapsed, 0.663 minutes remaining
# 74.4 % completed, 1.911 minutes elapsed, 0.657 minutes remaining
# 74.6 % completed, 1.917 minutes elapsed, 0.652 minutes remaining
# 74.8 % completed, 1.922 minutes elapsed, 0.647 minutes remaining
# 75.0 % completed, 1.927 minutes elapsed, 0.642 minutes remaining
# 75.2 % completed, 1.932 minutes elapsed, 0.637 minutes remaining
# 75.4 % completed, 1.937 minutes elapsed, 0.632 minutes remaining
# 75.6 % completed, 1.943 minutes elapsed, 0.627 minutes remaining
# 75.8 % completed, 1.948 minutes elapsed, 0.622 minutes remaining
# 76.0 % completed, 1.953 minutes elapsed, 0.616 minutes remaining
# 76.2 % completed, 1.958 minutes elapsed, 0.611 minutes remaining
# 76.4 % completed, 1.963 minutes elapsed, 0.606 minutes remaining
# 76.6 % completed, 1.968 minutes elapsed, 0.601 minutes remaining
# 76.8 % completed, 1.973 minutes elapsed, 0.596 minutes remaining
# 77.0 % completed, 1.978 minutes elapsed, 0.591 minutes remaining
# 77.2 % completed, 1.983 minutes elapsed, 0.586 minutes remaining
# 77.4 % completed, 1.988 minutes elapsed, 0.58 minutes remaining
# 77.6 % completed, 1.993 minutes elapsed, 0.575 minutes remaining
# 77.8 % completed, 1.999 minutes elapsed, 0.57 minutes remaining
# 78.0 % completed, 2.004 minutes elapsed, 0.565 minutes remaining
# 78.2 % completed, 2.009 minutes elapsed, 0.56 minutes remaining
# 78.4 % completed, 2.014 minutes elapsed, 0.555 minutes remaining
# 78.6 % completed, 2.019 minutes elapsed, 0.55 minutes remaining
# 78.8 % completed, 2.024 minutes elapsed, 0.544 minutes remaining
# 79.0 % completed, 2.029 minutes elapsed, 0.539 minutes remaining
# 79.2 % completed, 2.034 minutes elapsed, 0.534 minutes remaining
# 79.4 % completed, 2.039 minutes elapsed, 0.529 minutes remaining
# 79.6 % completed, 2.044 minutes elapsed, 0.524 minutes remaining
# 79.8 % completed, 2.05 minutes elapsed, 0.519 minutes remaining
# 80.0 % completed, 2.055 minutes elapsed, 0.514 minutes remaining
# 80.2 % completed, 2.06 minutes elapsed, 0.508 minutes remaining
# 80.4 % completed, 2.065 minutes elapsed, 0.503 minutes remaining
# 80.6 % completed, 2.07 minutes elapsed, 0.498 minutes remaining
# 80.8 % completed, 2.075 minutes elapsed, 0.493 minutes remaining
# 81.0 % completed, 2.08 minutes elapsed, 0.488 minutes remaining
# 81.2 % completed, 2.086 minutes elapsed, 0.483 minutes remaining
# 81.4 % completed, 2.091 minutes elapsed, 0.478 minutes remaining
# 81.6 % completed, 2.096 minutes elapsed, 0.472 minutes remaining
# 81.8 % completed, 2.101 minutes elapsed, 0.467 minutes remaining
# 82.0 % completed, 2.106 minutes elapsed, 0.462 minutes remaining
# 82.2 % completed, 2.112 minutes elapsed, 0.457 minutes remaining
# 82.4 % completed, 2.117 minutes elapsed, 0.452 minutes remaining
# 82.6 % completed, 2.122 minutes elapsed, 0.447 minutes remaining
# 82.8 % completed, 2.127 minutes elapsed, 0.442 minutes remaining
# 83.0 % completed, 2.132 minutes elapsed, 0.437 minutes remaining
# 83.2 % completed, 2.137 minutes elapsed, 0.431 minutes remaining
# 83.4 % completed, 2.142 minutes elapsed, 0.426 minutes remaining
# 83.6 % completed, 2.147 minutes elapsed, 0.421 minutes remaining
# 83.8 % completed, 2.152 minutes elapsed, 0.416 minutes remaining
# 84.0 % completed, 2.157 minutes elapsed, 0.411 minutes remaining
# 84.2 % completed, 2.162 minutes elapsed, 0.406 minutes remaining
# 84.4 % completed, 2.167 minutes elapsed, 0.401 minutes remaining
# 84.6 % completed, 2.172 minutes elapsed, 0.395 minutes remaining
# 84.8 % completed, 2.178 minutes elapsed, 0.39 minutes remaining
# 85.0 % completed, 2.183 minutes elapsed, 0.385 minutes remaining
# 85.2 % completed, 2.188 minutes elapsed, 0.38 minutes remaining
# 85.4 % completed, 2.193 minutes elapsed, 0.375 minutes remaining
# 85.6 % completed, 2.198 minutes elapsed, 0.37 minutes remaining
# 85.8 % completed, 2.203 minutes elapsed, 0.365 minutes remaining
# 86.0 % completed, 2.208 minutes elapsed, 0.359 minutes remaining
# 86.2 % completed, 2.213 minutes elapsed, 0.354 minutes remaining
# 86.4 % completed, 2.218 minutes elapsed, 0.349 minutes remaining
# 86.6 % completed, 2.223 minutes elapsed, 0.344 minutes remaining
# 86.8 % completed, 2.229 minutes elapsed, 0.339 minutes remaining
# 87.0 % completed, 2.234 minutes elapsed, 0.334 minutes remaining
# 87.2 % completed, 2.239 minutes elapsed, 0.329 minutes remaining
# 87.4 % completed, 2.244 minutes elapsed, 0.323 minutes remaining
# 87.6 % completed, 2.249 minutes elapsed, 0.318 minutes remaining
# 87.8 % completed, 2.254 minutes elapsed, 0.313 minutes remaining
# 88.0 % completed, 2.259 minutes elapsed, 0.308 minutes remaining
# 88.2 % completed, 2.264 minutes elapsed, 0.303 minutes remaining
# 88.4 % completed, 2.269 minutes elapsed, 0.298 minutes remaining
# 88.6 % completed, 2.275 minutes elapsed, 0.293 minutes remaining
# 88.8 % completed, 2.28 minutes elapsed, 0.287 minutes remaining
# 89.0 % completed, 2.285 minutes elapsed, 0.282 minutes remaining
# 89.2 % completed, 2.29 minutes elapsed, 0.277 minutes remaining
# 89.4 % completed, 2.295 minutes elapsed, 0.272 minutes remaining
# 89.6 % completed, 2.3 minutes elapsed, 0.267 minutes remaining
# 89.8 % completed, 2.305 minutes elapsed, 0.262 minutes remaining
# 90.0 % completed, 2.311 minutes elapsed, 0.257 minutes remaining
# 90.2 % completed, 2.316 minutes elapsed, 0.252 minutes remaining
# 90.4 % completed, 2.321 minutes elapsed, 0.246 minutes remaining
# 90.6 % completed, 2.326 minutes elapsed, 0.241 minutes remaining
# 90.8 % completed, 2.331 minutes elapsed, 0.236 minutes remaining
# 91.0 % completed, 2.336 minutes elapsed, 0.231 minutes remaining
# 91.2 % completed, 2.341 minutes elapsed, 0.226 minutes remaining
# 91.4 % completed, 2.347 minutes elapsed, 0.221 minutes remaining
# 91.6 % completed, 2.352 minutes elapsed, 0.216 minutes remaining
# 91.8 % completed, 2.357 minutes elapsed, 0.21 minutes remaining
# 92.0 % completed, 2.362 minutes elapsed, 0.205 minutes remaining
# 92.2 % completed, 2.367 minutes elapsed, 0.2 minutes remaining
# 92.4 % completed, 2.372 minutes elapsed, 0.195 minutes remaining
# 92.6 % completed, 2.377 minutes elapsed, 0.19 minutes remaining
# 92.8 % completed, 2.382 minutes elapsed, 0.185 minutes remaining
# 93.0 % completed, 2.387 minutes elapsed, 0.18 minutes remaining
# 93.2 % completed, 2.393 minutes elapsed, 0.175 minutes remaining
# 93.4 % completed, 2.398 minutes elapsed, 0.169 minutes remaining
# 93.6 % completed, 2.403 minutes elapsed, 0.164 minutes remaining
# 93.8 % completed, 2.408 minutes elapsed, 0.159 minutes remaining
# 94.0 % completed, 2.413 minutes elapsed, 0.154 minutes remaining
# 94.2 % completed, 2.419 minutes elapsed, 0.149 minutes remaining
# 94.4 % completed, 2.424 minutes elapsed, 0.144 minutes remaining
# 94.6 % completed, 2.429 minutes elapsed, 0.139 minutes remaining
# 94.8 % completed, 2.434 minutes elapsed, 0.133 minutes remaining
# 95.0 % completed, 2.439 minutes elapsed, 0.128 minutes remaining
# 95.2 % completed, 2.444 minutes elapsed, 0.123 minutes remaining
# 95.4 % completed, 2.449 minutes elapsed, 0.118 minutes remaining
# 95.6 % completed, 2.454 minutes elapsed, 0.113 minutes remaining
# 95.8 % completed, 2.459 minutes elapsed, 0.108 minutes remaining
# 96.0 % completed, 2.464 minutes elapsed, 0.103 minutes remaining
# 96.2 % completed, 2.469 minutes elapsed, 0.098 minutes remaining
# 96.4 % completed, 2.475 minutes elapsed, 0.092 minutes remaining
# 96.6 % completed, 2.48 minutes elapsed, 0.087 minutes remaining
# 96.8 % completed, 2.485 minutes elapsed, 0.082 minutes remaining
# 97.0 % completed, 2.49 minutes elapsed, 0.077 minutes remaining
# 97.2 % completed, 2.495 minutes elapsed, 0.072 minutes remaining
# 97.4 % completed, 2.5 minutes elapsed, 0.067 minutes remaining
# 97.6 % completed, 2.506 minutes elapsed, 0.062 minutes remaining
# 97.8 % completed, 2.511 minutes elapsed, 0.056 minutes remaining
# 98.0 % completed, 2.516 minutes elapsed, 0.051 minutes remaining
# 98.2 % completed, 2.521 minutes elapsed, 0.046 minutes remaining
# 98.4 % completed, 2.526 minutes elapsed, 0.041 minutes remaining
# 98.6 % completed, 2.531 minutes elapsed, 0.036 minutes remaining
# 98.8 % completed, 2.536 minutes elapsed, 0.031 minutes remaining
# 99.0 % completed, 2.541 minutes elapsed, 0.026 minutes remaining
# 99.2 % completed, 2.547 minutes elapsed, 0.021 minutes remaining
# 99.4 % completed, 2.552 minutes elapsed, 0.015 minutes remaining
# 99.6 % completed, 2.557 minutes elapsed, 0.01 minutes remaining
# 99.8 % completed, 2.562 minutes elapsed, 0.005 minutes remaining
# Finished bootstrapping!

# %%
print(mix_coeffs_all)
# Out:
# [array([[0.57875216, 0.42124784],
#        [0.28605059, 0.71394941],
#        [0.21379756, 0.78620244],
#        ...,
#        [0.59288886, 0.40711114],
#        [0.51313848, 0.48686152],
#        [0.58254325, 0.41745675]])]

# %%
print(f"Number of items: {len(mix_coeffs_all[0])}")
print(f"Array shape: {mix_coeffs_all[0].shape}")
# Out:
# Number of items: 5000
# Array shape: (5000, 2)

# %% [markdown]
# ### Export csv file of mix_coeffs_all for use in the zircon fertility analysis

# %%
# Converting the mix_coeffs_all to a 2D array so that we can run all 5000 pairs of w1 and w2 through to understand the
# distribution through the bootstraping analyses. 
try:
    # Convert list to NumPy array
    array = np.array(mix_coeffs_all)
    # Flatten the array
    flattened_array = array.reshape(-1, array.shape[-1])
    # Determine column names based on the number of coefficients
    num_coeffs = flattened_array.shape[1]
    if num_coeffs == 2:
        column_names = ['Column1', 'Column2']
    elif num_coeffs == 3:
        column_names = ['Column1', 'Column2', 'Column3']
    else:
        # Fallback for other numbers of coefficients
        column_names = [f'Column{i+1}' for i in range(num_coeffs)]
    # Convert to DataFrame
    df = pd.DataFrame(flattened_array, columns=column_names)
    # Save to CSV in a "Spreadsheets" folder
    folder_path = "Spreadsheets"
    # Change name to current mixture
    filename = "mix_coeffs_all_ct-5_ct-6_ct-3_to_ct-9.csv"
    # Create folder if it doesn't exist
    os.makedirs(folder_path, exist_ok=True)
    # Create full path and save
    full_path = os.path.join(folder_path, filename)
    df.to_csv(full_path, index=False)
    print("Saved")
    
except Exception as e:
    print(f"Not saved: {e}")
    # Optional: Print array shape for debugging
    if 'array' in locals():
        print(f"Array shape: {array.shape}")
    if 'flattened_array' in locals():
        print(f"Flattened array shape: {flattened_array.shape}")
# Out:
# Saved

# %%
# Plot histograms of all coefficients on same plot to visualize the distributions
plt.figure(figsize=(10, 6))

# Define colors for up to 6 coefficients (extend as needed)
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown']

# Get the number of coefficient columns
num_coeffs = len([col for col in df.columns if col.startswith('Column')])

# Plot histogram for each coefficient
for i in range(num_coeffs):
    col_name = f'Column{i+1}'
    color = colors[i % len(colors)]  # Cycle through colors if more coefficients than colors
    label = f'w{i+1}'
    
    plt.hist(df[col_name], bins=50, alpha=0.8, color=color, edgecolor='black', 
             linewidth=0.5, label=label)

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Mix Coefficients')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot the results of mixture modeling as both cumulative and relative probability distributions
# The code below plots the parents and children along with the best-fit or average mixture. Setting plotMixResults = True also shows mixing results as a line or violin plot (not recommended when using a large number of parents)

# %%
plotType = 'PDP' # Specify the type of plot to make: options are 'KDE' or 'PDP'

fillParent = True # Color parents according to their specified color
parent_colors = 'Default' # 'Default' or specify colors as a list (e.g., ['gray','orange','red'])
child_colors = 'Default' # 'Default' or specify colors as a list or as a single color (e.g., 'gray')

color_by_age = False # Will color KDE or PDP according to age categories if set to True
agebins = [0, 20, 100, 200] # Specify  age categories for colored KDE or PDP (only used if color_by_age = True)
agebinsc = ['red','orange','green']
agebinsc_alpha = 0.5

xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

# Specify the plot dimensions
w1 = 8 # width of the KDE or PDP plots
w2 = 4 # width of the mixture modeling plots
c = 4 # height of the CDF panel

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

plotPie = True # Will plot a pie diagram of best-fit, median, or average mixture (specified with 'best_plot_type')

# Specify whether to plot the mixture results (not recommended if using a large number (>>10) of parents)
plotMixResults = True 

plotResultType = 'violin' # Options: 'line' or 'violin'
violin_width = 0.2

fig = dMix.plotMix(main_byid_df, parent_list, child_list, plotType=plotType, bw=bw, bw_x=bw_x, x1=x1, x2=x2, xdif=xdif,
                   fillParent = fillParent, parent_colors=parent_colors, child_colors=child_colors,
                   color_by_age=color_by_age, agebins=agebins, agebinsc=agebinsc, agebinsc_alpha=agebinsc_alpha,
                   xaxis_1=xaxis_1, xaxis_2=xaxis_2, w1=w1, w2=w2, c=c, plotPie=plotPie, plotMixResults=plotMixResults,
                   best_plot_type=best_plot_type, plotResultType=plotResultType, violin_width=violin_width, sigma=sigma,
                  mix_coeffs_all=mix_coeffs_all, mix_coeffs_bf=mix_coeffs_bf, obj_func_val=obj_func_val, best_mixed_dist=best_mixed_dist,
                  obj_vals_all=obj_vals_all, objective_metric=objective_metric)

# %% [markdown]
# <b>Recommended exercise:</b> Try making best_fit_plot equal to 'average' or 'median'

# %%
# Saves figure to a folder named 'Figures'
os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-11_age_distribution.svg')

# %% [markdown]
# ### Visualize the distribution of mixing results
#
# detritalPy-Mix also contains some functions that allow you to visualize the distributions of model results obtained by bootstrapping.

# %% [markdown]
# **Assess how modelled objective functions compare to those produced by random sampling**
#
# This plot compares the distribution of objective functions calculated by the bootstrapped mixture models with the distribution of objective functions calculated by comparing a child sample to a resampled version of itself.  If the mixture modelling does a good job reproducing the observed child sample, then these distributions should have a large amount of overlap.

# %%
#Default to None to uses black. Otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
modelled_colors = None

#Default to None to use default color pallette from detritalPy, 
# otherwise specify a list of colors for each child, e.g., ['dodgerblue', 'mediumseagreen']
# or a single color for all models, e.g., 'dodgerblue'
self_compared_colors = None

#Adds a title with summary statistics to each plot
doAddSummaryTitle = True

#Set up the axis to plot on
plotWidth = 5.0 #How wide should plots be?
subplotHeight = 3.0 #About how tall should each subplot be?

# Create the figure for plotting
f,axs = plt.subplots(len(selfCompMetrics_bs_set),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True);

#Plot the distributions of objective function values
axs = dMix.plot_many_bootstrapped_metric_comparisons_model_observations(obj_vals_all,
                                                                  selfCompMetrics_bs_set, objective_metric,child_list,
                                                                        main_byid_df,
                                                                        obj_func_crit, worse_than_crit,
                                                                        obj_func_val,
                                                                        modelled_colors = modelled_colors,
                                                                        self_compared_colors = self_compared_colors,
                                                                        axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,
                                                                        doAddSummaryTitle=doAddSummaryTitle,
                                                                        alpha = 0.5, bins = 50)

# %% [markdown]
# <b>Note:</b> Ideally, the bootstrapped models and bootstrapped self-comparisons will overlap in a 'good' mixture model. The 'crit' objective metric value is equal to the 95th percentile of the bootstrapped self-comparisons. In the synthetic example (Example 1), we expect the model fits to be about as good as the resampled mixture - so the histograms should have quite a bit of overlap.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_objective_function_distributions.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how modelled distributions compare to the observed distribution**
#
# This plot compares the range of distributions calculated by the bootstrapped mixture models with the observed distributions. If the mixture modelling does a good job reproducing the observed child sample, then these distributions should look similar.

# %%
xaxis_1 = 0 # Minimum x-axis value of plot
xaxis_2 = 400 # Maximum x-axis value of plot

#Set up the axis to plot on
plotWidth = 6.0 #How wide should plots be?
subplotHeight = 4.0 #About how tall should each subplot be?

#What interval of bootsrapped estimates do you want to summarize?
confidence_interval = 95.0 

#Get some colors for the children
child_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')

#What color do we want to plot model results as?
model_color = 'black'

#How transparent should filled in bounds be?
fill_alpha = 0.25

#Do we want to plot the range of distributions observed in the self-comparison?
plot_self_comparisons = True

#Create the axes to plot on
f,axs = plt.subplots(len(child_list),1,figsize = (plotWidth,subplotHeight*len(child_list)),sharex = True,sharey = 'col')

#Plot
axs = dMix.plot_child_bootstrappedmodel_distribution_comparison(main_byid_df,
                                                                child_modelled_distributions,
                                                                child_list,
                                                                xaxis_1 = xaxis_1, xaxis_2 = xaxis_2,
                                                                x1 = x1, x2 = x2, xdif = xdif, bw = bw, bw_x=bw_x,
                                                                objective_metric = objective_metric,
                                                                confidence_interval = confidence_interval,
                                                                fill_alpha = fill_alpha,
                                                            plot_self_comparisons = plot_self_comparisons,
                                                                childDists_bs_set = childDists_bs_set,
                                                            axs = axs, plotWidth = plotWidth, subplotHeight = subplotHeight,child_colors = child_colors,
                                                                model_color = model_color,sigma = sigma)

# %% [markdown]
# <b>Note:</b> In the synthetic example (Example 1), the observed variability in the Mixture should be pretty similar to the variability in the Model results. In the real-world Example 2, we see that the model uncertainty mostly overlaps with the Loess sample. There is some divergence in the youngest part of the U-Pb age distribution (<~250 Ma). In Example 3, te quality of the mixture modeling is not particularly good and gets progressively worse for older units. Perhaps our choice of parents is not capturing the true sediment sources to the Bengal Fan going back in time?

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_distribution_comparisons.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# **Assess how mixture coefficients vary in a section (or spatially)**
#
# We can plot how mixing coefficients vary with some other dimension by plotting summaries of the bootstrapped mixing coefficients against another variable; for example height in a strat column or distance along a transport system.

# %%
separate_parents = True # Set to True to plot each parent in a separate subplot. Set to False to plot all results together in the same plot.

# Define the extra dimension (e.g., spatial or temporal value) for plotting each child
# Note: there needs to be a value in this array for each child
yAxisValues = None #np.array([0.5, 100, 300, 600]) #Set to None to just use evenly spaced values

# Should we flip the x and y axis of the plot, such that the extra dimension (called yAxisValues above)
# is plotted on the horizontal axis?
doFlipXY = False

# Should we add 'error bars' to each point?
do_plot_errorbars = True

# What percentage of mixing coefficients should we summarize?
confidence_interval = 95

# What value should we plot for each mixture? Options: 'best-fit', 'average', 'median'
best_plot_type = 'best-fit'

# Speicy the color of parents
parent_colors = 'Default' # Options: 'Default', a list of colors (e.g., ['black','red'], or a single color (e.g., 'black')
plot_alpha = 0.3 # Plotting transparency

plotWidth = 15.0
plotHeight = 4.0

#Make the plot
f, ax = dMix.plot_bootstrapped_mixturecoefficients_stratigraphy(parent_list, child_list, mix_coeffs_bf, mix_coeffs_all,
                                                            confidence_interval = confidence_interval,
                                                            ax = None, plotWidth = plotWidth,
                                                             plotHeight = plotHeight, parent_colors = parent_colors, 
                                                             do_plot_errorbars = do_plot_errorbars,
                                                            yAxisValues = yAxisValues, doFlipXY = doFlipXY, plot_alpha = plot_alpha,
                                                               separate_parents = separate_parents, best_plot_type = best_plot_type);

# %% [markdown]
# <b>Note:</b> If you are only plotting one child sample (e.g., Examples 1 and 2), this plot is not very interesting. Example 3 provides a better example of how this plot could be used.

# %%
"Saves figure to a folder named 'Figures'"
#os.makedirs('Figures', exist_ok=True)
# Change name to current mixture
# Save figure as png, you can change to save the figure as a pdf, png, jpeg, svg, etc
#fig.savefig('Figures/dPy-mix_ct-5_ct-6_to_ct-10_spatial_comparison.png')
# Out:
# "Saves figure to a folder named 'Figures'"

# %% [markdown]
# ### Export results as an Excel file

# %% [markdown]
# Results can be exported as an Excel file with multiple worksheets

# %%
os.makedirs('Spreadsheets', exist_ok=True)
file_name = 'Spreadsheets/dPy-mix_ct-5_ct-6_ct-3_to_ct-9_results.xlsx'
dMix.export_results(parent_list, child_list, main_byid_df, objective_metric, xdif, bw, mix_coeffs_bf, 
                   obj_func_val, file_name=file_name, verbose=True, version=detritalpy.__version__,
                   bootstrap=True, nBootstrapIterations=nBootstrapIterations,
                   doPerturbResampledAges=doPerturbResampledAges,nGrainsToResample=nGrainsToResample,
                   mix_coeffs_all=mix_coeffs_all,obj_vals_all=obj_vals_all, obj_func_crit=obj_func_crit,
                   worse_than_crit=worse_than_crit, selfCompMetrics_bs_set=selfCompMetrics_bs_set)
# Out:
# Workbook saved
